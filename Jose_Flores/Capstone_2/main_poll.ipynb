# %% [markdown]
# # Exploration of Air Pollution Data
# ### Source of the data can be found  [here](https://www.kaggle.com/datasets/mayukh18/deap-deciphering-environmental-air-pollution)

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (0.12.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: packaging in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: shapely>=1.7 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: fiona>=1.8 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: munch>=2.3.2 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: importlib-metadata in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from fiona>=1.8->geopandas) (4.11.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: click~=8.0 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from fiona>=1.8->geopandas) (8.1.3)
# Requirement already satisfied: certifi in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from fiona>=1.8->geopandas) (2022.6.15)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from click~=8.0->fiona>=1.8->geopandas) (0.4.5)
# Requirement already satisfied: six in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing libraries for data exploration

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import geopandas as gpd
from geopandas import geodataframe
from shapely.geometry import Point

# %% [markdown]
# ### Loading and Overview

# %%
# creating a dataframe from csv file and displaying first ten rows

df = pd.read_csv("pollution_data.csv")

df.head(10)
# Out:
#          Date         City       County State Population Staying at Home  \
# 0  2019-01-01  albuquerque   bernalillo    NM                   1,77,171
# 1  2019-01-01      atlanta       fulton    GA                   2,83,093
# 2  2019-01-01       austin       travis    TX                   2,68,732
# 3  2019-01-01    baltimore      baltimo    MD                   1,91,486
# 4  2019-01-01        boise          ada    ID                   1,05,237
# 5  2019-01-01       boston      suffolk    MA                   2,64,296
# 6  2019-01-01     brooklyn        kings    NY                   9,64,005
# 7  2019-01-01    charlotte  mecklenburg    NC                   2,63,196
# 8  2019-01-01      chicago         cook    IL                  13,96,803
# 9  2019-01-01     columbia     richland    SC                     89,669
#
#   Population Not Staying at Home   mil_miles  past_week_avg_miles   latitude  \
# 0                       4,99,456   19.038463                  0.0  35.107209
# 1                       7,63,811   29.295609                  0.0  33.760109
# 2                       9,76,194   27.286079                  0.0  30.283333
# 3                       4,09,167   12.961132                  0.0  39.305833
# 4                       3,63,293   12.640954                  0.0  43.604545
# 5                       5,40,489   17.221880                  0.0  42.351282
# 6                      16,10,930   52.130628                  0.0  40.653269
# 7                       8,27,361   30.960487                  0.0  35.196351
# 8                      37,67,856  148.042151                  0.0  41.858851
# 9                       3,23,640   11.010421                  0.0  34.011818
#
#     longitude  ...  pm10_max  pm10_median  pm10_variance  pm10_count  \
# 0 -106.617209  ...     127.0         18.0        5303.29        48.0
# 1  -84.402826  ...      27.0         14.0         280.83        23.0
# 2  -97.750641  ...       NaN          NaN            NaN         NaN
# 3  -76.610417  ...      15.0          6.0          74.76        24.0
# 4 -116.202424  ...      20.0          5.0         170.86        47.0
# 5  -71.062051  ...       NaN          NaN            NaN         NaN
# 6  -73.956538  ...       NaN          NaN            NaN         NaN
# 7  -80.828108  ...       NaN          NaN            NaN         NaN
# 8  -87.676437  ...      70.0         13.0        2756.66        47.0
# 9  -81.013333  ...       NaN          NaN            NaN         NaN
#
#    wind-gust_min  wind-gust_max  wind-gust_median  wind-gust_variance  \
# 0            0.3           27.3               3.8              839.84
# 1            0.1            4.5               1.7               12.11
# 2            0.2           14.0               6.8              162.34
# 3            0.1           24.0               8.5              355.46
# 4            0.1           11.3               2.2               46.19
# 5            2.6           46.0              15.7             1244.66
# 6            0.3           33.3              12.2              593.08
# 7            0.1           15.1               4.6              173.58
# 8            0.8           16.5               5.0               84.51
# 9            0.2            8.2               5.3               66.03
#
#    wind-gust_count    pp_feat
# 0             54.0   0.319492
# 1             44.0  23.304216
# 2             67.0  14.333042
# 3             70.0   6.403240
# 4             92.0   0.000000
# 5            120.0  86.681580
# 6             88.0  26.824525
# 7             82.0   0.000000
# 8            191.0   3.606315
# 9             20.0   1.231301
#
# [10 rows x 71 columns]

# %%
# Looking at how many records are in the df using shape

df.shape
# Out:
# (35596, 71)

# %%
# Looking at the last 7 records of df

df.tail(7)
# Out:
#              Date           City         County State  \
# 35589  2020-12-11  san francisco  san francisco    CA
# 35590  2020-12-11       san jose    santa clara    CA
# 35591  2020-12-11        seattle           king    WA
# 35592  2020-12-11    springfield       sangamon    IL
# 35593  2020-12-11  staten island       richmond    NY
# 35594  2020-12-11    tallahassee           leon    FL
# 35595  2020-12-11         tucson           pima    AZ
#
#       Population Staying at Home Population Not Staying at Home  mil_miles  \
# 35589                   3,41,807                       5,41,498  15.626241
# 35590                   6,35,594                      13,01,976  43.472052
# 35591                   7,33,494                      14,99,669  50.982852
# 35592                     60,167                       1,35,181   6.221078
# 35593                   1,59,253                       3,16,926  14.491843
# 35594                     76,894                       2,15,608   8.184401
# 35595                   3,17,121                       7,21,952  31.191188
#
#        past_week_avg_miles   latitude   longitude  ...  pm10_max  pm10_median  \
# 35589                  0.0  37.770154 -122.418308  ...       NaN          NaN
# 35590                  0.0  37.308947 -121.872281  ...       NaN          NaN
# 35591                  0.0  47.590794 -122.325714  ...       NaN          NaN
# 35592                  0.0  39.783158  -89.641842  ...       NaN          NaN
# 35593                  0.0  40.588571  -74.150000  ...       NaN          NaN
# 35594                  0.0  30.456000  -84.262500  ...       NaN          NaN
# 35595                  0.0  32.217037 -110.949815  ...      55.0         27.0
#
#        pm10_variance  pm10_count  wind-gust_min  wind-gust_max  \
# 35589            NaN         NaN            0.5           17.8
# 35590            NaN         NaN            0.2           12.2
# 35591            NaN         NaN            0.2           17.7
# 35592            NaN         NaN            1.2           15.3
# 35593            NaN         NaN            0.2           11.5
# 35594            NaN         NaN            4.5           15.1
# 35595        1950.18       189.0            0.1            8.0
#
#        wind-gust_median  wind-gust_variance  wind-gust_count    pp_feat
# 35589               3.2              124.27             60.0   1.110022
# 35590               4.7              150.47             23.0   3.436658
# 35591               4.5              161.93            182.0   0.000000
# 35592               4.5              220.83             24.0   7.243005
# 35593               6.2               92.10             58.0  35.199504
# 35594               8.3              134.12             17.0   0.927474
# 35595               3.0               28.64            169.0   1.676946
#
# [7 rows x 71 columns]

# %%
df.keys()
# Out:
# Index(['Date', 'City', 'County', 'State', 'Population Staying at Home',
#        'Population Not Staying at Home', 'mil_miles', 'past_week_avg_miles',
#        'latitude', 'longitude', 'o3_min', 'o3_max', 'o3_median', 'o3_variance',
#        'o3_count', 'pressure_min', 'pressure_max', 'pressure_median',
#        'pressure_variance', 'pressure_count', 'pm25_min', 'pm25_max',
#        'pm25_median', 'pm25_variance', 'pm25_count', 'humidity_min',
#        'humidity_max', 'humidity_median', 'humidity_variance',
#        'humidity_count', 'temperature_min', 'temperature_max',
#        'temperature_median', 'temperature_variance', 'temperature_count',
#        'dew_min', 'dew_max', 'dew_median', 'dew_variance', 'dew_count',
#        'no2_min', 'no2_max', 'no2_median', 'no2_variance', 'no2_count',
#        'wind-speed_min', 'wind-speed_max', 'wind-speed_median',
#        'wind-speed_variance', 'wind-speed_count', 'co_min', 'co_max',
#        'co_median', 'co_variance', 'co_count', 'so2_min', 'so2_max',
#        'so2_median', 'so2_variance', 'so2_count', 'pm10_min', 'pm10_max',
#        'pm10_median', 'pm10_variance', 'pm10_count', 'wind-gust_min',
#        'wind-gust_max', 'wind-gust_median', 'wind-gust_variance',
#        'wind-gust_count', 'pp_feat'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35596 entries, 0 to 35595
# Data columns (total 71 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            35596 non-null  object
#  1   City                            35596 non-null  object
#  2   County                          35596 non-null  object
#  3   State                           35596 non-null  object
#  4   Population Staying at Home      35596 non-null  object
#  5   Population Not Staying at Home  35596 non-null  object
#  6   mil_miles                       35596 non-null  float64
#  7   past_week_avg_miles             35596 non-null  float64
#  8   latitude                        35596 non-null  float64
#  9   longitude                       35596 non-null  float64
#  10  o3_min                          33950 non-null  float64
#  11  o3_max                          33950 non-null  float64
#  12  o3_median                       33950 non-null  float64
#  13  o3_variance                     33950 non-null  float64
#  14  o3_count                        33950 non-null  float64
#  15  pressure_min                    34667 non-null  float64
#  16  pressure_max                    34667 non-null  float64
#  17  pressure_median                 34667 non-null  float64
#  18  pressure_variance               34667 non-null  float64
#  19  pressure_count                  34667 non-null  float64
#  20  pm25_min                        35134 non-null  float64
#  21  pm25_max                        35134 non-null  float64
#  22  pm25_median                     35134 non-null  float64
#  23  pm25_variance                   35134 non-null  float64
#  24  pm25_count                      35134 non-null  float64
#  25  humidity_min                    34668 non-null  float64
#  26  humidity_max                    34668 non-null  float64
#  27  humidity_median                 34668 non-null  float64
#  28  humidity_variance               34668 non-null  float64
#  29  humidity_count                  34668 non-null  float64
#  30  temperature_min                 34658 non-null  float64
#  31  temperature_max                 34658 non-null  float64
#  32  temperature_median              34658 non-null  float64
#  33  temperature_variance            34658 non-null  float64
#  34  temperature_count               34658 non-null  float64
#  35  dew_min                         20491 non-null  float64
#  36  dew_max                         20491 non-null  float64
#  37  dew_median                      20491 non-null  float64
#  38  dew_variance                    20491 non-null  float64
#  39  dew_count                       20491 non-null  float64
#  40  no2_min                         23558 non-null  float64
#  41  no2_max                         23558 non-null  float64
#  42  no2_median                      23558 non-null  float64
#  43  no2_variance                    23558 non-null  float64
#  44  no2_count                       23558 non-null  float64
#  45  wind-speed_min                  34646 non-null  float64
#  46  wind-speed_max                  34646 non-null  float64
#  47  wind-speed_median               34646 non-null  float64
#  48  wind-speed_variance             34646 non-null  float64
#  49  wind-speed_count                34646 non-null  float64
#  50  co_min                          24538 non-null  float64
#  51  co_max                          24538 non-null  float64
#  52  co_median                       24538 non-null  float64
#  53  co_variance                     24538 non-null  float64
#  54  co_count                        24538 non-null  float64
#  55  so2_min                         14676 non-null  float64
#  56  so2_max                         14676 non-null  float64
#  57  so2_median                      14676 non-null  float64
#  58  so2_variance                    14676 non-null  float64
#  59  so2_count                       14676 non-null  float64
#  60  pm10_min                        16965 non-null  float64
#  61  pm10_max                        16965 non-null  float64
#  62  pm10_median                     16965 non-null  float64
#  63  pm10_variance                   16965 non-null  float64
#  64  pm10_count                      16965 non-null  float64
#  65  wind-gust_min                   34217 non-null  float64
#  66  wind-gust_max                   34217 non-null  float64
#  67  wind-gust_median                34217 non-null  float64
#  68  wind-gust_variance              34217 non-null  float64
#  69  wind-gust_count                 34217 non-null  float64
#  70  pp_feat                         35596 non-null  float64
# dtypes: float64(65), object(6)
# memory usage: 19.3+ MB

# %%
keys_list = ['Date', 'City', 'County', 'State', 'Population Staying at Home',
       'Population Not Staying at Home', 'mil_miles', 'past_week_avg_miles',
       'latitude', 'longitude', 'o3_min', 'o3_max', 'o3_median', 'o3_variance',
       'o3_count', 'pressure_min', 'pressure_max', 'pressure_median',
       'pressure_variance', 'pressure_count', 'pm25_min', 'pm25_max',
       'pm25_median', 'pm25_variance', 'pm25_count', 'humidity_min',
       'humidity_max', 'humidity_median', 'humidity_variance',
       'humidity_count', 'temperature_min', 'temperature_max',
       'temperature_median', 'temperature_variance', 'temperature_count',
       'dew_min', 'dew_max', 'dew_median', 'dew_variance', 'dew_count',
       'no2_min', 'no2_max', 'no2_median', 'no2_variance', 'no2_count',
       'wind-speed_min', 'wind-speed_max', 'wind-speed_median',
       'wind-speed_variance', 'wind-speed_count', 'co_min', 'co_max',
       'co_median', 'co_variance', 'co_count', 'so2_min', 'so2_max',
       'so2_median', 'so2_variance', 'so2_count', 'pm10_min', 'pm10_max',
       'pm10_median', 'pm10_variance', 'pm10_count', 'wind-gust_min',
       'wind-gust_max', 'wind-gust_median', 'wind-gust_variance',
       'wind-gust_count', 'pp_feat']

# %%
# using describe on the dataset
df.describe()
# Out:
#           mil_miles  past_week_avg_miles      latitude     longitude  \
# count  35596.000000              35596.0  35596.000000  35596.000000
# mean      46.856694                  0.0     37.094422    -97.172019
# std       52.963897                  0.0      5.230635     18.310666
# min        1.461991                  0.0     21.304651   -157.843488
# 25%       17.931973                  0.0     33.502593   -112.070988
# 50%       31.174508                  0.0     37.549032    -93.103947
# 75%       52.377897                  0.0     40.724364    -82.979783
# max      443.915641                  0.0     47.590794    -71.062051
#
#              o3_min        o3_max     o3_median    o3_variance      o3_count  \
# count  33950.000000  33950.000000  33950.000000   33950.000000  33950.000000
# mean       6.347216     41.418074     22.175976    6902.829271     74.791517
# std        8.571965     57.404942     28.127937   53155.246079     52.517788
# min        0.100000      0.100000      0.100000       0.000000      2.000000
# 25%        0.800000     25.600000     14.500000     233.375000     24.000000
# 50%        4.000000     33.600000     20.800000     563.080000     66.000000
# 75%        9.600000     42.400000     27.200000    1191.895000    104.000000
# max      500.000000    500.000000    500.000000  612542.000000    216.000000
#
#        pressure_min  ...      pm10_max   pm10_median  pm10_variance  \
# count  34667.000000  ...  16965.000000  16965.000000   1.696500e+04
# mean     949.846006  ...     55.385028     17.666490   3.872913e+03
# std      220.722048  ...     90.403915     10.997532   3.369546e+04
# min        0.000000  ...      2.000000      1.000000   0.000000e+00
# 25%     1003.200000  ...     23.000000     10.000000   1.563600e+02
# 50%     1009.700000  ...     36.000000     15.000000   4.221200e+02
# 75%     1014.200000  ...     58.000000     21.000000   1.164700e+03
# max     1118.000000  ...    999.000000    164.000000   1.003710e+06
#
#          pm10_count  wind-gust_min  wind-gust_max  wind-gust_median  \
# count  16965.000000   34217.000000   34217.000000      34217.000000
# mean      76.844916       0.666110      14.475015          5.336239
# std       60.742441       1.647992       7.953625          3.185103
# min        2.000000       0.100000       0.100000          0.100000
# 25%       24.000000       0.100000       9.700000          3.000000
# 50%       48.000000       0.200000      13.000000          4.600000
# 75%      114.000000       0.400000      17.500000          7.000000
# max      216.000000      36.000000     327.000000         94.000000
#
#        wind-gust_variance  wind-gust_count       pp_feat
# count        34217.000000     34217.000000  35596.000000
# mean           154.271994        81.158225      8.435058
# std            389.347015        54.236630     24.625900
# min              0.000000         2.000000      0.000000
# 25%             59.660000        43.000000      0.338402
# 50%            106.340000        66.000000      1.771250
# 75%            181.020000       111.000000      6.111875
# max          26644.700000       329.000000    304.387974
#
# [8 rows x 65 columns]

# %% [markdown]
# ### Cleaning and Formatting

# %%
# Doing a type check on a cell 
type(df['Population Not Staying at Home'][5])
# Out:
# str

# %%
# looping through the array in order to remove the comma
i = 0
while i < len(df['Population Staying at Home']):
    df['Population Staying at Home'][i] = df['Population Staying at Home'][i].replace(",","")
    i += 1
# Out:
# C:\Users\dvisi\AppData\Local\Temp\ipykernel_54644\2507408201.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Staying at Home'][i] = df['Population Staying at Home'][i].replace(",","")

# %%
# looping through the array in order to remove the comma
i = 0
while i < len(df['Population Not Staying at Home']):
    df['Population Not Staying at Home'][i] = df['Population Not Staying at Home'][i].replace(",","")
    i += 1
# Out:
# C:\Users\dvisi\AppData\Local\Temp\ipykernel_54644\1481582488.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Not Staying at Home'][i] = df['Population Not Staying at Home'][i].replace(",","")

# %%
# converting the data to numeric and displaying the mean values of each population category
df["Population Not Staying at Home"] = df["Population Not Staying at Home"].astype(int)
df['Population Staying at Home'] = df['Population Staying at Home'].astype(int)
pop_home = df['Population Not Staying at Home'].mean().round(2)
pop_not_home = df['Population Staying at Home'].mean().round(2)

print(f"The mean population for people staying at home is {pop_home} \n")
print(f"The mean population for people staying at home is {pop_not_home} ")
# Out:
# The mean population for people staying at home is 1124679.3
#
# The mean population for people staying at home is 337261.34

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Looking for missing values
df.isna().sum()
# Out:
# Date                             0
# City                             0
# County                           0
# State                            0
# Population Staying at Home       0
#                               ...
# wind-gust_max                 1379
# wind-gust_median              1379
# wind-gust_variance            1379
# wind-gust_count               1379
# pp_feat                          0
# Length: 71, dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.date

# %% [markdown]
# ### Visualizations

# %%
# creating a function to plot histograms
def pollu_hist(feature, slices, axis):
    feature.hist(bins=slices, edgecolor='black')
    plt.xlabel(axis)

# %%
plt.scatter(df['pm10_median'], df['o3_median'])
plt.xlabel("Particulate Matter Median (pm10)")
plt.ylabel("Ozone Median (O3)")
plt.title("Particulate Matter Median vs O3 Median")
plt.show()

# %%
plt.scatter(df['pm10_count'], df['pp_feat'])
plt.xlabel("Particulate Matter Count (pm10)")
plt.ylabel("Neighboring Power Plant Influence")
plt.title("Particulate Matter Count vs Power Plant Influence")
plt.show()

# %%
# Applying the log10 function to population not staying at home
df['Population_Not_Home_Log'] = np.log10(df['Population Not Staying at Home'])
df['Population_Staying_Home_Log'] = np.log10(df['Population Staying at Home'])

# %%
pollu_hist(df['Population Not Staying at Home'], 50, 'Population Not Staying Home')

# %%
# Creating histogram of population log10
pollu_hist(df['Population_Not_Home_Log'], 50, "log10 of Population Not Staying Home")

# %%
pollu_hist(df['Population Staying at Home'], 50, 'Population Staying Home')

# %%
pollu_hist(df['Population_Staying_Home_Log'], 50, 'log10 of Population Staying Home')

# %%
for feature in df.columns:
    plt.title("Plot of "+feature,fontsize=15)
    plt.hist(df[feature],bins=20, edgecolor='black')
    plt.show()

# %%
sns.pairplot(data=df,
             y_vars=['Population_Staying_Home_Log', 'Population_Not_Home_Log','pp_feat','pm10_count', 'pm25_count'], 
             x_vars=['Population_Staying_Home_Log', 'Population_Not_Home_Log','pp_feat','pm10_count', 'pm25_count']
             #diag_kind='kde'
             )

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(data=abs(df.corr()), cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Filters & Aggregations

# %%
df['State'].unique()
# Out:
# array(['NM', 'GA', 'TX', 'MD', 'ID', 'MA', 'NY', 'NC', 'IL', 'SC', 'OH',
#        'CO', 'MI', 'CA', 'CT', 'HI', 'IN', 'MS', 'FL', 'NV', 'AR', 'WI',
#        'KS', 'TN', 'OK', 'NE', 'PA', 'AZ', 'OR', 'RI', 'VA', 'MN', 'UT',
#        'WA'], dtype=object)

# %%
az_filter = df['State'] == 'AZ' 
ca_filter = df['State'] == 'CA'
ny_filter = df['State'] =='NY'

# %%
metrics = ['mean','median','min','max','std']

# %%
df[az_filter].agg(['mean','median','min','max','std']).T
# Out:
# C:\Users\dvisi\AppData\Local\Temp\ipykernel_54644\1450076956.py:1: FutureWarning: ['Date', 'City', 'County', 'State'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df[az_filter].agg(['mean','median','min','max','std']).T
#                                       mean    median         min         max  \
# Date                                   NaN       NaN  2019-01-01  2020-12-11
# City                                   NaN       NaN     phoenix      tucson
# County                                 NaN       NaN    maricopa        pima
# State                                  NaN       NaN          AZ          AZ
# Population Staying at Home   610669.336826  518427.0    156053.0   1544689.0
# ...                                    ...       ...         ...         ...
# wind-gust_variance              146.367826    126.32        3.65      960.95
# wind-gust_count                 177.778802     183.0         4.0       216.0
# pp_feat                           3.695116  3.606738    0.890146    6.679228
# Population_Not_Home_Log           6.218912  6.200851    5.830226    6.570908
# Population_Staying_Home_Log       5.672558  5.694136    5.193272    6.188841
#
#                                        std
# Date                                   NaN
# City                                   NaN
# County                                 NaN
# State                                  NaN
# Population Staying at Home   403745.465844
# ...                                    ...
# wind-gust_variance              101.109398
# wind-gust_count                  22.844397
# pp_feat                            1.39535
# Population_Not_Home_Log           0.314924
# Population_Staying_Home_Log       0.325622
#
# [73 rows x 5 columns]

# %%
pollutants_loc = ['State','latitude','longitude','o3_count','pm25_count', 'no2_count', 'co_count', 'so2_count', 'pm10_count', 'pp_feat']
pollutants = ['State','o3_count','pm25_count', 'no2_count', 'co_count', 'so2_count', 'pm10_count', 'pp_feat']

# %%
df[az_filter].agg(metrics)
# Out:
# C:\Users\dvisi\AppData\Local\Temp\ipykernel_54644\2659899017.py:1: FutureWarning: ['Date', 'City', 'County', 'State'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df[az_filter].agg(metrics)
#               Date     City    County State  Population Staying at Home  \
# mean           NaN      NaN       NaN   NaN                6.106693e+05
# median         NaN      NaN       NaN   NaN                5.184270e+05
# min     2019-01-01  phoenix  maricopa    AZ                1.560530e+05
# max     2020-12-11   tucson      pima    AZ                1.544689e+06
# std            NaN      NaN       NaN   NaN                4.037455e+05
#
#         Population Not Staying at Home   mil_miles  past_week_avg_miles  \
# mean                      2.110115e+06   88.609452                  0.0
# median                    1.872990e+06   59.307828                  0.0
# min                       6.764350e+05   16.103528                  0.0
# max                       3.723126e+06  194.871781                  0.0
# std                       1.312786e+06   57.620369                  0.0
#
#          latitude   longitude  ...  pm10_variance  pm10_count  wind-gust_min  \
# mean    32.859815 -111.510401  ...    2487.970591  192.125749       0.192780
# median  32.859815 -111.510401  ...    1319.465000  191.000000       0.200000
# min     32.217037 -112.070988  ...      67.440000   66.000000       0.100000
# max     33.502593 -110.949815  ...  235770.000000  216.000000       4.600000
# std      0.643018    0.560796  ...    9055.159487   17.447339       0.209337
#
#         wind-gust_max  wind-gust_median  wind-gust_variance  wind-gust_count  \
# mean        16.289171          4.803917          146.367826       177.778802
# median      15.200000          4.500000          126.320000       183.000000
# min          2.000000          1.200000            3.650000         4.000000
# max        121.800000         14.800000          960.950000       216.000000
# std          8.771622          1.934359          101.109398        22.844397
#
#          pp_feat  Population_Not_Home_Log  Population_Staying_Home_Log
# mean    3.695116                 6.218912                     5.672558
# median  3.606738                 6.200851                     5.694136
# min     0.890146                 5.830226                     5.193272
# max     6.679228                 6.570908                     6.188841
# std     1.395350                 0.314924                     0.325622
#
# [5 rows x 73 columns]

# %%
df_copy = df
df_copy.head()
# Out:
#          Date         City      County State  Population Staying at Home  \
# 0  2019-01-01  albuquerque  bernalillo    NM                      177171
# 1  2019-01-01      atlanta      fulton    GA                      283093
# 2  2019-01-01       austin      travis    TX                      268732
# 3  2019-01-01    baltimore     baltimo    MD                      191486
# 4  2019-01-01        boise         ada    ID                      105237
#
#    Population Not Staying at Home  mil_miles  past_week_avg_miles   latitude  \
# 0                          499456  19.038463                  0.0  35.107209
# 1                          763811  29.295609                  0.0  33.760109
# 2                          976194  27.286079                  0.0  30.283333
# 3                          409167  12.961132                  0.0  39.305833
# 4                          363293  12.640954                  0.0  43.604545
#
#     longitude  ...  pm10_variance  pm10_count  wind-gust_min  wind-gust_max  \
# 0 -106.617209  ...        5303.29        48.0            0.3           27.3
# 1  -84.402826  ...         280.83        23.0            0.1            4.5
# 2  -97.750641  ...            NaN         NaN            0.2           14.0
# 3  -76.610417  ...          74.76        24.0            0.1           24.0
# 4 -116.202424  ...         170.86        47.0            0.1           11.3
#
#    wind-gust_median  wind-gust_variance  wind-gust_count    pp_feat  \
# 0               3.8              839.84             54.0   0.319492
# 1               1.7               12.11             44.0  23.304216
# 2               6.8              162.34             67.0  14.333042
# 3               8.5              355.46             70.0   6.403240
# 4               2.2               46.19             92.0   0.000000
#
#    Population_Not_Home_Log  Population_Staying_Home_Log
# 0                 5.698497                     5.248393
# 1                 5.882986                     5.451929
# 2                 5.989536                     5.429319
# 3                 5.611901                     5.282137
# 4                 5.560257                     5.022168
#
# [5 rows x 73 columns]

# %%
df2 =df
df2.head()
# Out:
#          Date         City      County State  Population Staying at Home  \
# 0  2019-01-01  albuquerque  bernalillo    NM                      177171
# 1  2019-01-01      atlanta      fulton    GA                      283093
# 2  2019-01-01       austin      travis    TX                      268732
# 3  2019-01-01    baltimore     baltimo    MD                      191486
# 4  2019-01-01        boise         ada    ID                      105237
#
#    Population Not Staying at Home  mil_miles  past_week_avg_miles   latitude  \
# 0                          499456  19.038463                  0.0  35.107209
# 1                          763811  29.295609                  0.0  33.760109
# 2                          976194  27.286079                  0.0  30.283333
# 3                          409167  12.961132                  0.0  39.305833
# 4                          363293  12.640954                  0.0  43.604545
#
#     longitude  ...  pm10_variance  pm10_count  wind-gust_min  wind-gust_max  \
# 0 -106.617209  ...        5303.29        48.0            0.3           27.3
# 1  -84.402826  ...         280.83        23.0            0.1            4.5
# 2  -97.750641  ...            NaN         NaN            0.2           14.0
# 3  -76.610417  ...          74.76        24.0            0.1           24.0
# 4 -116.202424  ...         170.86        47.0            0.1           11.3
#
#    wind-gust_median  wind-gust_variance  wind-gust_count    pp_feat  \
# 0               3.8              839.84             54.0   0.319492
# 1               1.7               12.11             44.0  23.304216
# 2               6.8              162.34             67.0  14.333042
# 3               8.5              355.46             70.0   6.403240
# 4               2.2               46.19             92.0   0.000000
#
#    Population_Not_Home_Log  Population_Staying_Home_Log
# 0                 5.698497                     5.248393
# 1                 5.882986                     5.451929
# 2                 5.989536                     5.429319
# 3                 5.611901                     5.282137
# 4                 5.560257                     5.022168
#
# [5 rows x 73 columns]

# %%
df_ploc = df[pollutants_loc]
dfp = df[pollutants]
df_ploc
# Out:
#       State   latitude   longitude  o3_count  pm25_count  no2_count  co_count  \
# 0        NM  35.107209 -106.617209      66.0        71.0       19.0      22.0
# 1        GA  33.760109  -84.402826      24.0        48.0       24.0      20.0
# 2        TX  30.283333  -97.750641      46.0        72.0        NaN       NaN
# 3        MD  39.305833  -76.610417      23.0        66.0       46.0       NaN
# 4        ID  43.604545 -116.202424      44.0        42.0        NaN      79.0
# ...     ...        ...         ...       ...         ...        ...       ...
# 35591    WA  47.590794 -122.325714      24.0       255.0       67.0      47.0
# 35592    IL  39.783158  -89.641842       NaN        67.0        NaN       NaN
# 35593    NY  40.588571  -74.150000      23.0        92.0       72.0      53.0
# 35594    FL  30.456000  -84.262500      48.0        72.0        NaN      42.0
# 35595    AZ  32.217037 -110.949815     214.0       209.0      192.0     192.0
#
#        so2_count  pm10_count    pp_feat
# 0            NaN        48.0   0.319492
# 1            9.0        23.0  23.304216
# 2            NaN         NaN  14.333042
# 3            NaN        24.0   6.403240
# 4           68.0        47.0   0.000000
# ...          ...         ...        ...
# 35591        7.0         NaN   0.000000
# 35592        NaN         NaN   7.243005
# 35593        NaN         NaN  35.199504
# 35594        NaN         NaN   0.927474
# 35595       88.0       189.0   1.676946
#
# [35596 rows x 10 columns]

# %%
# calculating median particulate matter for each state
df.groupby(['State'])['pm10_count'].mean().round(2)
# Out:
# State
# AR       NaN
# AZ    192.13
# CA     45.98
# CO    195.69
# CT     46.60
# FL    101.39
# GA     22.77
# HI     45.24
# ID     63.36
# IL     45.56
# IN     22.60
# KS       NaN
# MA       NaN
# MD     22.23
# MI     30.88
# MN     46.12
# MS     38.24
# NC     23.18
# NE     23.39
# NM     62.86
# NV    168.05
# NY       NaN
# OH       NaN
# OK     93.24
# OR       NaN
# PA       NaN
# RI       NaN
# SC       NaN
# TN       NaN
# TX    162.11
# UT       NaN
# VA       NaN
# WA       NaN
# WI     75.96
# Name: pm10_count, dtype: float64

# %%
dfp.groupby(['State']).agg(metrics)
# Out:
#          o3_count                                  pm25_count                \
#              mean median    min    max        std        mean median    min
# State
# AR      22.090090   23.0    3.0   24.0   2.646204   44.498498   46.0    3.0
# AZ     199.904192  208.0  106.0  216.0  18.703877  189.151946  191.0   83.0
# CA      65.020719   67.0    3.0  139.0  35.089712   73.364467   71.0    2.0
# CO     167.372754  178.0   62.0  184.0  23.508402  182.285928  187.0   92.0
# CT      21.612275   23.0    6.0   23.0   2.489733   47.604790   48.0   25.0
# FL      78.545954   69.0    9.0  144.0  35.725397   89.293026   71.0    8.0
# GA      24.325337   22.0    8.0   48.0  10.724113   30.741018   24.0   11.0
# HI      23.176647   24.0    8.0   24.0   1.613825   54.534431   58.0   16.0
# ID      57.827844   43.0   12.0  116.0  21.510403   52.067669   41.0    2.0
# IL      72.167091   24.0    3.0  144.0  52.950149  121.863190   72.0    8.0
# IN      86.024427   91.0   31.0   96.0  11.699448  134.598473  140.0   72.0
# KS      24.744012   24.0    4.0   46.0   5.195608   69.217066   70.0    9.0
# MA     135.259427  138.0   33.0  144.0  11.199737  128.567119  134.0   37.0
# MD      41.396707   46.0    5.0   48.0   9.460711   66.537425   70.0   22.0
# MI      30.701131   24.0    4.0   69.0  12.686646   80.107903   48.0    8.0
# MN      41.481259   47.0   12.0   48.0  10.036758  134.413174  139.0   63.0
# MS      61.818591   67.0   23.0   72.0  11.184573   70.748126   72.0   40.0
# NC      41.049438   45.0    9.0   47.0   7.934927   57.744378   60.0   10.0
# NE      23.179910   24.0    7.0   24.0   1.696318   42.838323   46.0    2.0
# NM      68.188623   70.0   35.0   72.0   5.349023   63.808383   71.0   22.0
# NV     147.953775  152.0    6.0  189.0  27.053919  167.822804  176.0    7.0
# NY      48.506415   50.0    5.0  120.0  23.060069  113.197151  114.0   16.0
# OH      22.453390   23.0    2.0   24.0   1.942362   44.079460   47.0   18.0
# OK      66.461769   71.0   24.0   72.0   9.699987   94.815592   96.0   64.0
# OR      91.836275   94.0    7.0  140.0  36.305184  116.725843   72.0   24.0
# PA      83.406297   87.0   40.0   94.0   9.429436   85.380810   89.0   30.0
# RI      40.505295   45.0    4.0   48.0   9.689516   73.252632   71.0   32.0
# SC      22.292308   23.0   11.0   23.0   1.876858   19.620690   20.0    2.0
# TN      59.156550   67.0    2.0   72.0  17.578858   73.859715   72.0   23.0
# TX      83.566123   72.0    2.0  169.0  46.641300   89.485261   72.0    3.0
# UT     105.190405   70.0   27.0  216.0  67.257481  106.718141   72.0   28.0
# VA     103.194192  108.0   14.0  130.0  19.139878   43.787109   24.0    5.0
# WA     168.520301  207.0    9.0  216.0  70.154734  282.318318  296.0  155.0
# WI      89.911051   88.0    9.0  167.0  49.111258  105.141785   90.0   18.0
#
#                          ...  pm10_count                                  \
#          max        std  ...        mean median    min    max        std
# State                    ...
# AR      48.0   4.964006  ...         NaN    NaN    NaN    NaN        NaN
# AZ     216.0  22.704322  ...  192.125749  191.0   66.0  216.0  17.447339
# CA     144.0  32.982616  ...   45.977787   47.0    5.0  144.0  19.009121
# CO     207.0  20.577290  ...  195.687126  203.0  106.0  207.0  15.356709
# CT      71.0   2.283394  ...   46.604790   47.0   25.0   48.0   2.485841
# FL     168.0  44.822054  ...  101.385214  116.0    7.0  167.0  28.486343
# GA      48.0  11.010980  ...   22.768421   23.0    2.0   24.0   1.973597
# HI      72.0  12.129994  ...   45.244012   46.0   21.0   48.0   3.862173
# ID     119.0  32.461051  ...   63.361991   48.0   12.0  120.0  27.752116
# IL     231.0  64.246595  ...   45.556923   47.0   14.0   48.0   5.255036
# IN     144.0  12.226919  ...   22.598756   24.0    2.0   24.0   3.410283
# KS      96.0  17.342892  ...         NaN    NaN    NaN    NaN        NaN
# MA     144.0  15.529952  ...         NaN    NaN    NaN    NaN        NaN
# MD      72.0   7.995320  ...   22.225700   23.0    3.0   24.0   2.922000
# MI     168.0  48.841329  ...   30.880068   24.0    2.0   72.0  13.727126
# MN     144.0  11.008513  ...   46.122754   48.0   22.0   48.0   4.460712
# MS      72.0   3.994306  ...   38.242038   47.0   13.0   48.0  11.450787
# NC      95.0  14.673026  ...   23.182254   24.0    8.0   24.0   2.199612
# NE      48.0   7.531298  ...   23.391566   24.0    6.0   24.0   2.145602
# NM      72.0  12.752016  ...   62.860778   71.0   22.0   72.0  13.035993
# NV     184.0  26.308023  ...  168.049307  176.0    6.0  184.0  26.549233
# NY     168.0  29.567743  ...         NaN    NaN    NaN    NaN        NaN
# OH      48.0   7.264293  ...         NaN    NaN    NaN    NaN        NaN
# OK      96.0   3.901243  ...   93.244378   95.0   64.0   96.0   4.765549
# OR     188.0  60.411964  ...         NaN    NaN    NaN    NaN        NaN
# PA      96.0  10.490899  ...         NaN    NaN    NaN    NaN        NaN
# RI      96.0  13.624568  ...         NaN    NaN    NaN    NaN        NaN
# SC      45.0   6.571595  ...         NaN    NaN    NaN    NaN        NaN
# TN      95.0  13.846780  ...         NaN    NaN    NaN    NaN        NaN
# TX     192.0  50.727141  ...  162.107856  189.0    2.0  192.0  53.980271
# UT     216.0  66.482663  ...         NaN    NaN    NaN    NaN        NaN
# VA      96.0  30.930001  ...         NaN    NaN    NaN    NaN        NaN
# WA     312.0  28.465426  ...         NaN    NaN    NaN    NaN        NaN
# WI     192.0  59.781699  ...   75.960990   48.0   14.0  144.0  33.611653
#
#           pp_feat
#              mean      median        min         max        std
# State
# AR       0.057027    0.000000   0.000000    0.314956   0.094783
# AZ       3.695116    3.606738   0.890146    6.679228   1.395350
# CA       2.074601    1.123639   0.000000    8.626484   2.157315
# CO       6.926094    6.619297   4.609039    9.717373   1.315998
# CT       1.060816    1.279163   0.046252    2.269846   0.714238
# FL       1.303234    1.093651   0.000000    3.922299   1.218392
# GA      22.741228   23.546549  17.639997   25.408379   2.316200
# HI       1.706413    1.647220   1.303085    2.287505   0.280027
# ID       0.000000    0.000000   0.000000    0.000000   0.000000
# IL       5.392812    3.842610   0.000000   16.740327   4.059923
# IN       1.719086    1.290985   0.000000    5.367672   1.300458
# KS       0.000000    0.000000   0.000000    0.000000   0.000000
# MA      58.095814   60.708504   0.000000   90.589007  16.767136
# MD       2.542197    2.658443   0.000000    6.403240   2.106847
# MI      16.550397   17.370101   0.000000   21.169259   3.700867
# MN      20.067197   19.077434   7.274221   29.342909   6.245506
# MS       7.573921    9.027022   0.000000   11.237926   2.921150
# NC       0.167658    0.000000   0.000000    1.688775   0.323757
# NE       6.929268    7.349441   2.523261   10.449046   2.551836
# NM       0.566644    0.326481   0.000000    3.007933   0.662401
# NV       1.209431    0.775160   0.000000    3.406152   0.875551
# NY      35.060712   33.034650  17.054829   71.680113  12.784893
# OH       0.000000    0.000000   0.000000    0.000000   0.000000
# OK       1.043839    1.031553   0.000000    1.999388   0.398188
# OR       0.380132    0.000000   0.000000    1.051637   0.456759
# PA       7.170030    7.547535   2.465173   14.820654   3.728100
# RI     141.220000  170.720629   0.000000  304.387974  87.549286
# SC       1.255193    1.713283   0.000000    2.406135   0.922112
# TN       3.048435    3.724627   0.000000    6.776174   2.198457
# TX       4.075865    1.832957   0.000000   25.250072   5.280653
# UT       1.283353    0.980542   0.398139    3.629886   0.749844
# VA       1.009039    1.022238   0.000000    2.283909   0.596792
# WA       0.000000    0.000000   0.000000    0.000000   0.000000
# WI       6.124851    6.066578   0.000000   16.288607   4.894625
#
# [34 rows x 35 columns]

# %%
# geometry = [Point(xy) for xy in zip(df_ploc['longitude'], df_ploc['latitude'])]
# gdf = geodataframe(df_ploc, geometry=geometry)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\dvisi\PycharmProjects\2023-02-DSI-WE\Jose_Flores\Capstone_2\main.ipynb Cell 44 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> geometry = [Point(xy) for xy in zip(df_ploc['longitude'], df_ploc['latitude'])]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#X61sZmlsZQ%3D%3D?line=1'>2</a> gdf = geodataframe(df_ploc, geometry=geometry)
#
# TypeError: 'module' object is not callable

# %%
# creating filters for 3 different states
az_filter = df['State'] == 'AZ' 
ca_filter = df['State'] == 'CA'
ny_filter = df['State'] =='NY'

# %%
# Cehcking one filter and displaying head
df2[az_filter].head()
# Out:
#            Date     City    County State  Population Staying at Home  \
# 36   2019-01-01  phoenix  maricopa    AZ                     1025429
# 53   2019-01-01   tucson      pima    AZ                      246669
# 90   2019-01-02  phoenix  maricopa    AZ                      790437
# 107  2019-01-02   tucson      pima    AZ                      183326
# 144  2019-01-03  phoenix  maricopa    AZ                      808290
#
#      Population Not Staying at Home   mil_miles  past_week_avg_miles  \
# 36                          3371913  130.135000                  0.0
# 53                           789228   28.393075                  0.0
# 90                          3606905  157.750013                  0.0
# 107                          852571   36.084492                  0.0
# 144                         3589052  161.592417                  0.0
#
#       latitude   longitude  ...  pm10_variance  pm10_count  wind-gust_min  \
# 36   33.502593 -112.070988  ...        2670.76       216.0            0.1
# 53   32.217037 -110.949815  ...          85.93       178.0            0.1
# 90   33.502593 -112.070988  ...        1707.61       216.0            0.2
# 107  32.217037 -110.949815  ...        2991.77       190.0            0.1
# 144  33.502593 -112.070988  ...        1024.90       216.0            0.1
#
#      wind-gust_max  wind-gust_median  wind-gust_variance  wind-gust_count  \
# 36             9.0               2.1               42.24            170.0
# 53            14.5               4.5              104.11            176.0
# 90            12.0               3.2               57.79            180.0
# 107           11.5               2.8               74.37            173.0
# 144           10.8               4.0               60.38            178.0
#
#       pp_feat  Population_Not_Home_Log  Population_Staying_Home_Log
# 36   2.782755                 6.527876                     6.010906
# 53   0.890146                 5.897202                     5.392115
# 90   2.782755                 6.557135                     5.897867
# 107  0.890146                 5.930731                     5.263224
# 144  2.782755                 6.554980                     5.907567
#
# [5 rows x 73 columns]

# %%
# Creating one data frame out of 3 filtered sets
df_states = pd.concat([df2[az_filter], df2[ca_filter], df2[ny_filter]])

# %%
# displaying a 15 row sample of newly concatenated dataframe
df_states.sample(15)
# Out:
#              Date           City         County State  \
# 33086  2020-10-22     sacramento     sacramento    CA
# 19980  2020-02-08     sacramento     sacramento    CA
# 31055  2020-09-11       san jose    santa clara    CA
# 13231  2019-09-11        phoenix       maricopa    AZ
# 27659  2020-07-07        phoenix       maricopa    AZ
# 13281  2019-09-13        oakland        alameda    CA
# 16010  2019-11-04         fresno         fresno    CA
# 22068  2020-03-20         tucson           pima    AZ
# 29137  2020-08-05        oakland        alameda    CA
# 11153  2019-08-03       brooklyn          kings    NY
# 23123  2020-04-09  san francisco  san francisco    CA
# 3756   2019-03-14      san diego      san diego    CA
# 7214   2019-05-20       brooklyn          kings    NY
# 7583   2019-05-26  staten island       richmond    NY
# 5390   2019-04-15         fresno         fresno    CA
#
#        Population Staying at Home  Population Not Staying at Home   mil_miles  \
# 33086                      429789                         1111186   42.128078
# 19980                      445696                         1095279   42.726351
# 31055                      647427                         1290143   44.477229
# 13231                      919035                         3478307  146.983400
# 27659                     1168870                         3241954  123.208874
# 13281                      307855                         1353804   70.145026
# 16010                      217958                          773403   50.084783
# 22068                      296350                          742723   29.560403
# 29137                      482124                         1184629   35.202497
# 11153                      771565                         1803370   70.133832
# 23123                      316435                          566870   19.468284
# 3756                       641525                         2691620  124.070698
# 7214                       796145                         1778790   71.119893
# 7583                       117083                          357641   22.280058
# 5390                       221333                          770028   51.549718
#
#        past_week_avg_miles   latitude   longitude  ...  pm10_variance  \
# 33086                  0.0  38.569902 -121.467157  ...       21704.40
# 19980                  0.0  38.569902 -121.467157  ...         220.96
# 31055                  0.0  37.308947 -121.872281  ...            NaN
# 13231                  0.0  33.502593 -112.070988  ...        2856.06
# 27659                  0.0  33.502593 -112.070988  ...        1607.09
# 13281                  0.0  37.786296 -122.225556  ...            NaN
# 16010                  0.0  36.756833 -119.783333  ...         975.64
# 22068                  0.0  32.217037 -110.949815  ...         471.85
# 29137                  0.0  37.786296 -122.225556  ...            NaN
# 11153                  0.0  40.653269  -73.956538  ...            NaN
# 23123                  0.0  37.770154 -122.418308  ...            NaN
# 3756                   0.0  32.778148 -117.131728  ...            NaN
# 7214                   0.0  40.653269  -73.956538  ...            NaN
# 7583                   0.0  40.588571  -74.150000  ...            NaN
# 5390                   0.0  36.756833 -119.783333  ...         137.43
#
#        pm10_count  wind-gust_min  wind-gust_max  wind-gust_median  \
# 33086        23.0            0.4           14.9               8.0
# 19980        60.0            0.5           11.4               5.5
# 31055         NaN            0.1            9.9               3.5
# 13231       216.0            0.1           12.8               3.6
# 27659       190.0            0.2           15.0               5.8
# 13281         NaN            0.2           11.7               1.6
# 16010        49.0            0.1           20.0               5.3
# 22068       184.0            0.2           14.3               4.7
# 29137         NaN            0.1           12.0               2.2
# 11153         NaN            0.1           14.1               4.0
# 23123         NaN            0.2           10.5               5.2
# 3756          NaN            1.0           13.0               3.7
# 7214          NaN            0.2           26.7               9.1
# 7583          NaN            0.2            9.7               4.3
# 5390         48.0            0.7           19.5               9.7
#
#        wind-gust_variance  wind-gust_count    pp_feat  \
# 33086              173.96             49.0   2.729087
# 19980               65.03             50.0   1.861031
# 31055              126.96             32.0   2.780774
# 13231               82.92            156.0   4.475270
# 27659              122.55            166.0   6.679228
# 13281              113.19             61.0   1.311788
# 16010              307.22             70.0   0.000000
# 22068              110.07            185.0   2.822538
# 29137              107.06             84.0   1.869824
# 11153              120.36            118.0  33.034650
# 23123               91.06             41.0   0.550594
# 3756               118.44             24.0   0.302559
# 7214               439.32            139.0  22.788279
# 7583                78.27             85.0  43.336493
# 5390               180.34             71.0   0.000000
#
#        Population_Not_Home_Log  Population_Staying_Home_Log
# 33086                 6.045787                     5.633255
# 19980                 6.039525                     5.649039
# 31055                 6.110638                     5.811191
# 13231                 6.541368                     5.963332
# 27659                 6.510807                     6.067766
# 13281                 6.131556                     5.488346
# 16010                 5.888406                     5.338373
# 22068                 5.870827                     5.471805
# 29137                 6.073582                     5.683159
# 11153                 6.256085                     5.887373
# 23123                 5.753483                     5.500285
# 3756                  6.430014                     5.807214
# 7214                  6.250125                     5.900992
# 7583                  5.553447                     5.068494
# 5390                  5.886507                     5.345046
#
# [15 rows x 73 columns]

# %%
# Creating function in order to loop through particulates list and creat box plots
def box_loop(dataframe, features_list):
    for x in features_list:
        sns.boxplot(data=dataframe, y=x,
            x='State',
            notch=True,
            medianprops=dict(linestyle='-', linewidth=2, color='Yellow'),
            width=.3
        )
        plt.show()

# %%
# creating list of the pollutants of interest
pollutant_list = ['o3_count',
 'pm25_count',
 'no2_count',
 'co_count',
 'so2_count']

# %%
box_loop(dataframe=df_states, features_list=pollutant_list)

# %%
pop = ['Population Not Staying at Home','Population Staying at Home']

box_loop(dataframe=df_states, features_list=pop)

# %%
ky = ['Date', 'City', 'County', 'State', 'Population Staying at Home',
       'Population Not Staying at Home', 'past_week_avg_miles', 'latitude',
       'longitude', 'o3_min', 'o3_max', 'o3_median', 'o3_variance', 'o3_count',
       'pressure_min', 'pressure_max', 'pressure_median', 'pressure_variance',
       'pressure_count', 'pm25_min', 'pm25_max', 'pm25_median',
       'pm25_variance', 'pm25_count', 'humidity_min', 'humidity_max',
       'humidity_median', 'humidity_variance', 'humidity_count',
       'temperature_min', 'temperature_max', 'temperature_median',
       'temperature_variance', 'temperature_count', 'dew_min', 'dew_max',
       'dew_median', 'dew_variance', 'dew_count', 'no2_min', 'no2_max',
       'no2_median', 'no2_variance', 'no2_count', 'wind-speed_min',
       'wind-speed_max', 'wind-speed_median', 'wind-speed_variance',
       'wind-speed_count', 'co_min', 'co_max', 'co_median', 'co_variance',
       'co_count', 'so2_min', 'so2_max', 'so2_median', 'so2_variance',
       'so2_count', 'pm10_min', 'pm10_max', 'pm10_median', 'pm10_variance',
       'pm10_count', 'wind-gust_min', 'wind-gust_max', 'wind-gust_median',
       'wind-gust_variance', 'wind-gust_count', 'pp_feat',
       'Population_Not_Home_Log', 'Population_Staying_Home_Log']

for value in ky:
    miss = df_states[value].isna().sum()
    if miss > 0:
        print(f"{value}, {df[value].isna().sum()}")
# Out:
# o3_min, 1646
# o3_max, 1646
# o3_median, 1646
# o3_variance, 1646
# o3_count, 1646
# pressure_min, 929
# pressure_max, 929
# pressure_median, 929
# pressure_variance, 929
# pressure_count, 929
# pm25_min, 462
# pm25_max, 462
# pm25_median, 462
# pm25_variance, 462
# pm25_count, 462
# humidity_min, 928
# humidity_max, 928
# humidity_median, 928
# humidity_variance, 928
# humidity_count, 928
# temperature_min, 938
# temperature_max, 938
# temperature_median, 938
# temperature_variance, 938
# temperature_count, 938
# dew_min, 15105
# dew_max, 15105
# dew_median, 15105
# dew_variance, 15105
# dew_count, 15105
# no2_min, 12038
# no2_max, 12038
# no2_median, 12038
# no2_variance, 12038
# no2_count, 12038
# wind-speed_min, 950
# wind-speed_max, 950
# wind-speed_median, 950
# wind-speed_variance, 950
# wind-speed_count, 950
# co_min, 11058
# co_max, 11058
# co_median, 11058
# co_variance, 11058
# co_count, 11058
# so2_min, 20920
# so2_max, 20920
# so2_median, 20920
# so2_variance, 20920
# so2_count, 20920
# pm10_min, 18631
# pm10_max, 18631
# pm10_median, 18631
# pm10_variance, 18631
# pm10_count, 18631
# wind-gust_min, 1379
# wind-gust_max, 1379
# wind-gust_median, 1379
# wind-gust_variance, 1379
# wind-gust_count, 1379

# %% [markdown]
# # Cluster Work

# %%
pip install kneed
# Out:
# Collecting kneedNote: you may need to restart the kernel to use updated packages.
#
#   Downloading kneed-0.8.3-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from kneed) (1.22.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\dvisi\anaconda3\envs\dojo-env\lib\site-packages (from kneed) (1.8.1)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.3

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
import sklearn.cluster as cluster

import time
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
plot_kwds = {'alpha' : 0.25, 's' : 80, 'linewidths': 0}

# %%
def plot_clusters(data, algorithm, args, kwds):
    start_time = time.time()
    labels = algorithm(*args, **kwds).fit_predict(data)
    end_time = time.time()
    palette = sns.color_palette('deep', np.unique(labels).max() + 1)
    colors = [palette[x] if x >= 0 else (0.0, 0.0, 0.0) for x in labels]
    plt.scatter(data.T[0], data.T[1], c=colors, **plot_kwds)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)
    plt.title('Clusters found by {}'.format(str(algorithm.__name__)), fontsize=24)
    plt.text(-0.5, 0.7, 'Clustering took {:.2f} s'.format(end_time - start_time), fontsize=14)

# %%
df4.head()
# Out:
#          Date         City      County State  Population Staying at Home  \
# 0  2019-01-01  albuquerque  bernalillo    NM                      177171
# 1  2019-01-01      atlanta      fulton    GA                      283093
# 2  2019-01-01       austin      travis    TX                      268732
# 3  2019-01-01    baltimore     baltimo    MD                      191486
# 4  2019-01-01        boise         ada    ID                      105237
#
#    Population Not Staying at Home  mil_miles  past_week_avg_miles   latitude  \
# 0                          499456  19.038463                  0.0  35.107209
# 1                          763811  29.295609                  0.0  33.760109
# 2                          976194  27.286079                  0.0  30.283333
# 3                          409167  12.961132                  0.0  39.305833
# 4                          363293  12.640954                  0.0  43.604545
#
#     longitude  ...  pm10_variance  pm10_count  wind-gust_min  wind-gust_max  \
# 0 -106.617209  ...        5303.29        48.0            0.3           27.3
# 1  -84.402826  ...         280.83        23.0            0.1            4.5
# 2  -97.750641  ...            NaN         NaN            0.2           14.0
# 3  -76.610417  ...          74.76        24.0            0.1           24.0
# 4 -116.202424  ...         170.86        47.0            0.1           11.3
#
#    wind-gust_median  wind-gust_variance  wind-gust_count    pp_feat  \
# 0               3.8              839.84             54.0   0.319492
# 1               1.7               12.11             44.0  23.304216
# 2               6.8              162.34             67.0  14.333042
# 3               8.5              355.46             70.0   6.403240
# 4               2.2               46.19             92.0   0.000000
#
#    Population_Not_Home_Log  Population_Staying_Home_Log
# 0                 5.698497                     5.248393
# 1                 5.882986                     5.451929
# 2                 5.989536                     5.429319
# 3                 5.611901                     5.282137
# 4                 5.560257                     5.022168
#
# [5 rows x 73 columns]

# %%
df4 =df2.copy()

# %%
df4.drop(columns=['County'], inplace=True)

# %%
df4.head()
# Out:
#    Population Staying at Home  Population Not Staying at Home  mil_miles  \
# 0                      177171                          499456  19.038463
# 1                      283093                          763811  29.295609
# 2                      268732                          976194  27.286079
# 3                      191486                          409167  12.961132
# 4                      105237                          363293  12.640954
#
#    past_week_avg_miles   latitude   longitude  o3_min  o3_max  o3_median  \
# 0                  0.0  35.107209 -106.617209    10.4    26.4       20.8
# 1                  0.0  33.760109  -84.402826     1.6    21.6        8.0
# 2                  0.0  30.283333  -97.750641     1.6    15.2       11.2
# 3                  0.0  39.305833  -76.610417     4.0    28.1       19.2
# 4                  0.0  43.604545 -116.202424     1.6    28.1       17.4
#
#    o3_variance  ...  pm10_variance  pm10_count  wind-gust_min  wind-gust_max  \
# 0        98.44  ...        5303.29        48.0            0.3           27.3
# 1       379.32  ...         280.83        23.0            0.1            4.5
# 2       104.74  ...            NaN         NaN            0.2           14.0
# 3       548.92  ...          74.76        24.0            0.1           24.0
# 4       628.14  ...         170.86        47.0            0.1           11.3
#
#    wind-gust_median  wind-gust_variance  wind-gust_count    pp_feat  \
# 0               3.8              839.84             54.0   0.319492
# 1               1.7               12.11             44.0  23.304216
# 2               6.8              162.34             67.0  14.333042
# 3               8.5              355.46             70.0   6.403240
# 4               2.2               46.19             92.0   0.000000
#
#    Population_Not_Home_Log  Population_Staying_Home_Log
# 0                 5.698497                     5.248393
# 1                 5.882986                     5.451929
# 2                 5.989536                     5.429319
# 3                 5.611901                     5.282137
# 4                 5.560257                     5.022168
#
# [5 rows x 69 columns]

# %%
plot_clusters(df4, cluster.KMeans, (), {'n_clusters':0})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\dvisi\PycharmProjects\2023-02-DSI-WE\Jose_Flores\Capstone_2\main.ipynb Cell 63 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> plot_clusters(df4, cluster.KMeans, (), {'n_clusters':0})
#
# c:\Users\dvisi\PycharmProjects\2023-02-DSI-WE\Jose_Flores\Capstone_2\main.ipynb Cell 63 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> def plot_clusters(data, algorithm, args, kwds):
#       <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#Y114sZmlsZQ%3D%3D?line=1'>2</a>     start_time = time.time()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#Y114sZmlsZQ%3D%3D?line=2'>3</a>     labels = algorithm(*args, **kwds).fit_predict(data)
#       <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#Y114sZmlsZQ%3D%3D?line=3'>4</a>     end_time = time.time()
#       <a href='vscode-notebook-cell:/c%3A/Users/dvisi/PycharmProjects/2023-02-DSI-WE/Jose_Flores/Capstone_2/main.ipynb#Y114sZmlsZQ%3D%3D?line=4'>5</a>     palette = sns.color_palette('deep', np.unique(labels).max() + 1)
#
# File c:\Users\dvisi\anaconda3\envs\dojo-env\lib\site-packages\sklearn\cluster\_kmeans.py:996, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#     973 def fit_predict(self, X, y=None, sample_weight=None):
#     974     """Compute cluster centers and predict cluster index for each sample.
#     975
#     976     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#     994         Index of the cluster each sample belongs to.
#     995     """
# --> 996     return self.fit(X, sample_weight=sample_weight).labels_
#
# File c:\Users\dvisi\anaconda3\envs\dojo-env\lib\site-packages\sklearn\cluster\_kmeans.py:1367, in KMeans.fit(self, X, y, sample_weight)
#    1341 def fit(self, X, y=None, sample_weight=None):
#    1342     """Compute k-means clustering.
#    1343
#    1344     Parameters
#    (...)
#    1365         Fitted estimator.
#    1366     """
# -> 1367     X = self._validate_data(
#    1368         X,
#    1369         accept_sparse="csr",
#    1370         dtype=[np.float64, np.float32],
#    1371         order="C",
#    1372         copy=self.copy_x,
#    1373         accept_large_sparse=False,
#    1374     )
#    1376     self._check_params(X)
#    1377     random_state = check_random_state(self.random_state)
#
# File c:\Users\dvisi\anaconda3\envs\dojo-env\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File c:\Users\dvisi\anaconda3\envs\dojo-env\lib\site-packages\sklearn\utils\validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File c:\Users\dvisi\anaconda3\envs\dojo-env\lib\site-packages\sklearn\utils\validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.
# KMeans does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
