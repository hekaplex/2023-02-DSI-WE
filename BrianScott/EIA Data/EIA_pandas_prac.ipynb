# %%
import pandas as pd
import numpy as np

csv_path = 'eia2022.csv'

eia_data = pd.read_csv(csv_path, low_memory=False)
eia_data['value'] = pd.to_numeric(eia_data['value'], errors='coerce')

# %%
eia_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2503256 entries, 0 to 2503255
# Data columns (total 7 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   period           object
#  1   respondent       object
#  2   respondent-name  object
#  3   type             object
#  4   type-name        object
#  5   value            float64
#  6   value-units      object
# dtypes: float64(1), object(6)
# memory usage: 133.7+ MB

# %%
eia_data.head(10)
# Out:
#           period respondent
# 0  2023-01-01T00        JEA  \
# 1  2023-01-01T00       SCEG
# 2  2023-01-01T00       SCEG
# 3  2023-01-01T00       SCEG
# 4  2023-01-01T00       FMPP
# 5  2023-01-01T00       SCEG
# 6  2023-01-01T00        HST
# 7  2023-01-01T00        JEA
# 8  2023-01-01T00       WAUW
# 9  2023-01-01T00       PSEI
#
#                                      respondent-name type
# 0                                                JEA   TI  \
# 1               Dominion Energy South Carolina, Inc.   DF
# 2               Dominion Energy South Carolina, Inc.   TI
# 3               Dominion Energy South Carolina, Inc.    D
# 4                       Florida Municipal Power Pool   TI
# 5               Dominion Energy South Carolina, Inc.   NG
# 6                                  City of Homestead    D
# 7                                                JEA    D
# 8  Western Area Power Administration - Upper Grea...    D
# 9                           Puget Sound Energy, Inc.    D
#
#                    type-name value    value-units
# 0          Total interchange  -300  megawatthours
# 1  Day-ahead demand forecast  2450  megawatthours
# 2          Total interchange   255  megawatthours
# 3                     Demand  2500  megawatthours
# 4          Total interchange   -42  megawatthours
# 5             Net generation  2755  megawatthours
# 6                     Demand    87  megawatthours
# 7                     Demand  1408  megawatthours
# 8                     Demand   109  megawatthours
# 9                     Demand  3282  megawatthours
