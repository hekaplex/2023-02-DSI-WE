# %% [markdown]
# #### Data Science Project - Machine Leaning.
#
# Capstone:
# Y = (Predicted) Stroke.
# X = (Multiple Factors) Diabetes, Heart Dissease, High Blood Pressure, High Cholesterol, and Obesity
#
# ML Algorithms = Will be focusing on supervised (multiple linear regression) numeric values.
#
# ####### Data provided by https://data.cdc.gov/
# Dataset Files:  Diabetes.cvs
# Data Measure: 500 Cities: Diagnosed diabetes among adults aged >=18 years
#
# First feature:  Number of diabetes population.

# %%
#importing the libraies
import numpy as np
import matplotlib.pyplot as plt
 
import pandas as pd
import seaborn as sns
import math 
#%metplotlib inline #

# %%
# Reading, loading  datasets. 

df = pd.read_csv("500_Cities__High_blood_pressure.csv" )

# %%
df.shape
# Out:
# (29006, 24)

# %%
df.head().T
# Out:
#                                                                            0  \
# Year                                                                    2017
# StateAbbr                                                                 AZ
# StateDesc                                                            Arizona
# CityName                                                              Tucson
# GeographicLevel                                                 Census Tract
# DataSource                                                             BRFSS
# Category                                                     Health Outcomes
# UniqueID                                                 0477000-04019004710
# Measure                     High blood pressure among adults aged >=18 Years
# Data_Value_Unit                                                            %
# DataValueTypeID                                                       CrdPrv
# Data_Value_Type                                             Crude prevalence
# Data_Value                                                              21.9
# Low_Confidence_Limit                                                    20.9
# High_Confidence_Limit                                                   22.9
# Data_Value_Footnote_Symbol                                               NaN
# Data_Value_Footnote                                                      NaN
# PopulationCount                                                        2,138
# GeoLocation                                  (32.2851840496, -110.941404638)
# CategoryID                                                           HLTHOUT
# MeasureId                                                             BPHIGH
# CityFIPS                                                            477000.0
# TractFIPS                                                       4019004710.0
# Short_Question_Text                                      High Blood Pressure
#
#                                                                            1  \
# Year                                                                    2017
# StateAbbr                                                                 AR
# StateDesc                                                           Arkansas
# CityName                                                           Jonesboro
# GeographicLevel                                                         City
# DataSource                                                             BRFSS
# Category                                                     Health Outcomes
# UniqueID                                                             0535710
# Measure                     High blood pressure among adults aged >=18 Years
# Data_Value_Unit                                                            %
# DataValueTypeID                                                       CrdPrv
# Data_Value_Type                                             Crude prevalence
# Data_Value                                                              33.3
# Low_Confidence_Limit                                                    32.9
# High_Confidence_Limit                                                   33.6
# Data_Value_Footnote_Symbol                                               NaN
# Data_Value_Footnote                                                      NaN
# PopulationCount                                                       67,263
# GeoLocation                                  (35.8208121538, -90.6794991686)
# CategoryID                                                           HLTHOUT
# MeasureId                                                             BPHIGH
# CityFIPS                                                            535710.0
# TractFIPS                                                                NaN
# Short_Question_Text                                      High Blood Pressure
#
#                                                                            2  \
# Year                                                                    2017
# StateAbbr                                                                 CA
# StateDesc                                                         California
# CityName                                                           Fairfield
# GeographicLevel                                                         City
# DataSource                                                             BRFSS
# Category                                                     Health Outcomes
# UniqueID                                                             0623182
# Measure                     High blood pressure among adults aged >=18 Years
# Data_Value_Unit                                                            %
# DataValueTypeID                                                       CrdPrv
# Data_Value_Type                                             Crude prevalence
# Data_Value                                                              28.7
# Low_Confidence_Limit                                                    28.5
# High_Confidence_Limit                                                   28.9
# Data_Value_Footnote_Symbol                                               NaN
# Data_Value_Footnote                                                      NaN
# PopulationCount                                                      105,321
# GeoLocation                                  (38.2558446343, -122.039303253)
# CategoryID                                                           HLTHOUT
# MeasureId                                                             BPHIGH
# CityFIPS                                                            623182.0
# TractFIPS                                                                NaN
# Short_Question_Text                                      High Blood Pressure
#
#                                                                            3  \
# Year                                                                    2017
# StateAbbr                                                                 CA
# StateDesc                                                         California
# CityName                                                             Menifee
# GeographicLevel                                                 Census Tract
# DataSource                                                             BRFSS
# Category                                                     Health Outcomes
# UniqueID                                                 0646842-06065042740
# Measure                     High blood pressure among adults aged >=18 Years
# Data_Value_Unit                                                            %
# DataValueTypeID                                                       CrdPrv
# Data_Value_Type                                             Crude prevalence
# Data_Value                                                              54.1
# Low_Confidence_Limit                                                    51.7
# High_Confidence_Limit                                                   56.0
# Data_Value_Footnote_Symbol                                               NaN
# Data_Value_Footnote                                                      NaN
# PopulationCount                                                        2,017
# GeoLocation                                  (33.7251014333, -117.197756929)
# CategoryID                                                           HLTHOUT
# MeasureId                                                             BPHIGH
# CityFIPS                                                            646842.0
# TractFIPS                                                       6065042740.0
# Short_Question_Text                                      High Blood Pressure
#
#                                                                            4
# Year                                                                    2017
# StateAbbr                                                                 CA
# StateDesc                                                         California
# CityName                                                            Palmdale
# GeographicLevel                                                         City
# DataSource                                                             BRFSS
# Category                                                     Health Outcomes
# UniqueID                                                             0655156
# Measure                     High blood pressure among adults aged >=18 Years
# Data_Value_Unit                                                            %
# DataValueTypeID                                                    AgeAdjPrv
# Data_Value_Type                                      Age-adjusted prevalence
# Data_Value                                                              28.8
# Low_Confidence_Limit                                                    28.7
# High_Confidence_Limit                                                   29.0
# Data_Value_Footnote_Symbol                                               NaN
# Data_Value_Footnote                                                      NaN
# PopulationCount                                                      152,750
# GeoLocation                                  (34.5944899803, -118.105772328)
# CategoryID                                                           HLTHOUT
# MeasureId                                                             BPHIGH
# CityFIPS                                                            655156.0
# TractFIPS                                                                NaN
# Short_Question_Text                                      High Blood Pressure

# %%
New_df = df.drop(columns=["Year", "StateDesc",  "GeoLocation", "GeographicLevel" ,"DataSource", "Category", "UniqueID", "Measure", "Data_Value_Unit", "DataValueTypeID", \
"Low_Confidence_Limit", "High_Confidence_Limit", "Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Data_Value_Footnote_Symbol","CategoryID", "TractFIPS", "Short_Question_Text", "DataSource", \
"Category", "UniqueID", "Measure", "Data_Value_Unit","Data_Value",  "DataValueTypeID", "Data_Value_Footnote_Symbol", "MeasureId", "Data_Value_Footnote_Symbol", \
"CategoryID", "TractFIPS","CityFIPS" ,"Short_Question_Text"])

# %%
New_df.shape
# Out:
# (29006, 4)

# %%
New_df.head()
# Out:
#   StateAbbr   CityName          Data_Value_Type PopulationCount
# 0        AZ     Tucson         Crude prevalence           2,138
# 1        AR  Jonesboro         Crude prevalence          67,263
# 2        CA  Fairfield         Crude prevalence         105,321
# 3        CA    Menifee         Crude prevalence           2,017
# 4        CA   Palmdale  Age-adjusted prevalence         152,750

# %%
New_df = New_df.rename(columns={'StateAbbr':'States', 'CityName':'City', 'Data_Value_Type':'Age-adj_preval','PopulationCount':'PopCountByMM' })

# %%
New_df.head()
# Out:
#   States       City           Age-adj_preval PopCountByMM
# 0     AZ     Tucson         Crude prevalence        2,138
# 1     AR  Jonesboro         Crude prevalence       67,263
# 2     CA  Fairfield         Crude prevalence      105,321
# 3     CA    Menifee         Crude prevalence        2,017
# 4     CA   Palmdale  Age-adjusted prevalence      152,750

# %%
df_hbp = New_df.query('`Age-adj_preval` == "Age-adjusted prevalence"') 
df_hbp.to_csv("NewDataHighBloodPressure.csv")

# %%
# Check for NULL/Missing values
print(df_hbp.isna().sum())
# Out:
# States            0
# City              1
# Age-adj_preval    0
# PopCountByMM      0
# dtype: int64

# %%
# Verify for NULL and dup. values
# No NULL values are found.
df_hbp.loc[df_hbp.duplicated()]
# Out:
# Empty DataFrame
# Columns: [States, City, Age-adj_preval, PopCountByMM]
# Index: []

# %%
#count number of records by each state.
df_hbp['States'].value_counts()
# Out:
# CA    121
# TX     47
# FL     33
# IL     18
# MI     16
# NC     14
# WA     14
# CO     14
# MA     13
# AZ     12
# GA     11
# IN     11
# VA     11
# NY      9
# UT      9
# NJ      9
# OH      9
# OR      8
# CT      8
# MO      8
# WI      7
# MN      7
# PA      7
# KS      6
# TN      6
# IA      6
# LA      6
# AL      6
# OK      6
# SC      5
# NV      5
# AR      5
# NM      4
# RI      4
# ID      3
# KY      2
# MT      2
# NE      2
# MS      2
# SD      2
# NH      2
# VT      1
# US      1
# WV      1
# ND      1
# AK      1
# DE      1
# DC      1
# HI      1
# ME      1
# MD      1
# WY      1
# Name: States, dtype: int64

# %%
df_hbp.query('`States` == "CA"')
# Out:
#      States         City           Age-adj_preval PopCountByMM
# 4        CA     Palmdale  Age-adjusted prevalence      152,750
# 877      CA      Anaheim  Age-adjusted prevalence      336,265
# 962      CA      Antioch  Age-adjusted prevalence      102,372
# 997      CA     Alhambra  Age-adjusted prevalence       83,089
# 1098     CA      Alameda  Age-adjusted prevalence       73,812
# ...     ...          ...                      ...          ...
# 7207     CA      Visalia  Age-adjusted prevalence      124,442
# 7448     CA     Whittier  Age-adjusted prevalence       85,331
# 7465     CA        Vista  Age-adjusted prevalence       93,834
# 7490     CA  Victorville  Age-adjusted prevalence      115,903
# 7737     CA  West Covina  Age-adjusted prevalence      106,098
#
# [121 rows x 4 columns]

# %%
df_hbp.index
# Out:
# Int64Index([    4,     6,    20,    21,    22,    30,   170,   220,   297,
#               467,
#             ...
#             28613, 28693, 28706, 28874, 28892, 28898, 28931, 28943, 28944,
#             28949],
#            dtype='int64', length=501)
