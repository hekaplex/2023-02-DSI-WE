# %% [markdown]
# #### Data Science Project - Machine Leaning.
# Predicating Stroke Population based on 5 different factors.
#
# Factors:
# Diabetes, Heart Dissease, High Blood Pressure, High Cholesterol, and Obesity.
#
# ####### Data provided by https://data.cdc.gov/
# Dataset Files:  Diabetes.cvs
# Data Measure: 500 Cities: Diagnosed diabetes among adults aged >=18 years
#
# Capstone:
# Y = (Predicted) Stroke.
# X = (Multiple Factors) Diabetes, Heart Dissease, High Blood Pressure, High Cholesterol, and Obesity
#
# ML Algorithms = Will be focusing on supervised (multiple linear regression) numeric values.
#
# Data type/Metrix:
# Quantitative/Nemerical Data (Continuous)
# Discrete data - Data with final set of vlaues which can be categorized.
# Continuous - take any numerical value within a range.
#
#
#
# Data Wranging Process:
# *** Determine the issue or problems to be resolved.
# 0. Getting your data from internal or external sources.
# *** Collecting ranges of data.
#    *** verifying and due dilligence to make sure the data is valid( check and recheck
#        not to miss anything).
#    *** Detecting fairness
#    *** Elimating and look for bias or outliers because it will effects the outcome.
# 1. installing and importing the required libraies.
# 2. Reading the datasets.
# 3. Examing the datasets.
# 4. Data Danling, cleaning, formating and documenting the process.
#  - shaping the data to answer specific questions:
#     Removing unwanted data.
#     Renaming data - columns
#     Verifying and changing the data type.
#     Combing the data or creating new data - rows or columns or combine dataframe.
# 5. Take a look or snap-shoot of your data (Summary) using histogram().
# 6. Run Statistic of the data.
# 7. Using clean data to create your model - test, validate ..ect.
#    *** verifying and examing the behavior of the outcome.
#    *** re-adjust if needed.
# 8. Create visualizations and telling a story.
# 9. Sharing data with your team, other groups or stakeholders.

# %%
# importing the libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math 
# %metplotlib inline #

# %%
# %pip install scikit-learn  --upgrade --force
#from sklearn.linear_model import LinearRegression
#from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Reading, loading  datasets. 

df = pd.read_csv("500_Cities__Coronary_heart_disease.csv" )

# %%
df.shape
# Out:
# (29006, 24)

# %%
df.head().T
# Out:
#                                                                           0  \
# Year                                                                   2017
# StateAbbr                                                                TX
# StateDesc                                                             Texas
# CityName                                                            Abilene
# GeographicLevel                                                Census Tract
# DataSource                                                            BRFSS
# Category                                                    Health Outcomes
# UniqueID                                                4801000-48441012200
# Measure                     Diagnosed diabetes among adults aged >=18 Years
# Data_Value_Unit                                                           %
# DataValueTypeID                                                      CrdPrv
# ...

# %%
df.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'CityName', 'GeographicLevel',
#        'DataSource', 'Category', 'UniqueID', 'Measure', 'Data_Value_Unit',
#        'DataValueTypeID', 'Data_Value_Type', 'Data_Value',
#        'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'PopulationCount',
#        'GeoLocation', 'CategoryID', 'MeasureId', 'CityFIPS', 'TractFIPS',
#        'Short_Question_Text'],
#       dtype='object')

# %%
New_df = df.drop(columns=['Year','StateDesc', 'GeographicLevel','DataSource', 'Category', 'UniqueID', \
    'Data_Value_Unit','DataValueTypeID',  'Measure', 'Data_Value_Footnote_Symbol','Data_Value_Footnote', \
    'GeoLocation', 'CategoryID', 'MeasureId', 'CityFIPS', 'TractFIPS','Short_Question_Text'])

# %%
# New df after dropping unwanted data.
New_df
# Out:
#       StateAbbr CityName          Data_Value_Type  Data_Value  \
# 0            TX  Abilene         Crude prevalence        12.2
# 1            TX  Abilene         Crude prevalence        10.8
# 2            TX  Abilene         Crude prevalence         9.9
# 3            TX  Abilene         Crude prevalence        14.7
# 4            TX  Abilene         Crude prevalence         8.1
# ...         ...      ...                      ...         ...
# 29001        AZ     Yuma         Crude prevalence        16.4
# 29002        AZ     Yuma         Crude prevalence         NaN
# 29003        AZ     Yuma         Crude prevalence        12.2
# 29004        US      NaN         Crude prevalence        10.8
# 29005        US      NaN  Age-adjusted prevalence         9.6
#
#        Low_Confidence_Limit  High_Confidence_Limit PopulationCount
# 0                      11.5                   12.9           2,229
# 1                       9.8                   11.7           7,647
# ...

# %%
# Verifying data/columns.
New_df.columns
# Out:
# Index(['StateAbbr', 'CityName', 'Data_Value_Type', 'Data_Value',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'PopulationCount'],
#       dtype='object')

# %%
New_df = New_df.rename(columns={'StateAbbr':'States', 'CityName':'City', 'Data_Value_Type':'AgeAdj_Prevalence',  'Data_Value':'Diabetic', 'High_Confidence_Limit':'Pre_Diabetic','Low_Confidence_Limit':'Low_Risk', 'PopulationCount':'Pop_Count' })

# %%
New_df
# Out:
#       States     City        AgeAdj_Prevalence  Diabetic  Low_Risk  \
# 0         TX  Abilene         Crude prevalence      12.2      11.5
# 1         TX  Abilene         Crude prevalence      10.8       9.8
# 2         TX  Abilene         Crude prevalence       9.9       9.4
# 3         TX  Abilene         Crude prevalence      14.7      14.0
# 4         TX  Abilene         Crude prevalence       8.1       7.7
# ...      ...      ...                      ...       ...       ...
# 29001     AZ     Yuma         Crude prevalence      16.4      15.6
# 29002     AZ     Yuma         Crude prevalence       NaN       NaN
# 29003     AZ     Yuma         Crude prevalence      12.2      11.5
# 29004     US      NaN         Crude prevalence      10.8      10.6
# 29005     US      NaN  Age-adjusted prevalence       9.6       9.4
#
#        Pre_Diabetic    Pop_Count
# 0              12.9        2,229
# 1              11.7        7,647
# 2              10.5        2,684
# ...

# %%
New_df.columns
# Out:
# Index(['States', 'City', 'AgeAdj_Prevalence', 'Diabetic', 'Low_Risk',
#        'Pre_Diabetic', 'Pop_Count'],
#       dtype='object')

# %%
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29006 entries, 0 to 29005
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   States             29006 non-null  object
#  1   City               29004 non-null  object
#  2   AgeAdj_Prevalence  29006 non-null  object
#  3   Diabetic           28212 non-null  float64
#  4   Pre_Diabetic       28212 non-null  float64
#  5   Pop_Count          29006 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 1.3+ MB

# %%
# Checking for NaN/NULL and count them.
New_df.isna().sum()
# Out:
# States                 0
# City                   2
# AgeAdj_Prevalence      0
# Diabetic             794
# Low_Risk             794
# Pre_Diabetic         794
# Pop_Count              0
# dtype: int64

# %%
# Checking for NULL, NaN values

New_df.query("Pre_Diabetic.isna()")
# Out:
#       States         City AgeAdj_Prevalence  Diabetic  Low_Risk  Pre_Diabetic  \
# 9         TX      Abilene  Crude prevalence       NaN       NaN           NaN
# 68        OH        Akron  Crude prevalence       NaN       NaN           NaN
# 99        OH        Akron  Crude prevalence       NaN       NaN           NaN
# 191       NM  Albuquerque  Crude prevalence       NaN       NaN           NaN
# 214       NM  Albuquerque  Crude prevalence       NaN       NaN           NaN
# ...      ...          ...               ...       ...       ...           ...
# 28878     WA       Yakima  Crude prevalence       NaN       NaN           NaN
# 28952     OH   Youngstown  Crude prevalence       NaN       NaN           NaN
# 28996     AZ         Yuma  Crude prevalence       NaN       NaN           NaN
# 29000     AZ         Yuma  Crude prevalence       NaN       NaN           NaN
# 29002     AZ         Yuma  Crude prevalence       NaN       NaN           NaN
#
#       Pop_Count
# ...

# %%
New_df.columns
# Out:
# Index(['States', 'City', 'AgeAdj_Prevalence', 'Diabetic', 'Low_Risk',
#        'Pre_Diabetic', 'Pop_Count'],
#       dtype='object')

# %%
#Dropping NaN values. Make sure to select every columns in the dataframe.
New_df[[ 'States', 'City', 'AgeAdj_Prevalence', 'Diabetic', 'Low_Risk', 'Pre_Diabetic',
'Pop_Count' ]].dropna()
# Out:
#       States     City AgeAdj_Prevalence  Diabetic  Low_Risk  Pre_Diabetic  \
# 0         TX  Abilene  Crude prevalence      12.2      11.5          12.9
# 1         TX  Abilene  Crude prevalence      10.8       9.8          11.7
# 2         TX  Abilene  Crude prevalence       9.9       9.4          10.5
# 3         TX  Abilene  Crude prevalence      14.7      14.0          15.4
# 4         TX  Abilene  Crude prevalence       8.1       7.7           8.4
# ...      ...      ...               ...       ...       ...           ...
# 28997     AZ     Yuma  Crude prevalence      11.9      11.2          12.6
# 28998     AZ     Yuma  Crude prevalence       7.4       7.0           7.9
# 28999     AZ     Yuma  Crude prevalence      10.3       9.7          10.8
# 29001     AZ     Yuma  Crude prevalence      16.4      15.6          17.1
# 29003     AZ     Yuma  Crude prevalence      12.2      11.5          12.9
#
#       Pop_Count
# 0         2,229
# 1         7,647
# 2         2,684
# ...

# %%
# Double check on the NaN
New_df.query("Diabetic.isna()")
New_df
# Out:
#       States     City        AgeAdj_Prevalence  Diabetic  Low_Risk  \
# 0         TX  Abilene         Crude prevalence      12.2      11.5
# 1         TX  Abilene         Crude prevalence      10.8       9.8
# 2         TX  Abilene         Crude prevalence       9.9       9.4
# 3         TX  Abilene         Crude prevalence      14.7      14.0
# 4         TX  Abilene         Crude prevalence       8.1       7.7
# ...      ...      ...                      ...       ...       ...
# 29001     AZ     Yuma         Crude prevalence      16.4      15.6
# 29002     AZ     Yuma         Crude prevalence       NaN       NaN
# 29003     AZ     Yuma         Crude prevalence      12.2      11.5
# 29004     US      NaN         Crude prevalence      10.8      10.6
# 29005     US      NaN  Age-adjusted prevalence       9.6       9.4
#
#        Pre_Diabetic    Pop_Count
# 0              12.9        2,229
# 1              11.7        7,647
# 2              10.5        2,684
# ...

# %%
#Double check on the NaN NULL
New_df.isna().sum()
# Out:
# States                 0
# City                   2
# AgeAdj_Prevalence      0
# Diabetic             794
# Low_Risk             794
# Pre_Diabetic         794
# Pop_Count              0
# dtype: int64

# %%
#Verify data type. Need to change pop_count to int.
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29006 entries, 0 to 29005
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   States             29006 non-null  object
#  1   City               29004 non-null  object
#  2   AgeAdj_Prevalence  29006 non-null  object
#  3   Diabetic           28212 non-null  float64
#  4   Low_Risk           28212 non-null  float64
#  5   Pre_Diabetic       28212 non-null  float64
#  6   Pop_Count          29006 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 1.5+ MB

# %%
#Change data type:
# removing the "," from the PopCountByMM values and replace it with nothing than change it from object type to int. 
New_df["Pop_Count"] = New_df["Pop_Count"].str.replace(',','').astype(int)

# %%
#Verify data type again.
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29006 entries, 0 to 29005
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   States             29006 non-null  object
#  1   City               29004 non-null  object
#  2   AgeAdj_Prevalence  29006 non-null  object
#  3   Diabetic           28212 non-null  float64
#  4   Pre_Diabetic       28212 non-null  float64
#  5   Pop_Count          29006 non-null  int32
# dtypes: float64(2), int32(1), object(3)
# memory usage: 1.2+ MB

# %%
#New_df.sort_values(["States"])
New_df.sort_values(["States", "City"], ascending=[1,0])
# Out:
#      States       City        AgeAdj_Prevalence  Diabetic  Low_Risk  \
# 565      AK  Anchorage         Crude prevalence       7.4       6.9
# 566      AK  Anchorage         Crude prevalence       8.9       8.3
# 567      AK  Anchorage         Crude prevalence       8.2       7.8
# 568      AK  Anchorage         Crude prevalence       6.1       5.4
# 569      AK  Anchorage         Crude prevalence       7.3       6.7
# ...     ...        ...                      ...       ...       ...
# 3782     WY   Cheyenne  Age-adjusted prevalence       8.2       8.1
# 3783     WY   Cheyenne         Crude prevalence       7.4       6.9
# 3784     WY   Cheyenne         Crude prevalence       8.9       8.1
# 3785     WY   Cheyenne         Crude prevalence       9.1       8.3
# 3786     WY   Cheyenne         Crude prevalence       8.3       7.8
#
#       Pre_Diabetic  Pop_Count
# 565            7.8       4993
# 566            9.6        940
# 567            8.6       1988
# ...

# %%
# Filter and selecting only Age-adjusted prevalence from the dataset.
df_CorHartDis_01 = New_df.query('`AgeAdj_Prevalence` == "Age-adjusted prevalence"')
CorHartDis_01

# This code will do the same
#df_diab_01.loc[df_diab_01.duplicated(subset=['States'])]

# %%
# Count dup values.
# df_diab_01.loc[df_diab_01.duplicated(subset=['States'])]
CorHartDis_01.loc[CorHartDis_01.duplicated(subset=['States'])].count()
# Out:
# States               449
# City                 449
# AgeAdj_Prevalence    449
# Diabetic             449
# Low_Risk             449
# Pre_Diabetic         449
# Pop_Count            449
# dtype: int64

# %%
# Verify vales for TX/city based on "Age-adjusted prevalence"
CorHartDis_01 = CorHartDis_01.query('`States` == "TX"')
CorHartDis_01

# %%
# Concat State and City name into a NEW column called StateAndCity:
CorHartDis_01 ['StateAndCity'] = CorHartDis_01['States'] + '_' + CorHartDis_01['City']
CorHartDis_01

# %%
# DROPPING the states and city columns after concat:
CorHartDis_01 = CorHartDis_01.drop(columns=['States','City' ])
CorHartDis_01

# %%
CorHartDis_01.columns

# %%
#Reorganize the columns
#Create a new list and re-order the columns.
New_cols = ['StateAndCity','Diabetic', 'Pre_Diabetic', 'Low_Risk', 'Pop_Count']
CorHartDis_01 = CorHartDis_01[New_cols]
CorHartDis_01

CorHartDis_01.to_csv("New_Coronary_heart_disease_X01.csv")

# %%
CorHartDis_01.describe().T
# Out:
#               count           mean            std      min      25%       50%  \
# Diabetic       47.0      12.140426       2.549054      8.0     10.4      12.1
# Pre_Diabetic   47.0      12.287234       2.565458      8.2     10.5      12.2
# Pop_Count      47.0  262244.468085  387270.025670  67358.0  93528.5  118296.0
#
#                     75%        max
# Diabetic          13.50       18.3
# Pre_Diabetic      13.55       18.4
# Pop_Count     221583.00  2099451.0
