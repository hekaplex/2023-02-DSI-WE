# %% [markdown]
# #### Data Science Project - Machine Leaning.
#
# Capstone:
# Y = (Predicted) Stroke.
# X = (Multiple Factors) Diabetes, Heart Dissease, High Blood Pressure, High Cholesterol, and Obesity
#
# ML Algorithms = Will be focusing on supervised (multiple linear regression) numeric values.
#
# ####### Data provided by https://data.cdc.gov/
# Dataset Files:  Diabetes.cvs
# Data Measure: 500 Cities: Diagnosed diabetes among adults aged >=18 years
#
# First feature:  Number of diabetes population.

# %%
# importing the libraies
import numpy as np
import matplotlib.pyplot as plt
 
import pandas as pd
import seaborn as sns
import math 
#%metplotlib inline #

# %%
# Reading, loading  datasets. 

df = pd.read_csv("500_Cities__High_cholesterol.csv" )

# %%
df.shape
# Out:
# (29006, 24)

# %%
df.head().T
# Out:
#                                                                             0  \
# Year                                                                     2017
# StateAbbr                                                                  PA
# StateDesc                                                        Pennsylvania
# CityName                                                         Philadelphia
# GeographicLevel                                                  Census Tract
# DataSource                                                              BRFSS
# Category                                                      Health Outcomes
# UniqueID                                                  4260000-42101011800
# Measure                     High cholesterol among adults aged >=18 Years ...
# Data_Value_Unit                                                             %
# DataValueTypeID                                                        CrdPrv
# Data_Value_Type                                              Crude prevalence
# Data_Value                                                               34.1
# Low_Confidence_Limit                                                     33.1
# High_Confidence_Limit                                                    35.2
# Data_Value_Footnote_Symbol                                                NaN
# Data_Value_Footnote                                                       NaN
# PopulationCount                                                         5,621
# GeoLocation                                   (39.9852890218, -75.2357396856)
# CategoryID                                                            HLTHOUT
# MeasureId                                                            HIGHCHOL
# CityFIPS                                                            4260000.0
# TractFIPS                                                       42101011800.0
# Short_Question_Text                                          High Cholesterol
#
#                                                                             1  \
# Year                                                                     2017
# StateAbbr                                                                  NC
# StateDesc                                                       North Carolin
# CityName                                                                 Cary
# GeographicLevel                                                  Census Tract
# DataSource                                                              BRFSS
# Category                                                      Health Outcomes
# UniqueID                                                  3710740-37183053601
# Measure                     High cholesterol among adults aged >=18 Years ...
# Data_Value_Unit                                                             %
# DataValueTypeID                                                        CrdPrv
# Data_Value_Type                                              Crude prevalence
# Data_Value                                                               21.8
# Low_Confidence_Limit                                                     21.2
# High_Confidence_Limit                                                    22.4
# Data_Value_Footnote_Symbol                                                NaN
# Data_Value_Footnote                                                       NaN
# PopulationCount                                                         5,208
# GeoLocation                                   (35.8367740061, -78.8996374156)
# CategoryID                                                            HLTHOUT
# MeasureId                                                            HIGHCHOL
# CityFIPS                                                            3710740.0
# TractFIPS                                                       37183053601.0
# Short_Question_Text                                          High Cholesterol
#
#                                                                             2  \
# Year                                                                     2017
# StateAbbr                                                                  NC
# StateDesc                                                       North Carolin
# CityName                                                            Charlotte
# GeographicLevel                                                  Census Tract
# DataSource                                                              BRFSS
# Category                                                      Health Outcomes
# UniqueID                                                  3712000-37119003105
# Measure                     High cholesterol among adults aged >=18 Years ...
# Data_Value_Unit                                                             %
# DataValueTypeID                                                        CrdPrv
# Data_Value_Type                                              Crude prevalence
# Data_Value                                                               36.7
# Low_Confidence_Limit                                                     35.7
# High_Confidence_Limit                                                    37.7
# Data_Value_Footnote_Symbol                                                NaN
# Data_Value_Footnote                                                       NaN
# PopulationCount                                                         3,480
# GeoLocation                                   (35.1322746827, -80.8580889521)
# CategoryID                                                            HLTHOUT
# MeasureId                                                            HIGHCHOL
# CityFIPS                                                            3712000.0
# TractFIPS                                                       37119003105.0
# Short_Question_Text                                          High Cholesterol
#
#                                                                             3  \
# Year                                                                     2017
# StateAbbr                                                                  NC
# StateDesc                                                       North Carolin
# CityName                                                            Charlotte
# GeographicLevel                                                  Census Tract
# DataSource                                                              BRFSS
# Category                                                      Health Outcomes
# UniqueID                                                  3712000-37119005524
# Measure                     High cholesterol among adults aged >=18 Years ...
# Data_Value_Unit                                                             %
# DataValueTypeID                                                        CrdPrv
# Data_Value_Type                                              Crude prevalence
# Data_Value                                                               27.1
# Low_Confidence_Limit                                                     26.5
# High_Confidence_Limit                                                    27.8
# Data_Value_Footnote_Symbol                                                NaN
# Data_Value_Footnote                                                       NaN
# PopulationCount                                                         8,078
# GeoLocation                                   (35.2975067975, -80.7785615388)
# CategoryID                                                            HLTHOUT
# MeasureId                                                            HIGHCHOL
# CityFIPS                                                            3712000.0
# TractFIPS                                                       37119005524.0
# Short_Question_Text                                          High Cholesterol
#
#                                                                             4
# Year                                                                     2017
# StateAbbr                                                                  NC
# StateDesc                                                       North Carolin
# CityName                                                              Concord
# GeographicLevel                                                  Census Tract
# DataSource                                                              BRFSS
# Category                                                      Health Outcomes
# UniqueID                                                  3714100-37025041902
# Measure                     High cholesterol among adults aged >=18 Years ...
# Data_Value_Unit                                                             %
# DataValueTypeID                                                        CrdPrv
# Data_Value_Type                                              Crude prevalence
# Data_Value                                                               35.0
# Low_Confidence_Limit                                                     34.1
# High_Confidence_Limit                                                    35.9
# Data_Value_Footnote_Symbol                                                NaN
# Data_Value_Footnote                                                       NaN
# PopulationCount                                                         4,057
# GeoLocation                                   (35.4137935177, -80.5926488583)
# CategoryID                                                            HLTHOUT
# MeasureId                                                            HIGHCHOL
# CityFIPS                                                            3714100.0
# TractFIPS                                                       37025041902.0
# Short_Question_Text                                          High Cholesterol

# %%
New_df = df.drop(columns=["Year", "StateDesc",  "GeoLocation", "GeographicLevel" ,"DataSource", "Category", "UniqueID", "Measure", "Data_Value_Unit", "DataValueTypeID", \
"Low_Confidence_Limit", "High_Confidence_Limit", "Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Data_Value_Footnote_Symbol","CategoryID", "TractFIPS", "Short_Question_Text", "DataSource", \
"Category", "UniqueID", "Measure", "Data_Value_Unit","Data_Value",  "DataValueTypeID", "Data_Value_Footnote_Symbol", "MeasureId", "Data_Value_Footnote_Symbol", \
"CategoryID", "TractFIPS","CityFIPS" ,"Short_Question_Text"])

# %%
New_df.shape
# Out:
# (29006, 4)

# %%
New_df.head()
# Out:
#   StateAbbr      CityName   Data_Value_Type PopulationCount
# 0        PA  Philadelphia  Crude prevalence           5,621
# 1        NC          Cary  Crude prevalence           5,208
# 2        NC     Charlotte  Crude prevalence           3,480
# 3        NC     Charlotte  Crude prevalence           8,078
# 4        NC       Concord  Crude prevalence           4,057

# %%
New_df = New_df.rename(columns={'StateAbbr':'States', 'CityName':'City', 'Data_Value_Type':'Age-adj_preval','PopulationCount':'PopCountByMM' })

# %%
New_df.head()
# Out:
#   States          City    Age-adj_preval PopCountByMM
# 0     PA  Philadelphia  Crude prevalence        5,621
# 1     NC          Cary  Crude prevalence        5,208
# 2     NC     Charlotte  Crude prevalence        3,480
# 3     NC     Charlotte  Crude prevalence        8,078
# 4     NC       Concord  Crude prevalence        4,057

# %%
# write to a new file.
df_highchol = New_df.query('`Age-adj_preval` == "Age-adjusted prevalence"') 
df_highchol.to_csv("NewDataHighCholesterol.csv")

# %%
# Check for NULL/Missing values
print(df_highchol.isna().sum())
# Out:
# States            0
# City              1
# Age-adj_preval    0
# PopCountByMM      0
# dtype: int64

# %%
# Verify for NULL and dup. values
# No NULL values are found.
df_highchol.loc[df_highchol.duplicated()]
# Out:
# Empty DataFrame
# Columns: [States, City, Age-adj_preval, PopCountByMM]
# Index: []

# %%
#count number of records by each state.
df_highchol['States'].value_counts()
# Out:
# CA    121
# TX     47
# FL     33
# IL     18
# MI     16
# NC     14
# WA     14
# CO     14
# MA     13
# AZ     12
# VA     11
# GA     11
# IN     11
# UT      9
# OH      9
# NY      9
# NJ      9
# CT      8
# OR      8
# MO      8
# WI      7
# MN      7
# PA      7
# KS      6
# IA      6
# LA      6
# AL      6
# TN      6
# OK      6
# SC      5
# AR      5
# NV      5
# NM      4
# RI      4
# ID      3
# KY      2
# NH      2
# NE      2
# SD      2
# MT      2
# MS      2
# VT      1
# WV      1
# US      1
# AK      1
# MD      1
# ND      1
# DE      1
# DC      1
# HI      1
# ME      1
# WY      1
# Name: States, dtype: int64

# %%
df_highchol.query('`States` == "CA"')
# Out:
#      States         City           Age-adj_preval PopCountByMM
# 652      CA     Alhambra  Age-adjusted prevalence       83,089
# 667      CA      Anaheim  Age-adjusted prevalence      336,265
# 734      CA      Antioch  Age-adjusted prevalence      102,372
# 774      CA      Alameda  Age-adjusted prevalence       73,812
# 1208     CA    Daly City  Age-adjusted prevalence      101,123
# ...     ...          ...                      ...          ...
# 7423     CA  Westminster  Age-adjusted prevalence       89,701
# 7598     CA      Visalia  Age-adjusted prevalence      124,442
# 7667     CA  West Covina  Age-adjusted prevalence      106,098
# 7676     CA        Vista  Age-adjusted prevalence       93,834
# 7729     CA     Whittier  Age-adjusted prevalence       85,331
#
# [121 rows x 4 columns]

# %%
df_highchol.index
# Out:
# Int64Index([   14,    40,    90,   190,   191,   305,   351,   544,   554,
#               652,
#             ...
#             28462, 28681, 28684, 28810, 28823, 28867, 28933, 28938, 28974,
#             29001],
#            dtype='int64', length=501)
