# %% [markdown]
# ## Advanced Pandas, Basic Python Viz and Exercise
#
# ### Exercise
# 1. Use the same dataframes you generated or copied to this directory from the 03 Exercise:
#     1. Extract of any SQL database
#     1. Imported file from your capstone work
#     1. Any other data from other exercises you have aleady used
# 1. Import into Pandas
# 1. Generate at least three additional dataframes with analytics introduced in this notebook
#     1. Melt
#     1. Pivot
#     1. Quantile
#     1. Aggregations
# 1. Build at least three  visualizations supported by Pandas directly using prior analytics from the 03 Exercise or new analytics from this exercise

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\dolly\appdata\local\r-mini~1\envs\datascience-pro-env\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\dolly\appdata\local\r-mini~1\envs\datascience-pro-env\lib\site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd

# %% [markdown]
# ## Get the data

# %% [markdown]
# ### Read a CSV file from a website into a DataFrame

# %%
import pandas as pd
url = 'https://data.cdc.gov/api/views/v6ab-adf5/rows.csv?accessType=DOWNLOAD'
mortality_data = pd.read_csv(url)

# %%
type(mortality_data)
# Out:
# pandas.core.frame.DataFrame

# %%
mortality_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        476 non-null    int64
#  1   Age Group   476 non-null    object
#  2   Death Rate  476 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.3+ KB

# %%
mortality_data.plot.line(x="Year", y = "Death Rate")
# Out:
# <Axes: xlabel='Year'>

# %%
mortality_data
# Out:
#      Year    Age Group  Death Rate
# 0    1900    1-4 Years      1983.8
# 1    1901    1-4 Years      1695.0
# 2    1902    1-4 Years      1655.7
# 3    1903    1-4 Years      1542.1
# 4    1904    1-4 Years      1591.5
# ..    ...          ...         ...
# 471  2014  15-19 Years        45.5
# 472  2015  15-19 Years        48.3
# 473  2016  15-19 Years        51.2
# 474  2017  15-19 Years        51.5
# 475  2018  15-19 Years        49.2
#
# [476 rows x 3 columns]

# %%
# SELECT [Age Group] , Year, COUNT(*) GROUP BY [Age Group], Year
mortality_data[['Age Group','Year']].value_counts()
# Out:
# Age Group    Year
# 1-4 Years    1900    1
# 15-19 Years  1975    1
#              1987    1
#              1986    1
#              1985    1
#                     ..
# 10-14 Years  1935    1
#              1934    1
#              1933    1
#              1932    1
# 5-9 Years    2018    1
# Length: 476, dtype: int64

# %% [markdown]
# ### Save and restore a DataFrame

# %%
mortality_data.to_pickle('mortality_data.pkl')

# %%
mortality_data = pd.read_pickle('mortality_data.pkl')

# %%
mortality_data.head()
# Out:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0
# 2  1902  1-4 Years      1655.7
# 3  1903  1-4 Years      1542.1
# 4  1904  1-4 Years      1591.5

# %% [markdown]
# ## Examine and clean the data

# %%
print("Index:  ", mortality_data.index)
print("Columns:", mortality_data.columns)
print("Size:   ", mortality_data.size)
print("Shape:  ", mortality_data.shape)
# Out:
# Index:   RangeIndex(start=0, stop=476, step=1)
# Columns: Index(['Year', 'Age Group', 'Death Rate'], dtype='object')
# Size:    1428
# Shape:   (476, 3)

# %% [markdown]
# ### Use the columns attribute to replace spaces with nothing

# %%
mortality_data.columns = mortality_data.columns.str.replace(' ', '')
mortality_data.columns
# Out:
# Index(['Year', 'AgeGroup', 'DeathRate'], dtype='object')

# %%
mortality_data.head()
# Out:
#    Year   AgeGroup  DeathRate
# 0  1900  1-4 Years     1983.8
# 1  1901  1-4 Years     1695.0
# 2  1902  1-4 Years     1655.7
# 3  1903  1-4 Years     1542.1
# 4  1904  1-4 Years     1591.5

# %%
mortality_data.describe().T
# Out:
#            count        mean         std     min       25%     50%       75%  \
# Year       476.0  1959.00000   34.387268  1900.0  1929.000  1959.0  1989.000
# DeathRate  476.0   192.92416  293.224216    11.4    40.575    89.5   222.575
#
#               max
# Year       2018.0
# DeathRate  1983.8

# %%
mortality_data.describe(include="O").T
# Out:
#          count unique        top freq
# AgeGroup   476      4  1-4 Years  119

# %%
len(mortality_data.DeathRate.value_counts())
# Out:
# 430

# %%
mortality_data.DeathRate.hist()
# Out:
# <Axes: >

# %%
#log10() is used to find out the Logarithmic of a number when the base is 10.
#This method returns the base 10 logarithm of a double value.
#To calculate the base-10 logarithm of the number 100, 
# you would use the formula =LOG10(100).
#This would return the value 2, as 10^2 = 100. 

import numpy as np
mortality_data['death_log']= np.log10(mortality_data['DeathRate'])
print(mortality_data['death_log'])
# Out:
# 0      3.297498
# 1      3.229170
# 2      3.218982
# 3      3.188113
# 4      3.201807
#          ...
# 471    1.658011
# 472    1.683947
# 473    1.709270
# 474    1.711807
# 475    1.691965
# Name: death_log, Length: 476, dtype: float64

# %%
mortality_data.death_log.hist(bins=50)
# Out:
# <Axes: >

# %%
mortality_data.DeathRate.hist(bins=50)
# Out:
# <Axes: >

# %%
mortality_data.describe(include='O')
# Out:
#          AgeGroup
# count         476
# unique          4
# top     1-4 Years
# freq          119

# %%
mortality_data.describe().T
# Out:
#            count        mean         std          min          25%  \
# Year       476.0  1959.00000   34.387268  1900.000000  1929.000000
# DeathRate  476.0   192.92416  293.224216    11.400000    40.575000
# death_log  476.0     1.97402    0.507702     1.056905     1.608258
#
#                    50%          75%          max
# Year       1959.000000  1989.000000  2018.000000
# DeathRate    89.500000   222.575000  1983.800000
# death_log     1.951823     2.347475     3.297498

# %% [markdown]
# ## Access the data

# %%
mortality_data.query("Year == 2000 and AgeGroup != '1-4 Years'").hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'DeathRate'}>],
#        [<Axes: title={'center': 'death_log'}>, <Axes: >]], dtype=object)

# %%
mortality_data.query('Year == 1900 or Year == 2000').head()
# Out:
#      Year     AgeGroup  DeathRate  death_log
# 0    1900    1-4 Years     1983.8   3.297498
# 100  2000    1-4 Years       32.4   1.510545
# 119  1900    5-9 Years      466.1   2.668479
# 219  2000    5-9 Years       15.8   1.198657
# 238  1900  10-14 Years      298.3   2.474653

# %%
# use backticks if a column name contains spaces
mortality_data.query('Year == 2000 and `AgeGroup` != "1-4 Years"')
# Out:
#      Year     AgeGroup  DeathRate  death_log
# 219  2000    5-9 Years       15.8   1.198657
# 338  2000  10-14 Years       20.3   1.307496
# 457  2000  15-19 Years       67.1   1.826723

# %% [markdown]
# ### Access a subset of rows and columns

# %%
mortality_data.query('Year == 1900').DeathRate.head()
# Out:
# 0      1983.8
# 119     466.1
# 238     298.3
# 357     484.8
# Name: DeathRate, dtype: float64

# %%
mortality_data.query('Year == 1900')['DeathRate'].head()
# Out:
# 0      1983.8
# 119     466.1
# 238     298.3
# 357     484.8
# Name: DeathRate, dtype: float64

# %%
mortality_data.query('Year == 1900')[['AgeGroup','DeathRate']].head()
# Out:
#         AgeGroup  DeathRate
# 0      1-4 Years     1983.8
# 119    5-9 Years      466.1
# 238  10-14 Years      298.3
# 357  15-19 Years      484.8

# %% [markdown]
# ### Apply statistical methods

# %%
#mean = sum of values / count of case/observation
md_mu = mortality_data["DeathRate"].mean()

# %%
md_sigma = mortality_data["DeathRate"].std()

# %%
#95% confidence interval is mean +/- 2 stdev
print ("deathrate is {} +/- {}".format(md_mu,2*md_sigma))
# Out:
# deathrate is 192.92415966386554 +/- 586.4484319208581

# %%
mortality_data['outlier'] = mortality_data['DeathRate'].apply(
        lambda x: 
        True 
        if ( x > md_mu + 2*md_sigma or x < md_mu - 2*md_sigma)  
        else False 
            )

# %%
mortality_data.outlier.value_counts()
# Out:
# False    453
# True      23
# Name: outlier, dtype: int64

# %%
# line you draw for equal number of cases on either side
mortality_data.DeathRate.median()
# Out:
# 89.5

# %%
mortality_data[['AgeGroup','DeathRate']].max()
# Out:
# AgeGroup     5-9 Years
# DeathRate       1983.8
# dtype: object

# %%
mortality_data.count()
# Out:
# Year         476
# AgeGroup     476
# DeathRate    476
# death_log    476
# outlier      476
# dtype: int64

# %%
[i/20 for i in range(0,20)]
# Out:
# [0.0,
#  0.05,
#  0.1,
#  0.15,
#  0.2,
#  0.25,
#  0.3,
#  0.35,
#  0.4,
#  0.45,
#  0.5,
#  0.55,
#  0.6,
#  0.65,
#  0.7,
#  0.75,
#  0.8,
#  0.85,
#  0.9,
#  0.95]

# %%
mortality_data.quantile(0.5)
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_6452\668870176.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mortality_data.quantile(0.5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 mortality_data.quantile(0.5)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\frame.py:11274, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   11267 numeric_only = com.resolve_numeric_only(numeric_only)
#   11269 if not is_list_like(q):
#   11270     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   11271     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   11272     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   11273     # expected "float"
# > 11274     res_df = self.quantile(  # type: ignore[call-overload]
#   11275         [q],
#   11276         axis=axis,
#   11277         numeric_only=numeric_only,
#   11278         interpolation=interpolation,
#   11279         method=method,
#   11280     )
#   11281     if method == "single":
#   11282         res = res_df.iloc[0]
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\frame.py:11321, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   11315     raise ValueError(
#   11316         f"Invalid method: {method}. Method must be in {valid_method}."
#   11317     )
#   11318 if method == "single":
#   11319     # error: Argument "qs" to "quantile" of "BlockManager" has incompatible type
#   11320     # "Index"; expected "Float64Index"
# > 11321     res = data._mgr.quantile(
#   11322         qs=q, axis=1, interpolation=interpolation  # type: ignore[arg-type]
#   11323     )
#   11324 elif method == "table":
#   11325     valid_interpolation = {"nearest", "lower", "higher"}
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\internals\managers.py:1631, in BlockManager.quantile(self, qs, axis, interpolation)
#    1628 new_axes = list(self.axes)
#    1629 new_axes[1] = Float64Index(qs)
# -> 1631 blocks = [
#    1632     blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1633     for blk in self.blocks
#    1634 ]
#    1636 return type(self)(blocks, new_axes)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\internals\managers.py:1632, in <listcomp>(.0)
#    1628 new_axes = list(self.axes)
#    1629 new_axes[1] = Float64Index(qs)
#    1631 blocks = [
# -> 1632     blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1633     for blk in self.blocks
#    1634 ]
#    1636 return type(self)(blocks, new_axes)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\internals\blocks.py:1335, in Block.quantile(self, qs, interpolation, axis)
#    1332 assert axis == 1  # only ever called this way
#    1333 assert is_list_like(qs)  # caller is responsible for this
# -> 1335 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1336 # ensure_block_shape needed for cases where we start with EA and result
#    1337 #  is ndarray, e.g. IntegerArray, SparseArray
#    1338 result = ensure_block_shape(result, ndim=2)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\array_algos\quantile.py:37, in quantile_compat(values, qs, interpolation)
#      35     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      36     mask = isna(values)
# ---> 37     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      38 else:
#      39     return values._quantile(qs, interpolation)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\array_algos\quantile.py:95, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      93     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      94 else:
# ---> 95     result = _nanpercentile(
#      96         values,
#      97         qs * 100.0,
#      98         na_value=fill_value,
#      99         mask=mask,
#     100         interpolation=interpolation,
#     101     )
#     103     result = np.array(result, copy=False)
#     104     result = result.T
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\pandas\core\array_algos\quantile.py:216, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     214     return result
#     215 else:
# --> 216     return np.percentile(
#     217         values,
#     218         qs,
#     219         axis=1,
#     220         # error: No overload variant of "percentile" matches argument types
#     221         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     222         # "int", "Dict[str, str]"  [call-overload]
#     223         **{np_percentile_argname: interpolation},  # type: ignore[call-overload]
#     224     )
#
# File <__array_function__ internals>:180, in percentile(*args, **kwargs)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\numpy\lib\function_base.py:4166, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4164 if not _quantile_is_valid(q):
#    4165     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4166 return _quantile_unchecked(
#    4167     a, q, axis, out, overwrite_input, method, keepdims)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\numpy\lib\function_base.py:4424, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4416 def _quantile_unchecked(a,
#    4417                         q,
#    4418                         axis=None,
#    (...)
#    4421                         method="linear",
#    4422                         keepdims=False):
#    4423     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4424     r, k = _ureduce(a,
#    4425                     func=_quantile_ureduce_func,
#    4426                     q=q,
#    4427                     axis=axis,
#    4428                     out=out,
#    4429                     overwrite_input=overwrite_input,
#    4430                     method=method)
#    4431     if keepdims:
#    4432         return r.reshape(q.shape + k)
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\numpy\lib\function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\numpy\lib\function_base.py:4593, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4591     else:
#    4592         arr = a.copy()
# -> 4593 result = _quantile(arr,
#    4594                    quantiles=q,
#    4595                    axis=axis,
#    4596                    method=method,
#    4597                    out=out)
#    4598 return result
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\numpy\lib\function_base.py:4710, in _quantile(arr, quantiles, axis, method, out)
#    4708     result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4709     gamma = gamma.reshape(result_shape)
# -> 4710     result = _lerp(previous,
#    4711                    next,
#    4712                    gamma,
#    4713                    out=out)
#    4714 if np.any(slices_having_nans):
#    4715     if result.ndim == 0 and out is None:
#    4716         # can't write to a scalar
#
# File c:\Users\dolly\AppData\Local\R-MINI~1\envs\datascience-pro-env\Lib\site-packages\numpy\lib\function_base.py:4527, in _lerp(a, b, t, out)
#    4513 def _lerp(a, b, t, out=None):
#    4514     """
#    4515     Compute the linear interpolation weighted by gamma on each point of
#    4516     two same shape array.
#    (...)
#    4525         Output array.
#    4526     """
# -> 4527     diff_b_a = subtract(b, a)
#    4528     # asanyarray is a stop-gap until gh-13105
#    4529     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
len(mortality_data)

# %%
mort_dist = mortality_data.quantile([i/20 for i in range(0,20)])
mort_dist

# %%
mort_dist.info()

# %%
#bins of 20 percentile cuts

mort_dist["quantile"] = mort_dist.index
mort_dist

# %%
mort_dist.plot.line(y="quantile", x = "DeathRate")

# %%
mort_dist.plot.line(y="quantile", x = "death_log")

# %%
# compare with SUM() OVER in SQL
mortality_data["CumDeathRate"] = mortality_data.DeathRate.cumsum()
mortality_data

# %%
mortality_data.plot.line( y = "CumDeathRate")

# %% [markdown]
# ### Use Python for column arithmetic

# %%
mortality_data['MeanCentered'] = \
    mortality_data.DeathRate - mortality_data.DeathRate.mean()

# %%
#mortality_data.head(4)
mortality_data.MeanCentered.describe()

# %%
mortality_data['DeathRate'] = mortality_data.DeathRate / 100000

# %%
mortality_data.head(4)

# %% [markdown]
# ## Shape the data

# %% [markdown]
# ### Set and use an index

# %%
mortality_data = mortality_data.set_index('Year')
mortality_data.head(2)
# Out:
#        AgeGroup  DeathRate  death_log  outlier  CumDeathRate  MeanCentered
# Year
# 1900  1-4 Years   0.019838   3.297498     True        1983.8    1790.87584
# 1901  1-4 Years   0.016950   3.229170     True        3678.8    1502.07584

# %%
len(mortality_data)
# Out:
# 476

# %%
mortality_data.reset_index(inplace=True)
mortality_data
# Out:
#      Year     AgeGroup  DeathRate  death_log  outlier  CumDeathRate  \
# 0    1900    1-4 Years   0.019838   3.297498     True        1983.8
# 1    1901    1-4 Years   0.016950   3.229170     True        3678.8
# 2    1902    1-4 Years   0.016557   3.218982     True        5334.5
# 3    1903    1-4 Years   0.015421   3.188113     True        6876.6
# 4    1904    1-4 Years   0.015915   3.201807     True        8468.1
# ..    ...          ...        ...        ...      ...           ...
# 471  2014  15-19 Years   0.000455   1.658011    False       91631.7
# 472  2015  15-19 Years   0.000483   1.683947    False       91680.0
# 473  2016  15-19 Years   0.000512   1.709270    False       91731.2
# 474  2017  15-19 Years   0.000515   1.711807    False       91782.7
# 475  2018  15-19 Years   0.000492   1.691965    False       91831.9
#
#      MeanCentered
# 0      1790.87584
# 1      1502.07584
# 2      1462.77584
# 3      1349.17584
# 4      1398.57584
# ..            ...
# 471    -147.42416
# 472    -144.62416
# 473    -141.72416
# 474    -141.42416
# 475    -143.72416
#
# [476 rows x 7 columns]

# %%
# NOTE: the following line of code causes ValueError: Index has duplicate keys
mortality_data = mortality_data.set_index('Year', verify_integrity=True)
#mortality_data

# %%
mortality_data = mortality_data.set_index(
    ['Year','AgeGroup'], verify_integrity=True)
mortality_data.head(2)
# Out:
#                 DeathRate  death_log  outlier  CumDeathRate  MeanCentered
# Year AgeGroup
# 1900 1-4 Years   0.019838   3.297498     True        1983.8    1790.87584
# 1901 1-4 Years   0.016950   3.229170     True        3678.8    1502.07584

# %%
mortality_data.reset_index(inplace=True)
mortality_data.head(2)
# Out:
#    Year   AgeGroup  DeathRate  death_log  outlier  CumDeathRate  MeanCentered
# 0  1900  1-4 Years   0.019838   3.297498     True        1983.8    1790.87584
# 1  1901  1-4 Years   0.016950   3.229170     True        3678.8    1502.07584

# %%
mortality_data.shape
# Out:
# (476, 7)

# %% [markdown]
# ### Pivot the data

# %%
mortality_wide = mortality_data.pivot(
    index='Year', columns='AgeGroup', values=['DeathRate','MeanCentered'])
mortality_wide.head(3)
# Out:
#          DeathRate                                   MeanCentered              \
# AgeGroup 1-4 Years 10-14 Years 15-19 Years 5-9 Years    1-4 Years 10-14 Years
# Year
# 1900      0.019838    0.002983    0.004848  0.004661   1790.87584   105.37584
# 1901      0.016950    0.002736    0.004544  0.004276   1502.07584    80.67584
# 1902      0.016557    0.002525    0.004215  0.004033   1462.77584    59.57584
#
#
# AgeGroup 15-19 Years  5-9 Years
# Year
# 1900       291.87584  273.17584
# 1901       261.47584  234.67584
# 1902       228.57584  210.37584

# %%
mortality_wide.shape
# Out:
# (119, 8)

# %%
mortality_wide = mortality_data.pivot(
    index=['Year','MeanCentered'], columns='AgeGroup', values='DeathRate')
mortality_wide.head(3)
# Out:
# AgeGroup           1-4 Years  10-14 Years  15-19 Years  5-9 Years
# Year MeanCentered
# 1900 105.37584           NaN     0.002983          NaN        NaN
#      273.17584           NaN          NaN          NaN   0.004661
#      291.87584           NaN          NaN     0.004848        NaN

# %%
mortality_wide = mortality_data.pivot(
    index='Year', columns='AgeGroup')
mortality_wide.head(3)
# Out:
#          DeathRate                                   death_log              \
# AgeGroup 1-4 Years 10-14 Years 15-19 Years 5-9 Years 1-4 Years 10-14 Years
# Year
# 1900      0.019838    0.002983    0.004848  0.004661  3.297498    2.474653
# 1901      0.016950    0.002736    0.004544  0.004276  3.229170    2.437116
# 1902      0.016557    0.002525    0.004215  0.004033  3.218982    2.402261
#
#                                  outlier                                    \
# AgeGroup 15-19 Years 5-9 Years 1-4 Years 10-14 Years 15-19 Years 5-9 Years
# Year
# 1900        2.685563  2.668479      True       False       False     False
# 1901        2.657438  2.631038      True       False       False     False
# 1902        2.624798  2.605628      True       False       False     False
#
#          CumDeathRate                                   MeanCentered  \
# AgeGroup    1-4 Years 10-14 Years 15-19 Years 5-9 Years    1-4 Years
# Year
# 1900           1983.8     59864.0     71209.1   46070.0   1790.87584
# 1901           3678.8     60137.6     71663.5   46497.6   1502.07584
# 1902           5334.5     60390.1     72085.0   46900.9   1462.77584
#
#
# AgeGroup 10-14 Years 15-19 Years  5-9 Years
# Year
# 1900       105.37584   291.87584  273.17584
# 1901        80.67584   261.47584  234.67584
# 1902        59.57584   228.57584  210.37584

# %%
mortality_wide.to_csv("mortality_wide.csv")

# %%
mortality_wide.shape
# Out:
# (119, 20)

# %% [markdown]
# ### Melt the data

# %%
mortality_wide = mortality_data.pivot(
    index='Year', columns='AgeGroup', values='DeathRate')
mortality_wide.head(3)
# Out:
# AgeGroup  1-4 Years  10-14 Years  15-19 Years  5-9 Years
# Year
# 1900       0.019838     0.002983     0.004848   0.004661
# 1901       0.016950     0.002736     0.004544   0.004276
# 1902       0.016557     0.002525     0.004215   0.004033

# %%
# get starting data


# save to Excel format to remove indexes
mortality_wide.to_excel('mortality_wide.xlsx')
mortality_wide = pd.read_excel('mortality_wide.xlsx')

mortality_wide.head(4)
# Out:
#    Year  1-4 Years  10-14 Years  15-19 Years  5-9 Years
# 0  1900   0.019838     0.002983     0.004848   0.004661
# 1  1901   0.016950     0.002736     0.004544   0.004276
# 2  1902   0.016557     0.002525     0.004215   0.004033
# 3  1903   0.015421     0.002682     0.004341   0.004147

# %%
mortality_long = mortality_wide.melt(
    id_vars = 'Year',
    value_vars=['1-4 Years','5-9 Years'],
    var_name ='AgeGroup',
    value_name='DeathRate')

with pd.option_context('display.max_rows', 4):
    display(mortality_long)
# Out:
#      Year   AgeGroup  DeathRate
# 0    1900  1-4 Years   0.019838
# 1    1901  1-4 Years   0.016950
# ..    ...        ...        ...
# 236  2017  5-9 Years   0.000116
# 237  2018  5-9 Years   0.000115
#
# [238 rows x 3 columns]

# %% [markdown]
# ## Analyze the data

# %% [markdown]
# ### Group the data

# %%
mortality_data.groupby('AgeGroup').mean()
# Out:
#              Year  DeathRate  death_log   outlier  CumDeathRate  MeanCentered
# AgeGroup
# 1-4 Years    1959   0.003832   2.193591  0.193277  37353.117647    190.301891
# 10-14 Years  1959   0.000938   1.772540  0.000000  67911.569748    -99.154412
# 15-19 Years  1959   0.001774   2.134860  0.000000  85460.104202    -15.549370
# 5-9 Years    1959   0.001173   1.795091  0.000000  56497.440336    -75.598109

# %%
mortality_data.groupby('AgeGroup').median()
# Out:
#              Year  DeathRate  death_log  outlier  CumDeathRate  MeanCentered
# AgeGroup
# 1-4 Years    1959   0.001091   2.037825    False       42409.4     -83.82416
# 10-14 Years  1959   0.000446   1.649335    False       69110.8    -148.32416
# 15-19 Years  1959   0.001069   2.028978    False       87096.4     -86.02416
# 5-9 Years    1959   0.000484   1.684845    False       58040.5    -144.52416

# %%
mortality_data.groupby('Year').median().head(4)
# Out:
#       DeathRate  death_log  outlier  CumDeathRate  MeanCentered
# Year
# 1900   0.004755   2.677021    False      52967.00     282.52584
# 1901   0.004410   2.644238    False      53317.60     248.07584
# 1902   0.004124   2.615213    False      53645.50     219.47584
# 1903   0.004244   2.627662    False      53986.95     231.47584

# %%
mortality_data.groupby(['Year','AgeGroup']).count().head()
# Out:
#                   DeathRate  death_log  outlier  CumDeathRate  MeanCentered
# Year AgeGroup
# 1900 1-4 Years            1          1        1             1             1
#      10-14 Years          1          1        1             1             1
#      15-19 Years          1          1        1             1             1
#      5-9 Years            1          1        1             1             1
# 1901 1-4 Years            1          1        1             1             1

# %% [markdown]
# ### Aggregate the data

# %%
mortality_data[['AgeGroup','DeathRate']].groupby('AgeGroup').agg(['mean','median','min','max','std'])
# Out:
#             DeathRate
#                  mean    median       min       max       std
# AgeGroup
# 1-4 Years    0.003832  0.001091  0.000240  0.019838  0.005005
# 10-14 Years  0.000938  0.000446  0.000139  0.003751  0.000884
# 15-19 Years  0.001774  0.001069  0.000448  0.007774  0.001384
# 5-9 Years    0.001173  0.000484  0.000114  0.004661  0.001275

# %%
mortality_data[['AgeGroup','DeathRate']].groupby('AgeGroup')?
# Out:
#   File "<ipython-input-86-7348e6205b1b>", line 1
#     mortality_data[['AgeGroup','DeathRate']].groupby('AgeGroup')?
#                                                                 ^
# SyntaxError: invalid syntax

# %%
AgeGS = mortality_data.groupby("AgeGroup")
type(AgeGS)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
AgeGS["outlier"].agg(['mean','median','std','nunique'])
# Out:
#                  mean  median       std  nunique
# AgeGroup
# 1-4 Years    0.193277   False  0.396538        2
# 10-14 Years  0.000000   False  0.000000        1
# 15-19 Years  0.000000   False  0.000000        1
# 5-9 Years    0.000000   False  0.000000        1

# %%
mortality_data.groupby('AgeGroup')['DeathRate'] \
    .agg(['mean','median','std','nunique'])
# Out:
#                  mean    median       std  nunique
# AgeGroup
# 1-4 Years    0.003832  0.001091  0.005005      117
# 10-14 Years  0.000938  0.000446  0.000884      115
# 15-19 Years  0.001774  0.001069  0.001384      117
# 5-9 Years    0.001173  0.000484  0.001275      115

# %%
mortality_data.groupby('Year')['DeathRate'] \
    .agg(['mean','median','std','min','max','var','nunique']).head(3)
# Out:
#           mean    median       std       min       max       var  nunique
# Year
# 1900  0.008082  0.004755  0.007882  0.002983  0.019838  0.000062        4
# 1901  0.007127  0.004410  0.006597  0.002736  0.016950  0.000044        4
# 1902  0.006832  0.004124  0.006527  0.002525  0.016557  0.000043        4

# %%
def fun_1q(foo): return foo.quantile(0.75)

fun_1q(mortality_data.DeathRate)
# Out:
# 0.0022257500000000003

# %%
fun_1q(mortality_wide[['1-4 Years']])
# Out:
# 1-4 Years    0.005773
# Name: 0.75, dtype: float64

# %% [markdown]
# ## Visualize the data

# %%
mortality_data.pivot(index='Year',columns='AgeGroup')['DeathRate']
# Out:
# AgeGroup  1-4 Years  10-14 Years  15-19 Years  5-9 Years
# Year
# 1900       0.019838     0.002983     0.004848   0.004661
# 1901       0.016950     0.002736     0.004544   0.004276
# 1902       0.016557     0.002525     0.004215   0.004033
# 1903       0.015421     0.002682     0.004341   0.004147
# 1904       0.015915     0.003052     0.004714   0.004250
# ...             ...          ...          ...        ...
# 2014       0.000240     0.000140     0.000455   0.000115
# 2015       0.000249     0.000146     0.000483   0.000117
# 2016       0.000253     0.000146     0.000512   0.000122
# 2017       0.000243     0.000155     0.000515   0.000116
# 2018       0.000240     0.000149     0.000492   0.000115
#
# [119 rows x 4 columns]

# %%
mortality_data['DeathRate'].plot()
# Out:
# <AxesSubplot:>

# %%
mortality_data.pivot(index='Year',columns='AgeGroup')['DeathRate']
# Out:
# AgeGroup  1-4 Years  10-14 Years  15-19 Years  5-9 Years
# Year
# 1900       0.019838     0.002983     0.004848   0.004661
# 1901       0.016950     0.002736     0.004544   0.004276
# 1902       0.016557     0.002525     0.004215   0.004033
# 1903       0.015421     0.002682     0.004341   0.004147
# 1904       0.015915     0.003052     0.004714   0.004250
# ...             ...          ...          ...        ...
# 2014       0.000240     0.000140     0.000455   0.000115
# 2015       0.000249     0.000146     0.000483   0.000117
# 2016       0.000253     0.000146     0.000512   0.000122
# 2017       0.000243     0.000155     0.000515   0.000116
# 2018       0.000240     0.000149     0.000492   0.000115
#
# [119 rows x 4 columns]

# %%
mortality_data.pivot(index='Year',columns='AgeGroup')['DeathRate'].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
mortality_data.groupby('AgeGroup')['DeathRate'] \
    .agg(['mean','median','std'])
# Out:
#                  mean    median       std
# AgeGroup
# 1-4 Years    0.003832  0.001091  0.005005
# 10-14 Years  0.000938  0.000446  0.000884
# 15-19 Years  0.001774  0.001069  0.001384
# 5-9 Years    0.001173  0.000484  0.001275

# %%
mortality_data.plot.

# %%
mortality_data.groupby('AgeGroup')['DeathRate'] \
    .agg(['mean','median','std']).plot.barh()
# Out:
# <AxesSubplot:ylabel='AgeGroup'>

# %%
import seaborn as sns

# %%
sns.boxplot(data=mortality_data, 
             y='DeathRate', x='AgeGroup')
# Out:
# <AxesSubplot:xlabel='AgeGroup', ylabel='DeathRate'>

# %%
sns.relplot(data=mortality_data, 
            kind='line', x='Year', y='DeathRate', hue='AgeGroup', 
            height=4, aspect=1.25, 
            col='AgeGroup', col_wrap=2, legend=False)
