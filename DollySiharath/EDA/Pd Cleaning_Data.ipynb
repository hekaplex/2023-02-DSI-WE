# %% [markdown]
# https://www.youtube.com/watch?v=2isVrKpAx6Q
# Map and data wrangle
#
# Data Wranging Process:
# *** Determine the issue or problems to be resolved.
# 0. Getting your data from internal or external sources.
# *** Collecting ranges of data.
#    *** verifying and due dilligence to make sure the data is valid( check and recheck
#        not to miss anything).
#    *** Detecting fairness
#    *** Elimating and look for bias or outliers because it will effects the outcome.
# 1. installing and importing the required libraies.
#
# 2. Reading the datasets.
#     print("Index:  ", df.index)
#     print("Columns:", df.columns)
#     print("Size:   ", df.size)
#     print("Shape:  ", df.shape)
#
# 3. Examing the datasets and removing NULLs, Outliers, Blanks.
#     #df.isna().sum()
#     #df.isna().sum()
#     #df.head().T
#     #df.head()
#     #df.info()
#     df.shape
#     #df.describe().T # run a quick stat
#     #df.columns
#
#
#
# 4. Data Danling, cleaning, formating and documenting the process.
#  - shaping the data to answer specific questions:
#     Removing unwanted data.
#     Renaming data - columns
#     Verifying and changing the data type.
#     Combing the data or creating new data - rows or columns or combine dataframe.
#
#
# 5. Take a look or snap-shoot of your data (Summary) using histogram().
#
#
# 6. Run Statistic of the data.
#
#
# 7. Using clean data to create your model - test, validate ..ect.
#    *** verifying and examing the behavior of the outcome.
#    *** re-adjust if needed.
#
# 8. Create visualizations and telling a story.
#
# 9. Sharing data with your team, other groups or stakeholders.
#
# -================================================================================================
#
# ###### READING and extracting FILES into dataframe
#
#
# Extract only specific column that meet the condition:
# df = pd.read_csv('xxxx.csv')
# Tract_df = df[df['Age_prev'] == 'xxx'][:27004]
#
#
#
# with open ("C:/Diff/test.txt", "r") as f:
#     file_contents = f.read()
#     print(file_contents)
#
# with open ("C:/Diff/STROKEDatasets/2015_Mortality_Age35_Plus.csv", "r+" ) as f:
#     f_Dataset = f.read()
#     print(f_Dataset)
#
#
# test = "C:/Diff/Python/Stroke_Project/test.csv"
# test = pd.read_csv(test)
# test
#
#
# fires = pd.read_pickle('fires_cleaned.pkl')
# fires.head()
#
#
#
# with open ("C:/Diff/test.txt", "r") as f:
#     file_contents = f.read()
#     print(file_contents)
#
# with open ("C:/Diff/STROKEDatasets/2015_Mortality_Age35_Plus.csv", "r+" ) as f:
#     f_Dataset = f.read()
#     print(f_Dataset)
#
#
# test = "C:/Diff/Python/Stroke_Project/test.csv"
# test = pd.read_csv(test)
#
#
#
# Another example of selecting specific dataframe/columns from cvs file:
# TBL01_Stroke_Dataset = df[["Year", "LocationAbbr", "LocationDesc", "GeographicLevel", "Class", "Topic"]]
# TBL02_Stroke_Dataset = df[["Data_Value", "Data_Value_Unit", "Data_Value_Type", "StratificationCategory1", "Stratification1"]]
# TBL03_Stroke_Dataset = df[["StratificationCategory2", "Stratification2", "TopicID", "LocationID", "Location 1","Counties", "States"]]
# (TBL01_Stroke_Dataset)
#
#
# fires = pd.read_pickle('fires_cleaned.pkl')
# fires.head()
#
#
# Create dataframe.
# df = pd.DataFrame(ABC_Sales_Goal)
# df
#
#
#
#
# #### EXPLORE DATAFRAME after loading into a dataframe:  headers, tails,  data type  ect.
#
#
# Stroke_Dataset_2015.head(5)
# Stroke_Dataset_2015.info()
#
# df.describe()
# Options to use when analyzing data set:
#  #df.tail(2)
#  #df.shape  # print rows and columns in tuple.
#  #rows, columns = df.shape
#  #df.columns # will print all the column names.
#  #df.DATE # will print the entire column called "DATE".
#  #df[["DATE", "FUEL_COST_PER_GAL" ]]  # print multliple columns as a list.
#  #print(df["ColumnName"][0:5]) # print top 5 columns.
#  #print(df.ColumnName) # will print a column.
#  print(df[["col1", "col2", "col"]])  # create a list of multiple columns and print.
#
# Options with accessing or getting data in the rows:
#  #df[2:5]  # get row 2 - 4.
#  #print(df.iloc[1])  get the first index.
#  #print(df.iloc[1:4]) get the first - fourth.
#  #print(df.iloc[2, 1])   get the value from of the second "[2, 1]" row in the first position or cell of the column.
#
#
#
# #### DROPPING COLUMNS:
#
# df.drop(columns = ['Year'])
# df.drop(columns = ["Year","ID_Num", "County_Num"]).describe().T
#
# How to drop muliple dataframe:
# kwargs = {"columns":["GeographicLevel", "DataSource", "Class", "Topic", "Data_Value_Unit", \
# "Data_Value_Type", "Data_Value_Footnote_Symbol", "Data_Value_Footnote", "StratificationCategory1",\
# "StratificationCategory2", "TopicID", "Location 1"],"inplace":True}
# Stroke_Dataset_2015.drop(**kwargs)
#
#
#
#
#
#
#
#
#
#
# ##### Filtering
#
#
# CHANING DATA TYPES:
#
# change data type from str to date.
# pd.to_datetime(df['DATE'])
# pf.to_numeric(df['col_name])
#
# #Change data type:
# # removing the "," from the PopCountByMM values and replace it with nothing than change it from object type to int.
# New_df["Pop_Count"] = New_df["Pop_Count"].str.replace(',','').astype(int)
#
#
#
# RENAMING COLUMNS:
# df.rename(columns={'old_column_name':'new_column_name})
# Below is rewrite the dataframe.
# df =  df.rename(columns={'old_column_name':'new_column_name})
#
#
#
# MISSING VALUES:
# print(df.isna)
# df.isna().sum()
#
#
# NaN:
# NaN is a float not an int.
#
# df.query("name.notna()")
# print(New_df.isna)
#
# Print and list all the NaN in the column
# df.query("Pre_Diabetic.isna()")
#
#  ===== or ==== Display T/F
#  print(New_df['Diabetic'].isna())
#
# Count N t((New_df['Diabetic'].isna()).sum())
#
#
# ##### Dropping NaN values.
# Select every columns in the dataframe.
# New_df_NoNull = df[[ 'States', 'City', 'AgeAdj_Prevalence', 'Diabetic', 'Pre_Diabetic',
# 'Pop_Count' ]].dropna()
#
#
# Verify for NaN again:
# df.isna().sum()
# df.query("Diabetic.isna()")
#
#
#
# ##### DUPLICATE VALUES and DROPPING:
#
# df.duplicated()
# df.loc[df.duplicated()]
# df.loc[df.duplicated(subset=['StrokeDeath_Per100k'])] # by column name
# df.loc[df.duplicated(subset=['States_ID'])]
# df.query('States_ID == "40.0"')
#
#
# Verifying duplicate values and count:
# df_diab_01.loc[df_diab_01.duplicated(subset=['States'])]
# df_diab_01.loc[df_diab_01.duplicated(subset=['States'])].count()
#
# Removing dup values:
# note:  Becareful to make a backup before making changes.
#  ~ taking inverse and dropping duplicate rows.
#  .reset the index()
#
# print(df.isna().sum())
# df = df.loc[~df.duplicated(subset=['StrokeDeath_Per100k'])].reset_index(drop=True).copy()
# print(df.isna().sum())
# df
#
# note: The last row containing the NaN value will not be dropped.
#
#
# DUMPPING DATA - ROWS AND COLUMNS:
# for index, rows in df.iterrows(): # getting or reading row by row.
#     print(index, rows["StrokeDeath_Per100k"])
#
#
#
# ##### RESET INDEX:
#
# How to reset the index.
# new_df = new_df.reset_index(drop=T, inplace=True)
# new_df
#
# df = df.loc[~df.duplicated(subset=['StrokeDeath_Per100k'])].reset_index()
# #.reset_index() # Run it only one time, if run the second time, erro will occurred.
#
#
# ##### COMBINE DATA:
# Concat State and City name into one single column:
# df_diab_01 ['StateAndCity'] = df_diab_01['States'] + ['City']
# df_diab_01
#
#
# Reorganize the columns
# #Create a new list in the order that you want.
# New_cols = ['StateAndCity','Diabetic', 'Pre_Diabetic', 'Pop_Count']
# df_diab_01 = df_diab_01[New_cols]
# df_diab_01
#
#
#
# #### DROPPING OR DELETING NULL and comma ",".
#
# REMOVING SPACES FROM THE COLUMNS:
# df[[ "col_name01", "col_name02", "col_name02" ]].dropna()
#
#
# How to drop a column or selected specific columns:
# Columns_drop = Stroke_Dataset.drop(columns=["GeographicLevel", "DataSource", "Class", "Topic", "Data_Value_Unit"])
#
#
# How to remove spaces from the column name.
# df.columns = df.columns.str.replace(' ', '')
#
#
# How to select specific colums, dropping columns, and renaming columns.
# Selecting specific columns:
# New_Goal = df[["Year_2023", "Earning", "Goal"]]
# print(New_Goal)
#
#
# #### DROPPING COLUMN AND ROWS OR CREATE DATAFRAME
#
#
# Columns_drop = Stroke_Dataset.drop(columns=["GeographicLevel", "DataSource", "Class", "Topic", "Data_Value_Unit"])
#
#
# ==============
# 0 = ROWS
# 1 = COLUMN
#
# Dropping row by index:
# df = df.drop(df.index[[2]], axis = 0)
#
# df.drop(df[df.OB_M_Value == 10].index)
#
# # only keeping and create dataframe
# df_New = df[(df['OB_M_Value'] !=5 & (df['DB_M_Value'] > 20))]
#
# =============
# dropping multiple columns using "**kwargs"
# dropping a list inside the dictionaries
# inplace set to True.
#
# kwargs = {"columns":["GeographicLevel", "DataSource", "Class", "Topic", "Data_Value_Unit", \
# "Data_Value_Type", "Data_Value_Footnote_Symbol", "Data_Value_Footnote", "StratificationCategory1",\
# "StratificationCategory2", "TopicID", "Location 1"],"inplace":True}
# Stroke_Dataset.drop(**kwargs)
#
# ============
#
# Instead of dropping, create new df and specify only the columns to keep
#  df = df[['A', 'B', 'C']]
#
#
# #### TRANSPONE:
#
# New_Stroke_Dataset = df.T
# New_Stroke_Dataset.head(3)
# print(New_Stroke_Dataset)

# %% [markdown]
# GROUP BY:
#
# df.groupby(["col_name"]).mean()  # Sorted by the col_name and average all others data.
# df.groupby(["MILES_TRAVELED"]).mean().sort_values("FUEL_COST", ascending=False)
# Tx_Death_Rate.groupby(["Gender"]).mean().sort_values("death_per100k", ascending=False)
# Tx_Death_Rate.groupby(["Gender"]).sum()
# Tx_Death_Rate.groupby(["Gender"]).count()
# Tx_Death_Rate.groupby(["Gender"]).count()["States"]
# Tx_Death_ByGender = Tx_Death_Rate.groupby(["States","County", "Gender", "Race_Ethnicity" ]).count()["death_per100k"]
# Tx_Death_ByGender
#
# USING query to ACCESSING DATA:
# Stroke_Dataset_2015.query('`States` == "TX" and `Race_Ethnicity` != "Overall"')
# Stroke_Dataset_2015.query('Year == 2015 and `States` != "SD"')
# mortality_data.query('Year == 1900')[['AgeGroup','DeathRate']].head()
#
# USING query to ACCESSING DATA by condition:
# df_diab = New_df.query('`AgeAdj_Prevalence` == "Age-adjusted prevalence"').groupby(["States"])
#
#
# Using filter to get specific row that has specific key value
# TRIP_METTERS is the column name.
# df.loc[df["TRIP_METTERS"] != 250 ]
# df.loc[df["TRIP_METTERS"] == 250 ]
# df.loc[df["TRIP_METTERS"] == "xxxxx"]
# df.loc[df["column_name"]] == "vvv1") & [df["column_name"]] == "vvv2") & [df["column_name"]] > 50)]
#
# Retreive char/str values.
#  ~ means not.
#
# df.loc[df["column_name"].str.contains("Dolly")]
# df.loc[~df["column_name"].str.contains("Dolly")]
#
#
# USING regex to ACCESSING DATA:
# flags=re.I,   means ignor lower or upper case.
# "^Sih[a-z]*",  means get char. starting with Sih the rest are *
# import re
# df.loc[df["DATE"].str.contains("1/1/2023", regex=True)]
# df.loc[df["column_name"].str.contains("Dolly | Vanna", flags=re.I, regex=True)]
# df.loc[df["column_name"].str.contains("^Sih[a-z]*", flags=re.I, regex=True)]
# df.loc[df["column_name"] == "Douang", "column_name"] = "Dolly"  # Chaning cell value name.
#
# USING query to ACCESSING DATA:
# Stroke_Dataset_2015.query('`States` == "TX" and `Race_Ethnicity` != "Overall"')
# Stroke_Dataset_2015.query('Year == 2015 and `States` != "SD"')
# mortality_data.query('Year == 1900')[['AgeGroup','DeathRate']].head()
#
#
# SORTING:
# ascending=[1,0]
# 1 means sort the first column asce
# 0 means sort the second column dece
#
# #df.sort_values("TRIP_METTERS")
# df.sort_values("TRIP_METTERS","GALLONS_USED", ascending=False)
# df.sort_values(["TRIP_METTERS", "FUEL_COST"])
# df.sort_values(["TRIP_METTERS", "FUEL_COST"], ascending=[1,0])
#
# ADDING NEW COLUMN:
#
#  Adding column using init location "iloc"
#  : means select all rows in the columns
#   1:5 means select column 1-5
#  sum(axis=1) means adding honzontally
#  sum(axis=0) means adding vertically
#
# df["TOT"] = df.iloc[:, 1:7].sum(axis=1)
# df.head()
#
#
# ######  QUERY OR GETTING SPECIFIC ROW OR COLUMN
#
# How to query for none na.
# df.query("name.notna()")
#
#
# Query for NOT NaN/ NULL
# df.query("name.notna()")
#
# #Dropping NULL Values by columns.
# df_diabetes = New_df_db[["States","City", "DiagPer100k", "PopCountByMM" ]].dropna()
# df_diabetes
#
#
# #Dropping ALL NULL Values in the dataframe.
# df.dropna(inplace=True)
#
#
# # Verifying no NULL values - Dataset is cleaned!
# df_diabetes.loc[New_df_db.duplicated()].reset_index
#
# Change data type:
# # removing the "," from the PopCountByMM values and replace it with nothing than change it from object type to int.
# df_diabetes["PopCountByMM"] = df_diabetes["PopCountByMM"].str.replace(',','').astype(int)
#
#
# print(df_diabetes.isna().sum())
#
#
#
# import re
# df.loc[df["DATE"].str.contains("1/1/2023", regex=True)]
#
#
# df.groupby(["MILES_TRAVELED"]).mean().sort_values("FUEL_COST", ascending=False)
#
#
# mortality_data.query("Year == 2000 and AgeGroup != '1-4 Years'").hist()
#
# Female_Death_AvgRate = df.query('Gender == "Female" and Ethnicity == "White"').groupby('Gender') ['StrokeDeath_Per100k'] \
#     .agg(['mean', 'count'])
# Female_Death_AvgRate
#
# Combined codes by steps:
# CA_df = df_diabetes.query('`States` == "CA"')
# CA_df.to_csv("CA_Diabetes.csv")
# CA_df["CA_City"] = CA_df["States"] + " " + CA_df["City"]
# Drop_01 = CA_df.drop(columns=["States", "City" ])
# RM_01 = Drop_01.rename(columns={'DiagPer100k':'CA_DiagPer100k','PopCountByMM':'CA_PopByMM' })
# RM_01.to_csv("CA_Diabetes.csv")
#
#
# NExt step:
# New_Cols01 = ['CA_City','CA_PopByMM','CA_DiagPer100k'  ]
# df_New_CA = RM_01[New_Cols01]
# df_New_CA.to_csv("CA_Diabetes.csv")
# df_New_CA
#
#
# Another:
# #df_diabetes["Texas"]
# TX_df = df_diabetes.query('`States` == "TX"')
# TX_df.to_csv("TX_Diabetes.csv")
#
# TX_df["TX_City"] = TX_df["States"] + " " + TX_df["City"]
# Drop_02 = TX_df.drop(columns=["States", "City" ])
# RM_02 = Drop_02.rename(columns={'DiagPer100k':'TX_DiagPer100k','PopCountByMM':'TX_PopByMM' })
# #RM_02.to_csv("TX_Diabetes.csv")
# #RM_02
#
# New_Cols02 = ['TX_City','TX_PopByMM','TX_DiagPer100k'  ]
# df_New_TX = RM_02[New_Cols02]
# df_New_TX.to_csv("TX_Diabetes.csv")
# df_New_TX
#
#
#
# #df_diabetes["New York"]
# NY_df = df_diabetes.query('`States` == "NY"')
# NY_df.to_csv("NY_Diabetes.cvs")
# NY_df["NY_City"] = NY_df["States"] + " " + NY_df["City"]
# Drop_03 = NY_df.drop(columns=["States", "City" ])
# RM_03 = Drop_03.rename(columns={'DiagPer100k':'NY_DiagPer100k','PopCountByMM':'NY_PopByMM' })
# #RM_03.to_csv("NY_Diabetes.csv")
# #RM_03
#
# New_Cols03 = ['NY_City','NY_PopByMM','NY_DiagPer100k'  ]
# df_New_NY = RM_03[New_Cols03]
# df_New_NY.to_csv("NY_Diabetes.csv")
# df_New_NY
#
#
# #####  COUNT
#
# df.count() # count number of items in the column
# df.count(axis=0) # the same results as df.count()
# len(df) # number of rows in the dataframe
#
#  DF['COLUMN_NAME'].value_counts(dropna=False)  # diplay NaN value as well.
#
# ##### PERCENTILE:
#
# np.percentile(df['DB_M_Value'], [25, 50, 75, 100])
#
#
#
# ##### Subplot
#
# red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')
# fig, axs = plt.subplots(1, len(df02.columns), figsize=(20,10))
#
# for i, ax in enumerate(axs.flat):
#     ax.boxplot(df02.iloc[:,i], flierprops=red_circle) # exclude row#0 and #1
#     #ax.boxplot(df02.iloc[:,2:16], flierprops=red_circle) # exclude row#0 and #1
#     ax.set_title(df02.columns[i], fontsize=20, fontweight='bold')
#     ax.tick_params(axis='y', labelsize=14)
#
# plt.show()
#
#
# #### Subplot
#
# red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')
# fig, axs = plt.subplots(1, len(df02.columns), figsize=(20,10))
#
# for i, ax in enumerate(axs.flat):
#     ax.boxplot(df02.iloc[:,i], flierprops=red_circle) # exclude row#0 and #1
#     ax.set_title(df02.columns[i], fontsize=20, fontweight='bold')
#     ax.tick_params(axis='y', labelsize=14)
#
# plt.show()
#
# # Count and determine the outliers
# HD_degree_counts = df['HD_M_Value'].value_counts() # replace the outliers values on the upper quantile all values > 15.0 with 4.9
# HBP_degree_counts = df['HBP_M_Value'].value_counts()
# HC_degree_counts = df['HC_M_Value'].value_counts()
# OB_degree_counts = df['OB_M_Value'].value_counts()
# DB_degree_counts = df['DB_M_Value'].value_counts(normalize=True)  # get re;atove frequency - Percentage
#
# # Same results as above
# df.value_counts(df['HC_M_Value'])  # count unique value by column
#
#
#
# # Checking for outliers against the mean
#
# # Count unique and determine the outliers
# HD_degree_counts = df['HD_M_Value'].value_counts()
# HBP_degree_counts = df['HBP_M_Value'].value_counts()
# HC_degree_counts = df['HC_M_Value'].value_counts(normalize=True) # get the percentage for each group.
# OB_degree_counts = df['OB_M_Value'].value_counts()
# DB_degree_counts = df['DB_M_Value'].value_counts()
#
# #print(HD_degree_counts)
# #print(HBP_degree_counts)
# #print(HC_degree_counts)
# print(OB_degree_counts)
# #print(DB_degree_counts)
#
#
# #### plot distributin
# sns.distplot(df['OB_M_Value'])
#
# #### boxplot
#
# red_circle = dict(markerfacecolor='red', marker='o') ## outliers
# mean_shape = dict(markerfacecolor='green', marker='D', markeredgecolor='green') ##
# plt.boxplot(x=df['Target_Value'], vert=True, flierprops=red_circle, showmeans=True, meanprops=mean_shape, notch=True);
#
#
# #
# #df["HD_M_Value"].describe()
# #df["HC_M_Value"].describe()
# #df["HBP_M_Value"].describe()
# #df["OB_M_Value"].describe()
# #df["DB_M_Value"].describe()
# df["Target_Value"].describe()
#
# df_01 = df_org.query("`OB_M_Value` <=12 & `OB_M_Value` >50" )
# df_02 = df_01.query("`DB_M_Value` <=2 & `DB_M_Value` >25" )
# df_03 = df_02.query("`HD_M_Value` >15" )
# df_04 = df_03.query("`HBP_M_Value` <=15 & `HBP_M_Value` >50" )
# df = df_04.query("`HC_M_Value` <=15 & `HC_M_Value` >50" )
#
#
#
# # verifying outliers from the mean of both lower and upper quantiles.
#
#
# #df_OB_O_Less = df.loc[df["OB_M_Value"] < 12] # 16 records
# #df_OB_O_Grt50 = df.loc[df["OB_M_Value"] > 50.0 ] # 62 records
# #df_DB_O_Less = df.loc[df["DB_M_Value"] < 2] # 72 records below
# #df_DB_O_Greater  = df.loc[df["DB_M_Value"] > 25.0 ] # 99 records
# #df_HD_O_Greater  = df.loc[df["HD_M_Value"] > 15.0 ] #  records
# #df_HBP_O_Less = df.loc[df["HBP_M_Value"] < 15.0] # 72 records
# #df_HBP_O_Greater  = df.loc[df["HBP_M_Value"] > 50.0 ] #  records
# #df_HC_O_Less = df.loc[df["HC_M_Value"] < 15.0] # 72 records
# #df_HC_O_Greater  = df.loc[df["HC_M_Value"] > 50.0 ] #  records
# #df_HC_O_Less = df.loc[df["HC_M_Value"] < 15.0] # 72 records
# #df_HC_O_Greater  = df.loc[df["HC_M_Value"] > 45.0 ] #  records
#
# #=============================================================
#
#
# df_HC_O_Less = df.loc[df["HC_M_Value"] < 15.0]
# df_HC_O_Grter  = df.loc[df["HC_M_Value"] > 45.0 ]
#
# #df_DB_O_Less = df.loc[df["DB_M_Value"] < 2] # 72 records below
# #df_DB_O_Greater  = df.loc[df["DB_M_Value"] > 25.0 ] # 99 records
# #print(df_HC_O_Less["HC_M_Value"].value_counts())
# #print(df_HC_O_Grter["HC_M_Value"].value_counts())
#
#
#
#
# # Removing outliers by query for the values to keep
#
# df = df_org.query("`OB_M_Value` >=0 & `OB_M_Value` <51 & `DB_M_Value` >0 & `DB_M_Value` <19  & `HD_M_Value` <10  & `HD_M_Value` >1  & `HBP_M_Value` >13 & `HBP_M_Value` <46 & `HC_M_Value` >22 & `HC_M_Value` <42  & `Target_Value` >1 & `Target_Value` < 5" )
# print(df)
#
#
#
#
# ######   STATICTIS:
#
#
# (axis=0) means sum columns
# (axis=1) means sum rows
#
#
# ["TOT"] means creating new column.
# df["TOT"] = df.iloc[:, 1:7].sum(axis=1)
# df.head()
#
#
# Sum all values in each column.
# Tot_All= df.iloc[:, 0:5].sum(axis=0)
#
# Sum all columns from index [1-5]
# Tot_All= df.iloc[:, 1:5].sum(axis=0)
# Tot_All
#
# count number of the same value repeat in a column.
# new_data = df['FUEL_COST'].value_counts()
# new_data
#
# the length of the unique value in the column is 4.
# len(df.TRIP_METTERS.value_counts())
#
# the length of the unique value in the column(States) is 45 states.
# len(df.States.value_counts())
#
#
# log10 is a condence valuse of a larger number.
#
# import numpy as np
# df['death_log']= np.log10(df['StrokeDeath_Per100k'])
# print(df['death_log'])
#
# import numpy as np
# df['Trip_log']= np.log10(df['TRIP_METTERS'])
# print(df['Trip_log'])
#
#
#
# MEAN, MIN, MODE
#
# Low_value01 = min(df['HD_M_Value'])
# Low_value02 = min(df['HBP_M_Value'])
# Low_value03 = min(df['HC_M_Value'])
# Low_value04 = min(df['OB_M_Value'])
# Low_value05 = min(df['DB_M_Value'])
#
#
# np.mean(incomes)
# np.median(incomes)
# income.std()
# income.var() # variance
#
# plt.hist(income, 50) # same as bins=50
#
#
# from scipy import stats
# stats.mode(ages)

# %%
#Creating a dataframe from lists in dictionaries

import pandas as pd
import numpy as np 
import matplotlib.pylab as plt 
import seaborn as sns 
plt.style.use('ggplot')


Milage_Tracker = {
"DATE": ["1/1/2023","1/2/2023","1/3/2023","1/4/2023","1/5/2023" ], 
"LOCATION": ["Ft.Worth","Hurst","Bedford","Irving","Dallas"],
"SPEED": [50,65,75,80,90 ],
"COST_PER_GAL": [3.00, 3.00, 3.00, 3.00, 3.00 ],
"TRIP_METTERS": [200,220,250,300,315 ],
"MILES_TRAVELED": [20,30,50,70,65 ],
"GALLONS_USED": [2, 4, 5, 10, 9 ],
"FUEL_COST": [5, 8, 10, 13, 7],
"PAY_PER_MILE": [ .33, .33, .33, .33, .33  ]  
}

df = pd.DataFrame(Milage_Tracker).T
df.head() # print the first two rows
# Out:
#                      0         1         2         3         4
# DATE          1/1/2023  1/2/2023  1/3/2023  1/4/2023  1/5/2023
# LOCATION      Ft.Worth     Hurst   Bedford    Irving    Dallas
# SPEED               50        65        75        80        90
# COST_PER_GAL       3.0       3.0       3.0       3.0       3.0
# TRIP_METTERS       200       220       250       300       315

# %%
# first sort the values
# 25% percentile - value starts at 50.00, it's lower part of the range from the median
# 50% percentile - value starts at 75.00 
# 75% percentile - value starts at 90.00, it's upper part of the range from the median

df.describe().T
#df["LOCATION"].describe()
# Out:
#                 count    mean        std     min     25%     50%     75%  \
# SPEED             5.0   72.00  15.247951   50.00   65.00   75.00   80.00
# COST_PER_GAL      5.0    3.00   0.000000    3.00    3.00    3.00    3.00
# TRIP_METTERS      5.0  257.00  49.699095  200.00  220.00  250.00  300.00
# MILES_TRAVELED    5.0   47.00  21.679483   20.00   30.00   50.00   65.00
# GALLONS_USED      5.0    6.00   3.391165    2.00    4.00    5.00    9.00
# FUEL_COST         5.0    8.60   3.049590    5.00    7.00    8.00   10.00
# PAY_PER_MILE      5.0    0.33   0.000000    0.33    0.33    0.33    0.33
# TOT               5.0  385.00  88.834115  275.00  322.00  383.00  463.00
#
#                    max
# SPEED            90.00
# COST_PER_GAL      3.00
# TRIP_METTERS    315.00
# MILES_TRAVELED   70.00
# GALLONS_USED     10.00
# FUEL_COST        13.00
# PAY_PER_MILE      0.33
# TOT             482.00

# %%
new_data = df['FUEL_COST'].value_counts()
new_data
# Out:
# 5     1
# 8     1
# 10    1
# 13    1
# 7     1
# Name: FUEL_COST, dtype: int64

# %%
ax = df['FUEL_COST'].value_counts() \
    .plot(kind='bar', title ="  Tracking Fuel Cost" )
ax.set_xlabel('Five day fuel cost')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# Distribution 
ax = df['SPEED'].plot(kind='hist', bins=20)
ax.set_xlabel('(Traving MPH)')
# Out:
# Text(0.5, 0, '(Traving MPH)')

# %%
df_corr = df[['SPEED', 'FUEL_COST', 'GALLONS_USED',]].corr()
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
df.groupby(["MILES_TRAVELED"]).mean().sort_values("FUEL_COST", ascending=False)
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_11268\1043457249.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["MILES_TRAVELED"]).mean().sort_values("FUEL_COST", ascending=False)
#                 SPEED  COST_PER_GAL  TRIP_METTERS  GALLONS_USED  FUEL_COST  \
# MILES_TRAVELED
# 70               80.0           3.0         300.0          10.0       13.0
# 50               75.0           3.0         250.0           5.0       10.0
# 30               65.0           3.0         220.0           4.0        8.0
# 65               90.0           3.0         315.0           9.0        7.0
# 20               50.0           3.0         200.0           2.0        5.0
#
#                 PAY_PER_MILE
# MILES_TRAVELED
# 70                      0.33
# 50                      0.33
# ...

# %%
for index, row in df.iterrows(): # getting or reading row by row. 
    print(index, row)
# Out:
# 0 DATE              1/1/2023
# LOCATION          Ft.Worth
# SPEED                   50
# COST_PER_GAL           3.0
# TRIP_METTERS           200
# MILES_TRAVELED          20
# GALLONS_USED             2
# FUEL_COST                5
# PAY_PER_MILE          0.33
# Name: 0, dtype: object
# 1 DATE              1/2/2023
# LOCATION             Hurst
# SPEED                   65
# COST_PER_GAL           3.0
# TRIP_METTERS           220
# MILES_TRAVELED          30
# GALLONS_USED             4
# FUEL_COST                8
# PAY_PER_MILE          0.33
# Name: 1, dtype: object
# 2 DATE              1/3/2023
# LOCATION           Bedford
# SPEED                   75
# COST_PER_GAL           3.0
# TRIP_METTERS           250
# MILES_TRAVELED          50
# GALLONS_USED             5
# FUEL_COST               10
# PAY_PER_MILE          0.33
# Name: 2, dtype: object
# 3 DATE              1/4/2023
# LOCATION            Irving
# SPEED                   80
# COST_PER_GAL           3.0
# ...

# %%
for index, row in df.iterrows(): # getting all items by column name.
    print(index, row["TRIP_METTERS"])
# Out:
# 0 200
# 1 220
# 2 250
# 3 300
# 4 315

# %%
print(df.iloc[2, 1])
# Out:
# Bedford

# %%
#df.sort_values("TRIP_METTERS")
df.sort_values(["TRIP_METTERS", "FUEL_COST"])
# Out:
#        DATE  LOCATION  SPEED  COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  \
# 0  1/1/2023  Ft.Worth     50           3.0           200              20
# 1  1/2/2023     Hurst     65           3.0           220              30
# 2  1/3/2023   Bedford     75           3.0           250              50
# 3  1/4/2023    Irving     80           3.0           300              70
# 4  1/5/2023    Dallas     90           3.0           315              65
#
#    GALLONS_USED  FUEL_COST  PAY_PER_MILE
# 0             2          5          0.33
# 1             4          8          0.33
# 2             5         10          0.33
# 3            10         13          0.33
# 4             9          7          0.33

# %%
df.head()
# Out:
#        DATE  LOCATION  SPEED  COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  \
# 0  1/1/2023  Ft.Worth     50           3.0           200              20
# 1  1/2/2023     Hurst     65           3.0           220              30
# 2  1/3/2023   Bedford     75           3.0           250              50
# 3  1/4/2023    Irving     80           3.0           300              70
# 4  1/5/2023    Dallas     90           3.0           315              65
#
#    GALLONS_USED  FUEL_COST  PAY_PER_MILE
# 0             2          5          0.33
# 1             4          8          0.33
# 2             5         10          0.33
# 3            10         13          0.33
# 4             9          7          0.33

# %%
# Adding column using init location
# : means select all rows in the columns
#  1:5 means select column 1-5
# sum(axis=1) means adding honzontally 
df["TOT"] = df.iloc[:, 1:7].sum(axis=1)
df.head()
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_11268\1800124257.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df["TOT"] = df.iloc[:, 1:7].sum(axis=1)
#        DATE  LOCATION  SPEED  COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  \
# 0  1/1/2023  Ft.Worth     50           3.0           200              20
# 1  1/2/2023     Hurst     65           3.0           220              30
# 2  1/3/2023   Bedford     75           3.0           250              50
# 3  1/4/2023    Irving     80           3.0           300              70
# 4  1/5/2023    Dallas     90           3.0           315              65
#
#    GALLONS_USED  FUEL_COST  PAY_PER_MILE    TOT
# 0             2          5          0.33  275.0
# 1             4          8          0.33  322.0
# 2             5         10          0.33  383.0
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'LOCATION', 'SPEED', 'COST_PER_GAL', 'TRIP_METTERS',
#        'MILES_TRAVELED', 'GALLONS_USED', 'FUEL_COST', 'PAY_PER_MILE', 'TOT'],
#       dtype='object')

# %%
# Using filter
# Getting items that meet specifiction value or str.
df.loc[df["TRIP_METTERS"] != 250 ]
# Out:
#        DATE  LOCATION  SPEED  COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  \
# 0  1/1/2023  Ft.Worth     50           3.0           200              20
# 1  1/2/2023     Hurst     65           3.0           220              30
# 3  1/4/2023    Irving     80           3.0           300              70
# 4  1/5/2023    Dallas     90           3.0           315              65
#
#    GALLONS_USED  FUEL_COST  PAY_PER_MILE    TOT
# 0             2          5          0.33  275.0
# 1             4          8          0.33  322.0
# 3            10         13          0.33  463.0
# 4             9          7          0.33  482.0

# %%
import re
df.loc[df["DATE"].str.contains("1/1/2023", regex=True)]
# Out:
#        DATE  LOCATION  SPEED  COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  \
# 0  1/1/2023  Ft.Worth     50           3.0           200              20
#
#    GALLONS_USED  FUEL_COST  PAY_PER_MILE    TOT
# 0             2          5          0.33  275.0
