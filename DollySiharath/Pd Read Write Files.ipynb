# %% [markdown]
# %pip install scikit-learn  --upgrade --force
# #from sklearn.linear_model import LinearRegression
# #from sklearn.model_selection import train_test_split
#
# #### Step-By-Step
# ###### Step 1: Opening and reading a file.
# ###### Step 2: Reading a file from different types:   cvs, txt, xlsx ...ect.
# ###### Step 3: Converting different file types into the dataframe(colums/rows).
# ###### Step 4: Verifiy the file headers, data type and data in th columns.
# ###### Step 5: Filtering and Sorting.
#
#
#
#
# File Options: Reading a file from cvs, txt, xlsx ...ect.
#
# Example:
# df = pd.read_csv("mortality_wide.csv" )
#
# for df in pd.read_csv("mortality_wide.csv", chunksize=1000):
# print(df)
#
# for df in pd.read_csv("C:/Diff/STROKEDatasets/2016_Mortality_Age35_Plus.csv", chunksize=100):
#     print(df)
#
#
# df = pd.read_csv("mortality_wide.txt, delmiter="\t" )
# df = pd.read_csv("mortality_wide.txt, delmiter="xxx" )
# df = pd.read_lxsx("mortality_wide.xlsx" )
#
# Stroke_Dataset_2015 = "C:/Diff/STROKEDatasets/2015_Mortality_Age35_Plus.csv"
# poke = pd.read_csv(Stroke_Dataset_2015)
# print(poke.head())
#
# ##### Step 3
# Converting different file types into the dataframe(colums/rows).
#
# Example: Create a dataframe
# df = pd.DataFrame(Stroke_Dataset_2015)
# df
#
# ###### Step 4:
# Verifiy the file headers, tails,  data type  ect.
#
# Options to use when analyzing data set:
#  #df.tail(2)
#  #df.shape  # print rows and columns in tuple.
#  #rows, columns = df.shape
#  #df.columns # will print all the column names.
#  #df.DATE # will print the entire column called "DATE".
#  #df[["DATE", "FUEL_COST_PER_GAL" ]]  # print multliple columns as a list.
#  #print(df["ColumnName"][0:5]) # print top 5 columns.
#  #print(df.ColumnName) # will print a column.
#  print(df[["col1", "col2", "col"]])  # create a list of multiple columns and print.
#
# Options with accessing or getting data in the rows:
#  #df[2:5]  # get row 2 - 4.
#  #print(df.iloc[1])  get the first index.
#  #print(df.iloc[1:4]) get the first - fourth.
#  #print(df.iloc[2, 1])   get the value from of the second "[2, 1]" row in the first position or cell of the column.
#
# for index, row in df.iterrows(): # getting or reading row by row.
#     print(index, row)
#
# for index, row in df.iterrows(): # getting or reading row by row.
#     print(index, row["TRIP_METTERS"])
#
# ###### Filtering
# Using filter to get specific row that has specific key value
# TRIP_METTERS is the column name.
#
# df.loc[df["TRIP_METTERS"] == 250 ]
# df.loc[df["TRIP_METTERS"] == "xxxxx"]
#
# ###### Sorting - Passing in column names.
# ascending=[1,0]
# 1 means sort the first column asce
# 0 means sort the second column dece
#
# #df.sort_values("TRIP_METTERS")
# df.sort_values("TRIP_METTERS","GALLONS_USED", ascending=False)
# df.sort_values(["TRIP_METTERS", "FUEL_COST"])
# df.sort_values(["TRIP_METTERS", "FUEL_COST"], ascending=[1,0])
#
# ###### Adding Column
#
#  Adding column using init location
#  : means select all rows in the columns
#   1:5 means select column 1-5
#  sum(axis=1) means adding honzontally
#  sum(axis=0) means adding vertically
#
# df["TOT"] = df.iloc[:, 1:7].sum(axis=1)
# df.head()

# %%
# r for reading
# w for writing
# a for pending
# r+ for read and write

f = open ("C:/Diff/test.txt", "w")
print(f.name)
print(f.mode)
f.close()
# Out:
# C:/Diff/test.txt
# w

# %%
# This method will open and close the file when you leave this block of code. 

with open ("C:/Diff/test.txt", "r+") as f:
    file_contents = f.read()
    print(file_contents)

# %% [markdown]
# ###  How to creating a dataframe from lists in dictionaries

# %% [markdown]
# import os
# import pandas as pd
# master_df_01 = pd.DataFrame()
#
# for file in os.listdir(os.getcwd()):
#     if file.endswith('.csv'):
#         master_df_01 = master_df_01.append(pd.read_csv(file))
#
# master_df_01.to_csv('Master_df01.csv', index=False)

# %%
import pandas as pd

Milage_Tracker = {
"DATE": ["1/1/2023","1/2/2023","1/3/2023","1/4/2023","1/5/2023" ], 
"FUEL_COST_PER_GAL": [3.00, 3.00, 3.00, 3.00, 3.00 ],
"TRIP_METTERS": [200,200,250,300,315 ],
"MILES_TRAVELED": [20,30,50,50,15 ],
"GALLONS_USED": [2, 2, 4, 4, 1 ],
"FUEL_COST": [4,6, 10, 19,4 ],
"CO_PAYS_PER_MILE": [ .33, .33, .33, .33, .33  ]  
}

df = pd.DataFrame(Milage_Tracker)
df.head() # print the first two rows
# Out:
#        DATE  FUEL_COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  GALLONS_USED  \
# 0  1/1/2023                3.0           200              20             2
# 1  1/2/2023                3.0           200              30             2
# 2  1/3/2023                3.0           250              50             4
# 3  1/4/2023                3.0           300              50             4
# 4  1/5/2023                3.0           315              15             1
#
#    FUEL_COST  CO_PAYS_PER_MILE
# 0          4              0.33
# 1          6              0.33
# 2         10              0.33
# 3         19              0.33
# 4          4              0.33

# %%
type(df.DATE[0])
# Out:
# str

# %%
df.dtypes
# Out:
# DATE                  object
# FUEL_COST_PER_GAL    float64
# TRIP_METTERS           int64
# MILES_TRAVELED         int64
# GALLONS_USED           int64
# FUEL_COST              int64
# CO_PAYS_PER_MILE     float64
# dtype: object

# %%
# change data type from str to date.
pd.to_datetime(df['DATE'])
# Out:
# 0   2023-01-01
# 1   2023-01-02
# 2   2023-01-03
# 3   2023-01-04
# 4   2023-01-05
# Name: DATE, dtype: datetime64[ns]

# %%
for index, row in df.iterrows(): # getting or reading row by row. 
    print(index, row)
# Out:
# 0 DATE                 1/1/2023
# FUEL_COST_PER_GAL         3.0
# TRIP_METTERS              200
# MILES_TRAVELED             20
# GALLONS_USED                2
# FUEL_COST                   4
# CO_PAYS_PER_MILE         0.33
# Name: 0, dtype: object
# 1 DATE                 1/2/2023
# FUEL_COST_PER_GAL         3.0
# TRIP_METTERS              200
# MILES_TRAVELED             30
# GALLONS_USED                2
# FUEL_COST                   6
# CO_PAYS_PER_MILE         0.33
# Name: 1, dtype: object
# 2 DATE                 1/3/2023
# FUEL_COST_PER_GAL         3.0
# TRIP_METTERS              250
# MILES_TRAVELED             50
# GALLONS_USED                4
# FUEL_COST                  10
# CO_PAYS_PER_MILE         0.33
# Name: 2, dtype: object
# 3 DATE                 1/4/2023
# FUEL_COST_PER_GAL         3.0
# TRIP_METTERS              300
# MILES_TRAVELED             50
# GALLONS_USED                4
# FUEL_COST                  19
# CO_PAYS_PER_MILE         0.33
# ...

# %%
for index, row in df.iterrows(): # getting or reading row by row. 
    print(index, row["TRIP_METTERS"])
# Out:
# 0 200
# 1 200
# 2 250
# 3 300
# 4 315

# %%
print(df.iloc[2, 1])
# Out:
# 3.0

# %%
#df.sort_values("TRIP_METTERS")
df.sort_values(["TRIP_METTERS", "FUEL_COST"])
# Out:
#        DATE  FUEL_COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  GALLONS_USED  \
# 0  1/1/2023                3.0           200              20             2
# 1  1/2/2023                3.0           200              30             2
# 2  1/3/2023                3.0           250              50             4
# 3  1/4/2023                3.0           300              50             4
# 4  1/5/2023                3.0           315              15             1
#
#    FUEL_COST  CO_PAYS_PER_MILE
# 0          4              0.33
# 1          6              0.33
# 2         10              0.33
# 3         19              0.33
# 4          4              0.33

# %%
import numpy as np
df.head()
# Out:
#        DATE  FUEL_COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  GALLONS_USED  \
# 0  1/1/2023                3.0           200              20             2
# 1  1/2/2023                3.0           200              30             2
# 2  1/3/2023                3.0           250              50             4
# 3  1/4/2023                3.0           300              50             4
# 4  1/5/2023                3.0           315              15             1
#
#    FUEL_COST  CO_PAYS_PER_MILE
# 0          4              0.33
# 1          6              0.33
# 2         10              0.33
# 3         19              0.33
# 4          4              0.33

# %%
# count number of the same value repeat in a column. 
new_data = df['FUEL_COST'].value_counts()
new_data
# Out:
# 4     2
# 6     1
# 10    1
# 19    1
# Name: FUEL_COST, dtype: int64

# %%
# the length of the unique value in the column is 4.
len(df.TRIP_METTERS.value_counts())
# Out:
# 4

# %%
# Adding column using init location
# : means select all rows in the columns
#  1:5 means select column 1-5
# sum(axis=1) means adding honzontally 
df["TOT"] = df.iloc[:, 1:7].sum(axis=1)
df.head()
# Out:
#        DATE  FUEL_COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  GALLONS_USED  \
# 0  1/1/2023                3.0           200              20             2
# 1  1/2/2023                3.0           200              30             2
# 2  1/3/2023                3.0           250              50             4
# 3  1/4/2023                3.0           300              50             4
# 4  1/5/2023                3.0           315              15             1
#
#    FUEL_COST  CO_PAYS_PER_MILE     TOT
# 0          4              0.33  229.33
# 1          6              0.33  241.33
# 2         10              0.33  317.33
# 3         19              0.33  376.33
# 4          4              0.33  338.33

# %%
# Sum all values in each column.
#Tot_All= df.iloc[:, 0:5].sum(axis=0)
Tot_All= df.iloc[:, 1:5].sum(axis=0)
Tot_All
# Out:
# FUEL_COST_PER_GAL      15.0
# TRIP_METTERS         1265.0
# MILES_TRAVELED        165.0
# GALLONS_USED           13.0
# dtype: float64

# %%
import numpy as np
df['Trip_log']= np.log10(df['TRIP_METTERS'])
print(df['Trip_log'])
# Out:
# 0    2.301030
# 1    2.301030
# 2    2.397940
# 3    2.477121
# 4    2.498311
# Name: Trip_log, dtype: float64

# %% [markdown]
# ### Reading files from URL
# #### Sample code:
#
# import pandas as pd
# poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
# polls = pd.read_csv(poll_url)
# polls

# %%
import pandas as pd
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)
polls
# Out:
#        cycle     branch        type                        matchup  \
# 0       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state   startdate    enddate  \
# 0          11/8/16           U.S.   11/3/2016  11/6/2016
# ...

# %% [markdown]
# ### Reading the file stored locally in the c: dir.

# %%
import os

# %%
# Must change the path -  forward \ to backward / 
import pandas as pd
test = "C:/Diff/Python/Stroke_Project/test.csv"
test = pd.read_csv(test)
test
# Out:
#     Year LocationAbbr         LocationDesc GeographicLevel DataSource  \
# 0   2015           SD         South Dakota           State       NVSS
# 1   2015           MT        Fergus County          County       NVSS
# 2   2015           WV        West Virginia           State       NVSS
# 3   2015           MN            Minnesota           State       NVSS
# 4   2015           MS        Alcorn County          County       NVSS
# 5   2015           ID                Idaho           State       NVSS
# 6   2015           MD  Queen Anne's County          County       NVSS
# 7   2015           OH        Holmes County          County       NVSS
# 8   2015           WY              Wyoming           State       NVSS
# 9   2015           WV       Raleigh County          County       NVSS
# 10  2015           OR       Sherman County          County       NVSS
# 11  2015           IN        Porter County          County       NVSS
# ...

# %%
# Using filter to get specific row that has specific key value
df.loc[df["TRIP_METTERS"] == 250 ]
# Out:
#        DATE  FUEL_COST_PER_GAL  TRIP_METTERS  MILES_TRAVELED  GALLONS_USED  \
# 2  1/3/2023                3.0           250              50             4
#
#    FUEL_COST  CO_PAYS_PER_MILE     TOT
# 2         10              0.33  317.33
