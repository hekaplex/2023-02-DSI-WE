# %%
# !pip install openpyxl  
import os
import pandas as pd 
import numpy as np 
import matplotlib.pylab as plt
import matplotlib.pyplot as plt 


plt.style.use('fivethirtyeight') 

import seaborn as sns 
sns.set_style('darkgrid')

# %matplotlib inline

# %pip install scikit-learn  --upgrade --force
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df01 = pd.read_csv("MasterFile_6-1-23.csv", index_col=0)
df_ML_01 = pd.read_csv("MasterFile_6-1-23.csv" )
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.2.2-cp311-cp311-win_amd64.whl (8.3 MB)
# Collecting numpy>=1.17.3
#   Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
# Collecting scipy>=1.3.2
#   Using cached scipy-1.10.1-cp311-cp311-win_amd64.whl (42.2 MB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.1.0
#     Uninstalling threadpoolctl-3.1.0:
#       Successfully uninstalled threadpoolctl-3.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\dolly\\AppData\\Local\\r-miniconda\\envs\\datascience-pro-env\\Lib\\site-packages\\~%1py\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.

# %%
#df01.shape
#df01.head
#df01.info
#df01.describe().T

# %%
#print(df01['DB_Values'].describe())
#print(df01['DB_Low'].describe())
#print(df01['DB_High'].describe())

# %%
sns.distplot(df01['DB_Values'])
sns.distplot(df01['DB_Low'])
sns.distplot(df01['DB_High'])
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\3262892573.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['DB_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\3262892573.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['DB_Low'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\3262892573.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['DB_High'])
# <Axes: xlabel='DB_High', ylabel='Density'>

# %%
sns.distplot(df01['OB_Values'])
sns.distplot(df01['OB_Low'])
sns.distplot(df01['OB_High'])
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2169553720.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['OB_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2169553720.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['OB_Low'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2169553720.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['OB_High'])
# <Axes: xlabel='OB_High', ylabel='Density'>

# %%
sns.distplot(df01['HC_Values'])
sns.distplot(df01['HC_Low'])
sns.distplot(df01['HC_High'])
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\501032911.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HC_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\501032911.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HC_Low'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\501032911.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HC_High'])
# <Axes: xlabel='HC_High', ylabel='Density'>

# %%
sns.distplot(df01['HD_Values'])
sns.distplot(df01['HD_Low'])
sns.distplot(df01['HD_High'])
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\3150249995.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HD_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\3150249995.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HD_Low'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\3150249995.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HD_High'])
# <Axes: xlabel='HD_High', ylabel='Density'>

# %%
sns.distplot(df01['HBP_Values'])
sns.distplot(df01['HBP_Low'])
sns.distplot(df01['HBP_High'])
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\167383946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HBP_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\167383946.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HBP_Low'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\167383946.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HBP_High'])
# <Axes: xlabel='HBP_High', ylabel='Density'>

# %%
sns.distplot(df01['DB_Values'])
sns.distplot(df01['OB_Values'])

plt.xlabel('Diabestes vs. Obesity Population')
plt.ylabel('Median Measure(Density)')
#plt.title('Diabestes vs. Obesity')
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2273295914.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['DB_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2273295914.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['OB_Values'])
# Text(0, 0.5, 'Median Measure(Density)')

# %%
sns.distplot(df01['HC_Values'])
sns.distplot(df01['HD_Values'])
sns.distplot(df01['HBP_Values'])

plt.xlabel('High Cho vs. Heart Dis vs. Blood Pressure')
plt.ylabel('Median Measure(Density)')
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2639719328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HC_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2639719328.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HD_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2639719328.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df01['HBP_Values'])
# Text(0, 0.5, 'Median Measure(Density)')

# %%
df01.columns
# Out:
# Index(['States', 'DB_Values', 'DB_Low', 'DB_High', 'OB_Values', 'OB_Low',
#        'OB_High', 'HD_Values', 'HD_Low', 'HD_High', 'HC_Values', 'HC_Low',
#        'HC_High', 'HBP_Values', 'HBP_Low', 'HBP_High', 'TargetStroke'],
#       dtype='object')

# %%
# Extract Skewness before removing the outliers.

from scipy.stats import skew

HD_skew = skew(df01['HD_Values'])
HBP_skew = skew(df01['HBP_Values'])
HC_skew = skew(df01['HC_Values'])

OB_skew = skew(df01['OB_Values'])
DB_skew = skew(df01['DB_Values'])
STK_skew = skew(df01['TargetStroke'])

print(HD_skew)
print(HBP_skew)
print(HC_skew)
print(OB_skew)
print(DB_skew)
print(STK_skew)
# Out:
# 1.1055321824198625
# 0.690516831912011
# -0.6871016716073917
# 0.44821168348121687
# 0.9599236300680255
# 1.964167010165808

# %%
red_circle = dict(markerfacecolor='red', marker='o') ## outliers
mean_shape = dict(markerfacecolor='green', marker='D', markeredgecolor='green') ## 

plt.boxplot(x=df01['DB_Values'], vert=True, flierprops=red_circle, showmeans=True, meanprops=mean_shape, notch=True);

# %%
red_circle = dict(markerfacecolor='red', marker='o') ## outliers
mean_shape = dict(markerfacecolor='green', marker='D', markeredgecolor='green') ## 

plt.boxplot(x=df01['DB_Low'], vert=True, flierprops=red_circle, showmeans=True, meanprops=mean_shape, notch=True);

# %%
red_circle = dict(markerfacecolor='red', marker='o') ## outliers
mean_shape = dict(markerfacecolor='green', marker='D', markeredgecolor='green') ## 

plt.boxplot(x=df01['DB_High'], vert=True, flierprops=red_circle, showmeans=True, meanprops=mean_shape, notch=True);

# %%
red_circle = dict(markerfacecolor='red', marker='o') ## outliers
mean_shape = dict(markerfacecolor='green', marker='D', markeredgecolor='green') ## 

plt.boxplot(x=df01['TargetStroke'], vert=True, flierprops=red_circle, showmeans=True, meanprops=mean_shape, notch=True);

# %%
df01.columns
# Out:
# Index(['States', 'DB_Values', 'DB_Low', 'DB_High', 'OB_Values', 'OB_Low',
#        'OB_High', 'HD_Values', 'HD_Low', 'HD_High', 'HC_Values', 'HC_Low',
#        'HC_High', 'HBP_Values', 'HBP_Low', 'HBP_High', 'TargetStroke'],
#       dtype='object')

# %%
# dropping for the subplot - boxplots below
df02 = df01.drop(columns=[ "States" ])
df02 = df02.rename(columns={'DB_Values':'Diab', 'OB_Values':'Obes','HC_Values':'HgCho', 'HD_Values':'HtDis', 'HBP_Values':'HbpPrs'})

# %%
#Subplot

red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')
fig, axs = plt.subplots(1, len(df02.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(df02.iloc[:,i], flierprops=red_circle) # exclude row#0 and #1
    ax.set_title(df02.columns[i], fontsize=20, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    
plt.show()

# %%
# check the corr against the Target_value.
df01.corr()['TargetStroke']
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\3642055622.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df01.corr()['TargetStroke']
# DB_Values       0.137260
# DB_Low          0.135513
# DB_High         0.138664
# OB_Values       0.215474
# OB_Low          0.212521
# OB_High         0.218455
# HD_Values       0.140528
# HD_Low          0.142278
# HD_High         0.137892
# HC_Values       0.069340
# HC_Low          0.066839
# HC_High         0.071824
# HBP_Values      0.180633
# HBP_Low         0.179951
# HBP_High        0.181334
# TargetStroke    1.000000
# Name: TargetStroke, dtype: float64

# %%
#Heatmap - illustrate from the low to high scales.  It  shows which is skewed to the lower or higher end or from the median.

plt.title('Risk Factors vs. Target Stroke')
plt.tight_layout()
df_corr = df02[['Diab',  'Obes',  'HtDis','HgCho',  'HbpPrs', 'TargetStroke']].corr()
sns.heatmap(df_corr, annot=True)
plt.show()

# %%
# Verifying the unique values and outliers -  

#print(df01['TargetStroke'].value_counts())
#print(df01['HBP_Values'].value_counts())
#print(df01['HBP_Low'].value_counts())
#print(df01['HBP_High'].value_counts())

# %%
# Filter out the outliers based on conditions and the boxplot. 

#df_DB01 = df01.query("`DB_Values` >=1.5 & `DB_Values` <=18 " )
#df_DB02 = df01.query("`DB_Low` <=15.5" )
#df_DB03 = df01.query("`DB_High` <=19" )

#df_OB01 = df01.query("`OB_Values` <=50 " )
#df_OB02 = df01.query(" `OB_Low` <=49" )
#df_OB03 = df01.query("`OB_High` <=52 " )


#df_HD01 = df01.query("`HD_Values` >=1.0 & `HD_Values` <=9.5  " )
#df_HD02 = df01.query(" `HD_Low` >=1.0 & `HD_Low` <=8.5 " )
#df_HD03 = df01.query(" `HD_High` >=1.0 & `HD_High` <=10.5 " )

#df_HC01 = df01.query("`HC_Values` >=22.0 & `HC_Values` <=41.5  " )
#df_HC02 = df01.query(" `HC_Low` >=23.0 & `HC_Low` <=39.0 " )
#df_HC03 = df01.query(" `HC_High` >=23.0 & `HC_High` <=42.0 " )


#df_HBP01 = df01.query("`HBP_Values` >=14.0 & `HBP_Values` <=45.0  " )
#df_HBP02 = df01.query(" `HBP_Low` >=12.5 & `HBP_Low` <=44.0 " )
#df_HBP03 = df01.query(" `HBP_High` >=14.0 & `HBP_High` <=46.5 " )

#df_STK01 = df01.query("`TargetStroke` >=1.5 & `TargetStroke` <=10 " )

# %%
df_ML = df01.query("`DB_Values` >=2.0 & `DB_Values` <=18 &   `DB_Low` <=15.5   &  `DB_High` >=2.5  & `DB_High` <=17   & `OB_Values` <=45 & `OB_Low` <=49 & `OB_High` >=12.0 & `OB_High` <=52 & `HD_Values` >=1.5 & `HD_Values` <=8.5 & \
    `HD_Low` >=1.0 & `HD_Low` <=8.5 & `HD_High` >=2.0 & `HD_High` <=8.5 & `HC_Values` >=22.0 & `HC_Values` <=41.5 & `HC_Low` >=23.0 & `HC_Low` <=39.0 & `HC_High` >=23.0 & `HC_High` <=41.0 & `HBP_Values` >=15.0 & `HBP_Values` <=43.0 & `HBP_Low` >=13.5 & `HBP_Low` <=41.0 & `HBP_High` >=14.0 & `HBP_High` <=42.5 & `TargetStroke` >=1.5 & `TargetStroke` <=10 " )

df_ML
# Out:
#                   States  DB_Values  DB_Low  DB_High  OB_Values  OB_Low  \
# Year_Obv
# 2017Tracts1          AK1        7.4     6.9      7.8       36.3    35.0
# 2017Tracts2          AK2        8.9     8.3      9.6       33.5    32.1
# 2017Tracts3          AK3        8.2     7.8      8.6       39.0    38.2
# 2017Tracts4          AK4        6.1     5.4      6.8       33.4    32.0
# 2017Tracts5          AK5        7.3     6.7      7.9       33.2    31.5
# ...                  ...        ...     ...      ...        ...     ...
# 2017Tracts28000  WY28000        9.0     8.2      9.9       28.9    27.6
# 2017Tracts28001  WY28001        7.4     6.9      7.9       29.7    28.4
# 2017Tracts28002  WY28002        8.9     8.1      9.7       28.4    26.9
# 2017Tracts28003  WY28003        9.1     8.3      9.9       27.2    26.0
# 2017Tracts28004  WY28004        8.3     7.8      8.9       27.3    25.8
#
#                  OB_High  HD_Values  HD_Low  HD_High  HC_Values  HC_Low  \
# Year_Obv
# 2017Tracts1         37.6        4.2     3.9      4.6       32.3    31.1
# 2017Tracts2         34.7        4.7     4.5      5.0       33.0    32.4
# 2017Tracts3         39.8        5.8     5.2      6.4       31.9    31.3
# 2017Tracts4         34.8        4.4     4.1      4.8       29.3    28.5
# 2017Tracts5         34.6        4.0     3.6      4.4       31.4    30.6
# ...                  ...        ...     ...      ...        ...     ...
# 2017Tracts28000     30.3        3.3     2.9      3.6       29.4    28.6
# 2017Tracts28001     31.0        4.9     4.4      5.4       30.8    29.8
# 2017Tracts28002     29.8        6.7     5.9      7.5       32.9    31.9
# 2017Tracts28003     28.4        5.2     4.7      5.7       31.6    30.7
# 2017Tracts28004     28.7        4.8     4.5      5.2       32.5    31.2
#
#                  HC_High  HBP_Values  HBP_Low  HBP_High  TargetStroke
# Year_Obv
# 2017Tracts1         33.4        32.3     30.7      34.0           2.2
# 2017Tracts2         33.6        28.3     26.8      29.8           2.2
# 2017Tracts3         32.4        33.8     32.4      35.1           2.2
# 2017Tracts4         30.2        27.4     26.7      28.1           2.2
# 2017Tracts5         32.2        33.0     32.4      33.6           2.2
# ...                  ...         ...      ...       ...           ...
# 2017Tracts28000     30.1        20.8     20.0      21.7           2.8
# 2017Tracts28001     31.9        32.5     31.0      34.0           3.2
# 2017Tracts28002     33.9        31.3     30.1      32.6           3.0
# 2017Tracts28003     32.5        31.9     30.7      33.1           2.3
# 2017Tracts28004     33.7        30.6     29.8      31.3           2.3
#
# [16728 rows x 17 columns]

# %%
#Testing and filter out the outliers
#red_circle = dict(markerfacecolor='red', marker='o') ## outliers
#mean_shape = dict(markerfacecolor='green', marker='D', markeredgecolor='green') 
#plt.boxplot(x=df_STK01['TargetStroke'], vert=True, flierprops=red_circle, showmeans=True, meanprops=mean_shape, notch=True);

# %%
sns.distplot(df_ML['DB_Values'])
sns.distplot(df_ML['OB_Values'])

plt.xlabel('Diabestes vs. Obesity Population')
plt.ylabel('Median Measure(Density)')
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2451244908.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_ML['DB_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\2451244908.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_ML['OB_Values'])
# Text(0, 0.5, 'Median Measure(Density)')

# %%
df_ML.describe().T
# Out:
#                 count       mean       std   min   25%    50%   75%   max
# DB_Values     16728.0   9.633040  2.761343   2.2   7.7   9.50  11.5  16.3
# DB_Low        16728.0   9.031396  2.639774   1.9   7.1   8.90  10.8  15.5
# DB_High       16728.0  10.247591  2.881094   2.5   8.2  10.15  12.2  17.0
# OB_Values     16728.0  28.408772  6.766759  11.0  23.5  28.20  32.9  45.0
# OB_Low        16728.0  27.285811  6.691828   9.7  22.3  27.00  31.7  44.3
# OB_High       16728.0  29.492548  6.818684  12.0  24.6  29.40  34.1  47.0
# HD_Values     16728.0   5.000490  1.306585   1.7   4.1   5.00   5.9   8.1
# HD_Low        16728.0   4.586155  1.206168   1.5   3.7   4.60   5.4   7.8
# HD_High       16728.0   5.448990  1.423655   2.0   4.5   5.40   6.4   8.5
# HC_Values     16728.0  31.463825  3.373796  23.4  29.2  31.60  33.7  40.0
# HC_Low        16728.0  30.682661  3.309421  23.0  28.4  30.80  32.9  39.0
# HC_High       16728.0  32.267597  3.447057  23.9  30.0  32.10  34.6  41.0
# HBP_Values    16728.0  28.392157  5.338931  15.0  24.8  28.30  31.9  41.7
# HBP_Low       16728.0  27.412016  5.250029  13.6  23.9  27.20  30.8  41.0
# HBP_High      16728.0  29.361561  5.418749  15.5  25.7  29.30  33.0  42.5
# TargetStroke  16728.0   2.819369  1.115798   1.5   2.2   2.20   3.1   9.9

# %%
# Looking at the data and compare with each other features (break down the each data).
# 25% - 50% of the stroke patient are in the 2.2 percentile.
np.percentile(df_ML['TargetStroke'],25)
# Out:
# 2.2

# %%
np.percentile(df_ML['TargetStroke'],50)
# Out:
# 2.2

# %%
np.percentile(df_ML['TargetStroke'],50)
# Out:
# 2.2

# %%
np.percentile(df_ML['TargetStroke'],70)
# Out:
# 2.9

# %%
np.percentile(df_ML['TargetStroke'],80)
# Out:
# 3.4

# %%
np.percentile(df_ML['TargetStroke'],90)
# Out:
# 4.2

# %%
np.percentile(df_ML['TargetStroke'],95)
# Out:
# 5.2

# %%
np.percentile(df_ML['TargetStroke'],100)
# Out:
# 9.9

# %%
sns.distplot(df_ML['HC_Values'])
sns.distplot(df_ML['HD_Values'])
sns.distplot(df_ML['HBP_Values'])

plt.xlabel('High Cho vs. Heart Dis vs. Blood Pressure')
plt.ylabel('Median Measure(Density)')
# Out:
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\674226067.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_ML['HC_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\674226067.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_ML['HD_Values'])
# C:\Users\dolly\AppData\Local\Temp\ipykernel_2624\674226067.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_ML['HBP_Values'])
# Text(0, 0.5, 'Median Measure(Density)')

# %%
# dropping for the subplot - boxplots below
df_ML_box = df_ML.drop(columns=[ "States" ])
df_boxplot = df_ML_box.rename(columns={'DB_Values':'Diab', 'OB_Values':'Obs','HC_Values':'HgCh', 'HD_Values':'HtDs', 'HBP_Values':'Hbp'})

# %%
#Subplot

red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')
fig, axs = plt.subplots(1, len(df_boxplot.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(df_boxplot.iloc[:,i], flierprops=red_circle) # exclude row#0 and #1
    ax.set_title(df_boxplot.columns[i], fontsize=20, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    
plt.show()

# %%
col_to_plot01 = ['DB_Values', 'OB_Values', 'HD_Values', 'HC_Values', 'HBP_Values']
sns.pairplot(df_ML[col_to_plot01], diag_kind='kde', kind='reg', plot_kws={'line_kws':{'color':'brown'}})

# %%
#Heatmap after dropping the outliers - illustrate from the low to high scales.  It  shows which is skewed to the lower or higher end or from the median.

plt.title('Risk Factors vs. Target Stroke')
plt.tight_layout()
df_corr = df_ML[['DB_Values',  'OB_Values',  'HD_Values',  'HC_Values', 'HBP_Values', 'TargetStroke']].corr()
sns.heatmap(df_corr, annot=True)
plt.show()

# %%
#df_ML.describe().T

# %%
#df_dummies_01 = pd.get_dummies(df_ML.Year_Obv)
df_dummies_02 = pd.get_dummies(df_ML.States)

# %%
# last column->  2017Tracts9999
#df_dummies_01.tail()

# %%
# last column-> WY28004 
#df_dummies_02.tail()

# %%
# Only merging the stateName (Dummies)
df_merged = pd.concat([df_ML, df_dummies_02],axis='columns')
#df_merged

# %%
# Dropping - including the target -> 'TargetStroke'
df_Final = df_merged.drop([ 'States','TargetStroke', 'WY28004'],axis='columns' )
#df_Final

# %%
df_ML.plot.scatter(x='DB_Values', y='TargetStroke', color ='r', alpha=.07)
# Out:
# <Axes: xlabel='DB_Values', ylabel='TargetStroke'>

# %% [markdown]
# ML - Linear Regression

# %% [markdown]
# Test train split for supervised training.
# Using the testing portion to predict how well the model perform

# %%
# laod types of model to use.

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

# %%
X= df_Final
y= df_ML['TargetStroke']  # dependent feature (Stroke).
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.metrics import accuracy_score

# Fit/load into a model
modelReg = LinearRegression ()
modelReg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#=========================================
score_train = modelReg.predict(X_train)
score_test = modelReg.predict(X_test)
#-========================================

y_pred = modelReg.predict(X_test) # predict X(all factors).
modelReg.score(X_test,y_test) # See the performance (diff of actual value(y_test) from predicted X_test)
# Out:
# 0.07199678544131494

# %%
# Creating new df for the results. What is the probility of someone have the stroke based on the results.
pred_y_df = pd.DataFrame({'Actual Stroke Value':y_test, 'Predicted Value':y_pred, 'absErrors':abs(y_test-y_pred),  'Sqr':(y_test-y_pred)*(y_test-y_pred),  'Percentage_Err':((abs(y_pred - y_test)) / y_test) * 100 })
pred_y_df[0:20]
# Out:
#                  Actual Stroke Value  Predicted Value  absErrors       Sqr  \
# Year_Obv
# 2017Tracts4112                   2.2         2.175991   0.024009  0.000576
# 2017Tracts5896                   2.2         2.715701   0.515701  0.265947
# 2017Tracts21344                  2.1         2.454907   0.354907  0.125959
# 2017Tracts23509                  2.1         3.304205   1.204205  1.450111
# 2017Tracts23252                  2.3         3.068623   0.768623  0.590781
# 2017Tracts16092                  5.4         2.747160   2.652840  7.037560
# 2017Tracts15477                  2.1         2.702434   0.602434  0.362927
# 2017Tracts23339                  3.4         3.024696   0.375304  0.140853
# 2017Tracts5198                   2.2         2.387595   0.187595  0.035192
# 2017Tracts75                     2.2         2.902468   0.702468  0.493461
# 2017Tracts22821                  2.1         3.044717   0.944717  0.892490
# 2017Tracts14999                  2.2         2.902359   0.702359  0.493308
# 2017Tracts18734                  4.2         2.685995   1.514005  2.292212
# 2017Tracts19408                  3.0         2.873800   0.126200  0.015926
# 2017Tracts23118                  2.6         3.641807   1.041807  1.085363
# 2017Tracts1697                   2.2         2.407936   0.207936  0.043237
# 2017Tracts25715                  2.5         3.045125   0.545125  0.297162
# 2017Tracts27353                  3.2         2.877145   0.322855  0.104235
# 2017Tracts3624                   2.2         2.893366   0.693366  0.480757
# 2017Tracts6864                   2.2         2.435529   0.235529  0.055474
#
#                  Percentage_Err
# Year_Obv
# 2017Tracts4112         1.091318
# 2017Tracts5896        23.440951
# 2017Tracts21344       16.900317
# 2017Tracts23509       57.343115
# 2017Tracts23252       33.418392
# 2017Tracts16092       49.126665
# 2017Tracts15477       28.687332
# 2017Tracts23339       11.038359
# 2017Tracts5198         8.527028
# 2017Tracts75          31.930347
# 2017Tracts22821       44.986514
# 2017Tracts14999       31.925405
# 2017Tracts18734       36.047744
# 2017Tracts19408        4.206651
# 2017Tracts23118       40.069519
# 2017Tracts1697         9.451642
# 2017Tracts25715       21.805009
# 2017Tracts27353       10.089220
# 2017Tracts3624        31.516651
# 2017Tracts6864        10.705864

# %%
print(modelReg.score(X_test,y_test))
#print(r2_score(y_test,y_pred)) # the accuracy of the prediction and the different is the errors(SSE).
print('Score', r2_score(y_test,y_pred)) # r2 = SSR / SST
print("r2:{}  ".format(r2_score(y_pred,y_test)))  

print("mae:{}  ".format(mean_absolute_error(y_pred,y_test)))
print('MAE = ', mean_absolute_error(y_pred,y_test))
#print('MAPE = ', mean_absolute_percentage_error(y_pred,y_test))  # Verify error

#==============================================================
Tot_Err = pred_y_df['absErrors'].count()
#==============================================================


# Cal. MAD
Sum_absErr = pred_y_df['absErrors'].sum()
print('MAD = ', Sum_absErr / Tot_Err)


# Cal. MSE
Tot_Sum_Sqr = Sum_Sqr = pred_y_df['Sqr'].sum()
print('MSE = ', Tot_Sum_Sqr / Tot_Err)

# Cal. MAPE
Tot_Percentage_Err = pred_y_df['Percentage_Err'].sum()
print('MAPE = ', Tot_Percentage_Err / Tot_Err)
# Out:
# 0.07199678544131494
# Score 0.07199678544131494
# r2:-10.799505489896415
# mae:0.7476061562584244
# MAE =  0.7476061562584244
# MAD =  0.7476061562584244
# MSE =  1.1836985446857624
# MAPE =  25.11700499023164

# %% [markdown]
# XGBRegressor ML Model

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\dolly\appdata\local\r-mini~1\envs\datascience-pro-env\lib\site-packages (1.7.5)
# Requirement already satisfied: numpy in c:\users\dolly\appdata\local\r-mini~1\envs\datascience-pro-env\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\dolly\appdata\local\r-mini~1\envs\datascience-pro-env\lib\site-packages (from xgboost) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from xgboost import XGBRegressor
modelXGB= XGBRegressor()
modelXGB.fit(X_train,y_train)
modelXGB.predict(X_test)
#y_test  


y_pred = modelXGB.predict(X_test) # Predicting X(all factors).
modelXGB.score(X_test,y_test) # The performance.


print('Score', r2_score(y_test,y_pred))
print("r2:{}  ".format(r2_score(y_pred,y_test)))  
print("mae:{}  ".format(mean_absolute_error(y_pred,y_test)))

print('mean_absolute_error = ', mean_absolute_error(y_pred,y_test))
print('mean_absolute_percentage_error = ', mean_absolute_percentage_error(y_pred,y_test))  # Verify error
# Out:
# Score 0.06622546428550968
# r2:-11.35539755122407
# mae:0.7382778298690941
# mean_absolute_error =  0.7382778298690941
# mean_absolute_percentage_error =  0.25962384004567896

# %%
#-=================
# Creating new df - holding values 

pred_y_XGB_df = pd.DataFrame({'Actual Stroke Value':y_test, 'Predicted Value':y_pred, 'absErrors':abs(y_test-y_pred),  'Sqr':(y_test-y_pred)*(y_test-y_pred),  'Percentage_Err':((abs(y_pred - y_test)) / y_test) * 100 })
pred_y_XGB_df [0:20]
# Out:
#                  Actual Stroke Value  Predicted Value  absErrors       Sqr  \
# Year_Obv
# 2017Tracts4112                   2.2         2.347135   0.147135  0.021649
# 2017Tracts5896                   2.2         2.837437   0.637437  0.406326
# 2017Tracts21344                  2.1         2.799413   0.699413  0.489178
# 2017Tracts23509                  2.1         3.854212   1.754212  3.077259
# 2017Tracts23252                  2.3         2.765876   0.465876  0.217041
# 2017Tracts16092                  5.4         2.630773   2.769227  7.668618
# 2017Tracts15477                  2.1         2.474144   0.374144  0.139984
# 2017Tracts23339                  3.4         2.673320   0.726680  0.528064
# 2017Tracts5198                   2.2         2.448836   0.248836  0.061920
# 2017Tracts75                     2.2         2.768493   0.568493  0.323184
# 2017Tracts22821                  2.1         2.956427   0.856427  0.733467
# 2017Tracts14999                  2.2         2.625381   0.425381  0.180949
# 2017Tracts18734                  4.2         2.533940   1.666060  2.775755
# 2017Tracts19408                  3.0         2.636485   0.363515  0.132143
# 2017Tracts23118                  2.6         3.321432   0.721432  0.520464
# 2017Tracts1697                   2.2         2.506938   0.306938  0.094211
# 2017Tracts25715                  2.5         2.612543   0.112543  0.012666
# 2017Tracts27353                  3.2         2.591790   0.608210  0.369919
# 2017Tracts3624                   2.2         2.544596   0.344596  0.118747
# 2017Tracts6864                   2.2         2.404126   0.204126  0.041667
#
#                  Percentage_Err
# Year_Obv
# 2017Tracts4112         6.687968
# 2017Tracts5896        28.974416
# 2017Tracts21344       33.305368
# 2017Tracts23509       83.533896
# 2017Tracts23252       20.255491
# 2017Tracts16092       51.281980
# 2017Tracts15477       17.816380
# 2017Tracts23339       21.372940
# 2017Tracts5198        11.310742
# 2017Tracts75          25.840599
# 2017Tracts22821       40.782220
# 2017Tracts14999       19.335500
# 2017Tracts18734       39.668088
# 2017Tracts19408       12.117163
# 2017Tracts23118       27.747389
# 2017Tracts1697        13.951705
# 2017Tracts25715        4.501724
# 2017Tracts27353       19.006556
# 2017Tracts3624        15.663463
# 2017Tracts6864         9.278440

# %%
#==============================================================
Tot_Err = pred_y_XGB_df['absErrors'].count()
#==============================================================


# Cal. MAD
Sum_absErr = pred_y_XGB_df['absErrors'].sum()
print('MAD = ', Sum_absErr / Tot_Err)


# Cal. MSE
Tot_Sum_Sqr = Sum_Sqr = pred_y_XGB_df['Sqr'].sum()
print('MSE = ', Tot_Sum_Sqr / Tot_Err)

# Cal. MAPE
Tot_Percentage_Err = pred_y_XGB_df['Percentage_Err'].sum()
print('MAPE = ', Tot_Percentage_Err / Tot_Err)

from sklearn.metrics import mean_squared_error

print('MSE = ', mean_squared_error(pred_y_XGB_df['Actual Stroke Value'], pred_y_XGB_df['Predicted Value'] ) )

#SSE - sum of sqr, the goal is to reduced SSE (compare to SSE before removing the outliers)
print("SSE = ", pred_y_XGB_df['Sqr'].sum())
# Out:
# MAD =  0.7382778298690941
# MSE =  1.1910600541567071
# MAPE =  24.465662396127808
# MSE =  1.1910600541567071
# SSE =  3985.286941208342

# %% [markdown]
# ML Analyzing using - Decision Tree Model.

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.tree import DecisionTreeRegressor

modelDT= DecisionTreeRegressor()
modelDT.fit(X_train,y_train)
modelDT.predict(X_test)
#y_test  


y_pred = modelDT.predict(X_test) # Predicting X(all factors).
modelDT.score(X_test,y_test) # The performance.
# Out:
# -0.28744764632083375

# %%
# Creating new df - holding values for Decision Tree

pred_y_DT_df = pd.DataFrame({'Actual Stroke Value':y_test, 'Predicted Value':y_pred, 'absErrors':abs(y_test-y_pred),  'Sqr':(y_test-y_pred)*(y_test-y_pred),  'Percentage_Err':((abs(y_pred - y_test)) / y_test) * 100 })
pred_y_DT_df[0:20]
# Out:
#                  Actual Stroke Value  Predicted Value     absErrors  \
# Year_Obv
# 2017Tracts4112                   2.2              2.2  1.332268e-15
# 2017Tracts5896                   2.2              2.1  1.000000e-01
# 2017Tracts21344                  2.1              2.2  1.000000e-01
# 2017Tracts23509                  2.1              3.8  1.700000e+00
# 2017Tracts23252                  2.3              2.2  1.000000e-01
# 2017Tracts16092                  5.4              2.2  3.200000e+00
# 2017Tracts15477                  2.1              2.2  1.000000e-01
# 2017Tracts23339                  3.4              1.6  1.800000e+00
# 2017Tracts5198                   2.2              2.2  1.332268e-15
# 2017Tracts75                     2.2              3.6  1.400000e+00
# 2017Tracts22821                  2.1              2.5  4.000000e-01
# 2017Tracts14999                  2.2              2.2  4.440892e-16
# 2017Tracts18734                  4.2              2.2  2.000000e+00
# 2017Tracts19408                  3.0              1.9  1.100000e+00
# 2017Tracts23118                  2.6              2.1  5.000000e-01
# 2017Tracts1697                   2.2              2.2  0.000000e+00
# 2017Tracts25715                  2.5              2.2  3.000000e-01
# 2017Tracts27353                  3.2              2.2  1.000000e+00
# 2017Tracts3624                   2.2              2.2  4.440892e-16
# 2017Tracts6864                   2.2              2.2  8.881784e-16
#
#                           Sqr  Percentage_Err
# Year_Obv
# 2017Tracts4112   1.774937e-30    6.055762e-14
# 2017Tracts5896   1.000000e-02    4.545455e+00
# 2017Tracts21344  1.000000e-02    4.761905e+00
# 2017Tracts23509  2.890000e+00    8.095238e+01
# 2017Tracts23252  1.000000e-02    4.347826e+00
# 2017Tracts16092  1.024000e+01    5.925926e+01
# 2017Tracts15477  1.000000e-02    4.761905e+00
# 2017Tracts23339  3.240000e+00    5.294118e+01
# 2017Tracts5198   1.774937e-30    6.055762e-14
# 2017Tracts75     1.960000e+00    6.363636e+01
# 2017Tracts22821  1.600000e-01    1.904762e+01
# 2017Tracts14999  1.972152e-31    2.018587e-14
# 2017Tracts18734  4.000000e+00    4.761905e+01
# 2017Tracts19408  1.210000e+00    3.666667e+01
# 2017Tracts23118  2.500000e-01    1.923077e+01
# 2017Tracts1697   0.000000e+00    0.000000e+00
# 2017Tracts25715  9.000000e-02    1.200000e+01
# 2017Tracts27353  1.000000e+00    3.125000e+01
# 2017Tracts3624   1.972152e-31    2.018587e-14
# 2017Tracts6864   7.888609e-31    4.037175e-14

# %%
print('Score', r2_score(y_test,y_pred))
print("r2:{}  ".format(r2_score(y_pred,y_test)))  
print("mae:{}  ".format(mean_absolute_error(y_pred,y_test)))

print('mean_absolute_error = ', mean_absolute_error(y_pred,y_test))
print('mean_absolute_percentage_error = ', mean_absolute_percentage_error(y_pred,y_test))  # Verify error



#==============================================================
Tot_Err = pred_y_DT_df['absErrors'].count()
#==============================================================


# Cal. MAD
Sum_absErr = pred_y_DT_df['absErrors'].sum()
print('MAD = ', Sum_absErr / Tot_Err)


# Cal. MSE
Tot_Sum_Sqr = Sum_Sqr = pred_y_DT_df['Sqr'].sum()
print('MSE = ', Tot_Sum_Sqr / Tot_Err)

# Cal. MAPE
Tot_Percentage_Err = pred_y_DT_df['Percentage_Err'].sum()
print('MAPE = ', Tot_Percentage_Err / Tot_Err)
# Out:
# Score -0.28744764632083375
# r2:-4.1175378621158005
# mae:0.7567842199641377
# mean_absolute_error =  0.7567842199641377
# mean_absolute_percentage_error =  0.31186148287628623
# MAD =  0.7567842199641377
# MSE =  1.642181709503884
# MAPE =  22.003804190884814

# %%
model_ranks=pd.Series(modelDT.feature_importances_,index=X_train.columns,name='Importance')
ax=model_ranks.plot(kind='barh')

# %% [markdown]
# #### ML Analyzing using - RandomForestRegressor Model.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

modelRF = RandomForestRegressor(n_estimators=20, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)


modelRF.fit(X_train,y_train)
y_pred = modelRF.predict(X_test)
modelRF.score(X_test,y_test)
# Out:
# -0.04936443586729422

# %%
pred_y_RF_df = pd.DataFrame({'Actual Stroke Value':y_test, 'Predicted Value':y_pred, 'absErrors':abs(y_test-y_pred),  'Sqr':(y_test-y_pred)*(y_test-y_pred),  'Percentage_Err':((abs(y_pred - y_test)) / y_test) * 100 })
pred_y_RF_df[0:20]
# Out:
#                  Actual Stroke Value  Predicted Value     absErrors  \
# Year_Obv
# 2017Tracts2186                   2.2            2.200  3.552714e-15
# 2017Tracts18155                  3.6            2.200  1.400000e+00
# 2017Tracts3029                   2.2            2.235  3.500000e-02
# 2017Tracts19284                  3.8            2.200  1.600000e+00
# 2017Tracts27453                  2.6            2.385  2.150000e-01
# 2017Tracts19118                  2.8            2.200  6.000000e-01
# 2017Tracts1925                   2.2            2.200  1.332268e-15
# 2017Tracts461                    2.2            2.275  7.500000e-02
# 2017Tracts14663                  3.1            2.305  7.950000e-01
# 2017Tracts2028                   2.2            2.285  8.500000e-02
# 2017Tracts3904                   2.2            2.200  1.776357e-15
# 2017Tracts17645                  4.0            2.930  1.070000e+00
# 2017Tracts9000                   2.2            2.890  6.900000e-01
# 2017Tracts24599                  3.1            2.485  6.150000e-01
# 2017Tracts10781                  2.4            3.340  9.400000e-01
# 2017Tracts24526                  4.1            2.760  1.340000e+00
# 2017Tracts25590                  3.8            2.830  9.700000e-01
# 2017Tracts1946                   2.2            2.220  2.000000e-02
# 2017Tracts5258                   2.2            2.820  6.200000e-01
# 2017Tracts5926                   2.2            2.200  4.884981e-15
#
#                           Sqr  Percentage_Err
# Year_Obv
# 2017Tracts2186   1.262177e-29    1.614870e-13
# 2017Tracts18155  1.960000e+00    3.888889e+01
# 2017Tracts3029   1.225000e-03    1.590909e+00
# 2017Tracts19284  2.560000e+00    4.210526e+01
# 2017Tracts27453  4.622500e-02    8.269231e+00
# 2017Tracts19118  3.600000e-01    2.142857e+01
# 2017Tracts1925   1.774937e-30    6.055762e-14
# 2017Tracts461    5.625000e-03    3.409091e+00
# 2017Tracts14663  6.320250e-01    2.564516e+01
# 2017Tracts2028   7.225000e-03    3.863636e+00
# 2017Tracts3904   3.155444e-30    8.074349e-14
# 2017Tracts17645  1.144900e+00    2.675000e+01
# 2017Tracts9000   4.761000e-01    3.136364e+01
# 2017Tracts24599  3.782250e-01    1.983871e+01
# 2017Tracts10781  8.836000e-01    3.916667e+01
# 2017Tracts24526  1.795600e+00    3.268293e+01
# 2017Tracts25590  9.409000e-01    2.552632e+01
# 2017Tracts1946   4.000000e-04    9.090909e-01
# 2017Tracts5258   3.844000e-01    2.818182e+01
# 2017Tracts5926   2.386304e-29    2.220446e-13

# %%
print('Score', r2_score(y_test,y_pred))
print("r2:{}  ".format(r2_score(y_pred,y_test)))  
print("mae:{}  ".format(mean_absolute_error(y_pred,y_test)))
print('mean_absolute_error = ', mean_absolute_error(y_pred,y_test))
print('mean_absolute_percentage_error = ', mean_absolute_percentage_error(y_pred,y_test))  # Verify error
print('MSE', mean_squared_error(y_test,y_pred))

#==============================================================
Tot_Err = pred_y_RF_df['absErrors'].count()
#==============================================================


# Cal. MAD
Sum_absErr = pred_y_RF_df['absErrors'].sum()
print('MAD = ', Sum_absErr / Tot_Err)


# Cal. MSE
Tot_Sum_Sqr = Sum_Sqr = pred_y_RF_df['Sqr'].sum()
print('MSE = ', Tot_Sum_Sqr / Tot_Err)

# Cal. MAPE
Tot_Percentage_Err = pred_y_RF_df['Percentage_Err'].sum()
print('MAPE = ', Tot_Percentage_Err / Tot_Err)
# Out:
# Score -0.04936443586729422
# r2:-12.404784366481207
# mae:0.6586625821876871
# mean_absolute_error =  0.6586625821876871
# mean_absolute_percentage_error =  0.2594609076674523
# MSE 1.306339861028093
# MAD =  0.6586625821876871
# MSE =  1.306339861028093
# MAPE =  19.086608862176643

# %%
model_ranks=pd.Series(modelRF.feature_importances_,index=X_train.columns,name='Importance')
ax=model_ranks.plot(kind='barh')
